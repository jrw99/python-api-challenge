# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import math
from datetime import date
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output Directory
output_data_loc = "../output_data"

# Output File (CSV)
output_data_file = f"{output_data_loc}/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
cities = []

def buildCityList() :
    # List for holding lat_lngs and cities
    lat_lngs = []

    # Create a set of random lat and lng combinations
    lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
    lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
    lat_lngs = zip(lats, lngs)

    # Identify nearest city for each lat, lng combination
    for lat_lng in lat_lngs:
        city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

        # If the city is unique, then add it to a our cities list
        if city not in cities:
            cities.append(city)

buildCityList()

if len(cities) < 500:
    buildCityList()

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 602

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# The free version of the openweathermap api allows for max 60 requests per minute, so we need to chunk our cities list
# into sets of < 60 per set to safely make calls 1 set per minute to ensure the requets get fullfiled and our account
# doesn't get suspended

def splitListBySize(listToSplit, size):
     lst = []
     while len(listToSplit) > size:
         chunk = listToSplit[:size]
         lst.append(chunk)
         listToSplit = listToSplit[size:]
     lst.append(listToSplit)
     return lst

city_sets = splitListBySize(cities,50)
city_sets
# Out:
# [['zaozerne',
#   'bluff',
#   'windhoek',
#   'cayenne',
#   'vestmannaeyjar',
#   'jamestown',
#   'tuktoyaktuk',
#   'neuquen',
#   'mar del plata',
#   'taolanaro',
#   'deputatskiy',
#   'hofn',
#   'bredasdorp',
#   'punta arenas',
#   'doume',
#   'puerto ayora',
#   'korla',
#   'rikitea',
#   'turukhansk',
#   'lasa',
#   'lysa hora',
#   'gorontalo',
#   'morgan city',
#   'chokurdakh',
#   'bethel',
#   'leningradskiy',
#   'samusu',
#   'new norfolk',
#   'port alfred',
#   'conakry',
#   'butaritari',
#   'cape town',
#   'lompoc',
#   'torbay',
#   'beringovskiy',
#   'clyde river',
#   'chuy',
#   'yirol',
#   'vaini',
#   'yellowknife',
#   'tasiilaq',
#   'avarua',
#   'juneau',
#   'progreso',
#   'comodoro rivadavia',
#   'vardo',
#   'bayburt',
#   'mildura',
#   'padang',
#   'hermanus'],
#  ['hihifo',
#   'acapulco',
#   'karauzyak',
#   'guadalupe y calvo',
#   'mokhsogollokh',
#   'upernavik',
#   'coquimbo',
#   'ozgon',
#   'yerbogachen',
#   'jalu',
#   'busselton',
#   'arequipa',
#   'vilyuysk',
#   'ahipara',
#   'kodiak',
#   'yulara',
#   'narsaq',
#   'bambous virieux',
#   'velikodvorskiy',
#   'grand river south east',
#   'barentsburg',
#   'palabuhanratu',
#   'albany',
#   'sept-iles',
#   'nome',
#   'grand-lahou',
#   'manbij',
#   'noshiro',
#   'nikolskoye',
#   'belushya guba',
#   'la maddalena',
#   'arraial do cabo',
#   'zaqatala',
#   'mangalia',
#   'saint-philippe',
#   'sioux lookout',
#   'bawku',
#   'illoqqortoormiut',
#   'carnarvon',
#   'mugur-aksy',
#   'nizhneyansk',
#   'atuona',
#   'ibra',
#   'kinablangan',
#   'pryazha',
#   'birao',
#   'sault sainte marie',
#   'hobart',
#   'severo-kurilsk',
#   'fort nelson'],
#  ['kijang',
#   'kaitangata',
#   'gizo',
#   'norman wells',
#   'naze',
#   'nara',
#   'dali',
#   'saint anthony',
#   'olinda',
#   'ulmu',
#   'saskylakh',
#   'buraydah',
#   'baoding',
#   'villa carlos paz',
#   'ushuaia',
#   'rivadavia',
#   'corvallis',
#   'xining',
#   'sao joao da barra',
#   'whitehorse',
#   'hilo',
#   'sisimiut',
#   'barrow',
#   'ribeira grande',
#   'san cristobal',
#   'chardara',
#   'berlevag',
#   'bengkulu',
#   'salta',
#   'lata',
#   'constitucion',
#   'umzimvubu',
#   'launceston',
#   'eldikan',
#   'kapaa',
#   'puerto del rosario',
#   'bjornevatn',
#   'taksimo',
#   'aklavik',
#   'providencia',
#   'lebu',
#   'gimli',
#   'khatanga',
#   'alice springs',
#   'skjervoy',
#   'dosso',
#   'madera',
#   'moree',
#   'masuguru',
#   'victoria'],
#  ['evensk',
#   'zhanatas',
#   'kuytun',
#   'beidao',
#   'kupang',
#   'sitka',
#   'urdoma',
#   'hirara',
#   'asosa',
#   'christchurch',
#   'quatre cocos',
#   'troitskoye',
#   'ballina',
#   'carutapera',
#   'vao',
#   'chara',
#   'vaitupu',
#   'tiksi',
#   'tuatapere',
#   'port hedland',
#   'nanortalik',
#   'guerrero negro',
#   'opuwo',
#   'port hardy',
#   'flin flon',
#   'felidhoo',
#   'praia da vitoria',
#   'komsomolskiy',
#   'airai',
#   'amasya',
#   'qandala',
#   'salalah',
#   'rumuruti',
#   'fortuna',
#   'ornskoldsvik',
#   'los llanos de aridane',
#   'thompson',
#   'dikson',
#   'ponta do sol',
#   'kruisfontein',
#   'gboko',
#   'marsh harbour',
#   'winslow',
#   'coro',
#   'ketchikan',
#   'bermejo',
#   'koyilandi',
#   'dickinson',
#   'kloulklubed',
#   'sunrise manor'],
#  ['panzhihua',
#   'kampot',
#   'peoria',
#   'graham',
#   'kavieng',
#   'provideniya',
#   'lavrentiya',
#   'attawapiskat',
#   'amderma',
#   'wajima',
#   'dunedin',
#   'mergui',
#   'narodychi',
#   'fare',
#   'chitungwiza',
#   'damara',
#   'sobolevo',
#   'esperance',
#   'ilulissat',
#   'mataura',
#   'tumannyy',
#   'saint george',
#   'port elizabeth',
#   'kailua',
#   'rocha',
#   'east london',
#   'qaanaaq',
#   'pastavy',
#   'qaqortoq',
#   'puta',
#   'sao filipe',
#   'ambodifototra',
#   'caravelas',
#   'general pico',
#   'lorengau',
#   'pamekasan',
#   'cabo san lucas',
#   'mount isa',
#   'mariental',
#   'sao gabriel da cachoeira',
#   'bichena',
#   'hasaki',
#   'pevek',
#   'talcahuano',
#   'san borja',
#   'nizwa',
#   'la rioja',
#   'saint-pierre',
#   'kamaishi',
#   'privolzhye'],
#  ['paamiut',
#   'gushikawa',
#   'geraldton',
#   'luderitz',
#   'poum',
#   'volkhov',
#   'truth or consequences',
#   'okhotsk',
#   'bhanjanagar',
#   'west bay',
#   'ancud',
#   'taltal',
#   'uwayl',
#   'sibolga',
#   'sturgis',
#   'nhulunbuy',
#   'bobonong',
#   'grand centre',
#   'bagdarin',
#   'iqaluit',
#   'alto araguaia',
#   'novyy rogachik',
#   'bougouni',
#   'makakilo city',
#   'touba',
#   'paita',
#   'axim',
#   'manokwari',
#   'harper',
#   'mabay',
#   'sentyabrskiy',
#   'horsham',
#   'port-cartier',
#   'yokadouma',
#   'tsihombe',
#   'suclayin',
#   'laguna',
#   'brae',
#   'irbil',
#   'hualmay',
#   'mahadday weyne',
#   'miri',
#   'namibe',
#   'ixtapa',
#   'palana',
#   'castro',
#   'meulaboh',
#   'kirakira',
#   'kulhudhuffushi',
#   'gerash'],
#  ['wuwei',
#   'port blair',
#   'wahran',
#   'riverton',
#   'longyearbyen',
#   'sherlovaya gora',
#   'susanville',
#   'tottori',
#   'rawannawi',
#   'saldanha',
#   'darhan',
#   'noyabrsk',
#   'acajutla',
#   'bolungarvik',
#   'manggar',
#   'maceio',
#   'semey',
#   'kinsale',
#   'shingu',
#   'souillac',
#   'bogovarovo',
#   'saint-joseph',
#   'kahului',
#   'orchard homes',
#   'sangar',
#   'omboue',
#   'champerico',
#   'mazamari',
#   'parras',
#   'stoyba',
#   'gao',
#   'alexandria',
#   'cedar city',
#   'galveston',
#   'zhifang',
#   'wanning',
#   'song phi nong',
#   'karratha',
#   'sola',
#   'grindavik',
#   'georgetown',
#   'portland',
#   'berekua',
#   'florianopolis',
#   'loandjili',
#   'svetlogorsk',
#   'platteville',
#   'aginskoye',
#   'pavda',
#   'sorvag'],
#  ['jiddah',
#   'bandarbeyla',
#   'chulman',
#   'sinnamary',
#   'kuche',
#   'illela',
#   'muros',
#   'mayo',
#   'yarmouth',
#   'denpasar',
#   'podbelsk',
#   'nuuk',
#   'aguimes',
#   'temaraia',
#   'baracoa',
#   'srednekolymsk',
#   'wooster',
#   'cockburn town',
#   'cherskiy',
#   'coihaique',
#   'half moon bay',
#   'codrington',
#   'faanui',
#   'severnoye',
#   'masvingo',
#   'port lincoln',
#   'west plains',
#   'namatanai',
#   'marrakesh',
#   'usinsk',
#   'mayahi',
#   'hithadhoo',
#   'burnie',
#   'palestine',
#   'unai',
#   'cawayan',
#   'lolua',
#   'mahebourg',
#   'hanna',
#   'broome',
#   'aksehir',
#   'mitu',
#   'aranos',
#   'tizapan el alto',
#   'athabasca',
#   'weligama',
#   'taoudenni',
#   'klaksvik',
#   'luanda',
#   'nalut'],
#  ['dawlatabad',
#   'pacific grove',
#   'lagoa',
#   'cidreira',
#   'santa cruz',
#   'warqla',
#   'mazyr',
#   'isabela',
#   'prince rupert',
#   'tessalit',
#   'moacsa',
#   'kristiansund',
#   'bilecik',
#   'korgen',
#   'izumo',
#   'swan river',
#   'alberton',
#   'dzhusaly',
#   'samalaeulu',
#   'lithakia',
#   'mount gambier',
#   'maningrida',
#   'alizai',
#   'haines junction',
#   'cap malheureux',
#   'kiama',
#   'alghero',
#   'pangai',
#   'vila velha',
#   'petropavlovsk-kamchatskiy',
#   'pisco',
#   'ostersund',
#   'coahuayana',
#   'satipo',
#   'nantucket',
#   'itarema',
#   'mys shmidta',
#   'sur',
#   'vila franca do campo',
#   'manaure',
#   'moose factory',
#   'nsoko',
#   'helong',
#   'petropavlovka',
#   'saleaula',
#   'jiuquan',
#   'rio grande',
#   'maniitsoq',
#   'fjerritslev',
#   'dingle'],
#  ['deogarh',
#   'henties bay',
#   'fuerte olimpo',
#   'khatra',
#   'belaya gora',
#   'jinchang',
#   'bow island',
#   'pochutla',
#   'balikpapan',
#   'san luis',
#   'aksarka',
#   'byron bay',
#   'pangnirtung',
#   'dhadar',
#   'avera',
#   'shestakovo',
#   'neiafu',
#   'barela',
#   'marawi',
#   'bemidji',
#   'brooks',
#   'baruun-urt',
#   'muncar',
#   'galiwinku',
#   'ust-kamchatsk',
#   'aguia branca',
#   'quarai',
#   'adrar',
#   'lazaro cardenas',
#   'gambiran',
#   'bouna',
#   'sukhobuzimskoye',
#   'hassleholm',
#   'azogues',
#   'talnakh',
#   'dhidhdhoo',
#   'barauli',
#   'jaranwala',
#   'marquette',
#   'hamilton',
#   'puerto lempira',
#   'chernyshevskiy',
#   'damulog',
#   'dubrovka',
#   'mwinilunga',
#   'adra',
#   'pampas',
#   'pedernales',
#   'bonthe',
#   'laishevo'],
#  ['pirajui',
#   'pokhara',
#   'yar-sale',
#   'erenhot',
#   'zaysan',
#   'nemuro',
#   'cooma',
#   'gornozavodsk',
#   'nyrob',
#   'feijo',
#   'kenora',
#   'diffa',
#   'husavik',
#   'ust-kuyga',
#   'hobyo',
#   'saint-augustin',
#   'rockhampton',
#   'chhatarpur',
#   'havoysund',
#   'ayorou',
#   'seoul',
#   'lida',
#   'pervomayskoye',
#   'labutta',
#   'falealupo',
#   'xiamen',
#   'maumere',
#   'silver city',
#   'te anau',
#   'lebedinyy',
#   'dwarka',
#   'lebanon',
#   'borujan',
#   'luwingu',
#   'quimper',
#   'luena',
#   'palmer',
#   'havelock',
#   'kota belud',
#   'mocuba',
#   'smidovich',
#   'tautira',
#   'moerai',
#   'faya',
#   'viedma',
#   'nicoya',
#   'la suiza',
#   'lazo',
#   'karaul',
#   'bolu'],
#  ['nagato',
#   'ossora',
#   'lai',
#   'burica',
#   'bull savanna',
#   'pinega',
#   'carmen',
#   'santiago de cao',
#   'suao',
#   'angra',
#   'kambi',
#   'jiwani',
#   'yeppoon',
#   'suntar',
#   'goderich',
#   'karakendzha',
#   'mikhaylovskoye',
#   'madimba',
#   'marcona',
#   'mahon',
#   'stromness',
#   'ahuimanu',
#   'morristown',
#   'necochea',
#   'prieska',
#   'mehamn',
#   'goure',
#   'itacare',
#   'yuzawa',
#   'mackay',
#   'koumac',
#   'beloha',
#   'bathsheba',
#   'yarim',
#   'katangli',
#   'kaputa',
#   'cozumel',
#   'katsuura',
#   'egvekinot',
#   'bima',
#   'kardymovo',
#   'chicama',
#   'bilibino',
#   'ndioum',
#   'limbang',
#   'asau',
#   'strezhevoy',
#   'fairbanks',
#   'jand',
#   'yakeshi'],
#  ['trincomalee', 'bac lieu']]

# %%
# base url for request
base_url = "http://api.openweathermap.org/data/2.5/weather"

# params for request
params = {
"units":"imperial",
"appid":weather_api_key
}

params['q'] = cities[0]
response = requests.get(url=base_url, params=params).json()
response
# Out:
# {'coord': {'lon': 33.2787, 'lat': 45.1582},
#  'weather': [{'id': 803,
#    'main': 'Clouds',
#    'description': 'broken clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 64.94,
#   'feels_like': 64.33,
#   'temp_min': 64.94,
#   'temp_max': 64.94,
#   'pressure': 1020,
#   'humidity': 68,
#   'sea_level': 1020,
#   'grnd_level': 1019},
#  'visibility': 10000,
#  'wind': {'speed': 10.38, 'deg': 284, 'gust': 15.9},
#  'clouds': {'all': 59},
#  'dt': 1632683939,
#  'sys': {'type': 2,
#   'id': 2037874,
#   'country': 'UA',
#   'sunrise': 1632627519,
#   'sunset': 1632670665},
#  'timezone': 10800,
#  'id': 687726,
#  'name': 'Zaozyornoye',
#  'cod': 200}

# %%
weather_data_cities = []

print('Beginning Data Retrieval\n------------------------------')

#for x in range(len(cities)):
#    print(f'Processing Record {x} of Set {} | {cities[x]}')

#def keepGoing(howmany, timeframe, startedAt):
#    tic = time.perf_counter()

# get the current time

city_sets_upperBound = (len(city_sets)-1)

for set_idx, city_set in enumerate(city_sets):    
    
    tic = time.perf_counter()
    
    for record_idx, city in enumerate(city_set):
        print(f'Processing Record {record_idx} of Set {set_idx} | {city}')
        
        # Add the city to the query params for the request
        params['q'] = city
        
        # Make the request
        response = requests.get(url=base_url, params=params).json()
        
        try:
            name = response['name']
        
            # add the response to a list 
            weather_data_cities.append(response)
        except:
            print('City not found. Skipping...')
            pass        
       
    toc = time.perf_counter()
    
    # if toc is > 1 min since tic, go ahead and iterate, otherwise wait whatever duration is left between 1 min and the elapsed time
    
    elapsedTime = toc - tic
    
    if set_idx < city_sets_upperBound:    
        if elapsedTime <= 60 :
            timeToWait = (60 - elapsedTime)
            print(f'waiting {timeToWait} seconds before next batch...')
            time.sleep(timeToWait)
            print('Resuming...')
    else:
        print('All cities processed!')
# Out:
# Beginning Data Retrieval
# ------------------------------
# Processing Record 0 of Set 0 | zaozerne
# Processing Record 1 of Set 0 | bluff
# Processing Record 2 of Set 0 | windhoek
# Processing Record 3 of Set 0 | cayenne
# Processing Record 4 of Set 0 | vestmannaeyjar
# Processing Record 5 of Set 0 | jamestown
# Processing Record 6 of Set 0 | tuktoyaktuk
# Processing Record 7 of Set 0 | neuquen
# Processing Record 8 of Set 0 | mar del plata
# Processing Record 9 of Set 0 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 0 | deputatskiy
# Processing Record 11 of Set 0 | hofn
# Processing Record 12 of Set 0 | bredasdorp
# Processing Record 13 of Set 0 | punta arenas
# Processing Record 14 of Set 0 | doume
# Processing Record 15 of Set 0 | puerto ayora
# Processing Record 16 of Set 0 | korla
# Processing Record 17 of Set 0 | rikitea
# Processing Record 18 of Set 0 | turukhansk
# Processing Record 19 of Set 0 | lasa
# Processing Record 20 of Set 0 | lysa hora
# Processing Record 21 of Set 0 | gorontalo
# Processing Record 22 of Set 0 | morgan city
# Processing Record 23 of Set 0 | chokurdakh
# Processing Record 24 of Set 0 | bethel
# Processing Record 25 of Set 0 | leningradskiy
# Processing Record 26 of Set 0 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 0 | new norfolk
# Processing Record 28 of Set 0 | port alfred
# Processing Record 29 of Set 0 | conakry
# Processing Record 30 of Set 0 | butaritari
# Processing Record 31 of Set 0 | cape town
# Processing Record 32 of Set 0 | lompoc
# Processing Record 33 of Set 0 | torbay
# Processing Record 34 of Set 0 | beringovskiy
# Processing Record 35 of Set 0 | clyde river
# Processing Record 36 of Set 0 | chuy
# Processing Record 37 of Set 0 | yirol
# City not found. Skipping...
# Processing Record 38 of Set 0 | vaini
# Processing Record 39 of Set 0 | yellowknife
# Processing Record 40 of Set 0 | tasiilaq
# Processing Record 41 of Set 0 | avarua
# Processing Record 42 of Set 0 | juneau
# Processing Record 43 of Set 0 | progreso
# Processing Record 44 of Set 0 | comodoro rivadavia
# Processing Record 45 of Set 0 | vardo
# Processing Record 46 of Set 0 | bayburt
# Processing Record 47 of Set 0 | mildura
# Processing Record 48 of Set 0 | padang
# Processing Record 49 of Set 0 | hermanus
# waiting 56.7646734000009 seconds before next batch...
# Resuming...
# Processing Record 0 of Set 1 | hihifo
# City not found. Skipping...
# Processing Record 1 of Set 1 | acapulco
# Processing Record 2 of Set 1 | karauzyak
# City not found. Skipping...
# Processing Record 3 of Set 1 | guadalupe y calvo
# Processing Record 4 of Set 1 | mokhsogollokh
# Processing Record 5 of Set 1 | upernavik
# Processing Record 6 of Set 1 | coquimbo
# Processing Record 7 of Set 1 | ozgon
# City not found. Skipping...
# Processing Record 8 of Set 1 | yerbogachen
# Processing Record 9 of Set 1 | jalu
# Processing Record 10 of Set 1 | busselton
# Processing Record 11 of Set 1 | arequipa
# Processing Record 12 of Set 1 | vilyuysk
# Processing Record 13 of Set 1 | ahipara
# Processing Record 14 of Set 1 | kodiak
# Processing Record 15 of Set 1 | yulara
# Processing Record 16 of Set 1 | narsaq
# Processing Record 17 of Set 1 | bambous virieux
# Processing Record 18 of Set 1 | velikodvorskiy
# Processing Record 19 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | sept-iles
# Processing Record 24 of Set 1 | nome
# Processing Record 25 of Set 1 | grand-lahou
# Processing Record 26 of Set 1 | manbij
# Processing Record 27 of Set 1 | noshiro
# Processing Record 28 of Set 1 | nikolskoye
# Processing Record 29 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 1 | la maddalena
# Processing Record 31 of Set 1 | arraial do cabo
# Processing Record 32 of Set 1 | zaqatala
# Processing Record 33 of Set 1 | mangalia
# Processing Record 34 of Set 1 | saint-philippe
# Processing Record 35 of Set 1 | sioux lookout
# Processing Record 36 of Set 1 | bawku
# Processing Record 37 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 38 of Set 1 | carnarvon
# Processing Record 39 of Set 1 | mugur-aksy
# Processing Record 40 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 1 | atuona
# Processing Record 42 of Set 1 | ibra
# Processing Record 43 of Set 1 | kinablangan
# Processing Record 44 of Set 1 | pryazha
# Processing Record 45 of Set 1 | birao
# Processing Record 46 of Set 1 | sault sainte marie
# Processing Record 47 of Set 1 | hobart
# Processing Record 48 of Set 1 | severo-kurilsk
# Processing Record 49 of Set 1 | fort nelson
# waiting 49.76388319999387 seconds before next batch...
# Resuming...
# Processing Record 0 of Set 2 | kijang
# Processing Record 1 of Set 2 | kaitangata
# Processing Record 2 of Set 2 | gizo
# Processing Record 3 of Set 2 | norman wells
# Processing Record 4 of Set 2 | naze
# Processing Record 5 of Set 2 | nara
# Processing Record 6 of Set 2 | dali
# Processing Record 7 of Set 2 | saint anthony
# Processing Record 8 of Set 2 | olinda
# Processing Record 9 of Set 2 | ulmu
# Processing Record 10 of Set 2 | saskylakh
# Processing Record 11 of Set 2 | buraydah
# Processing Record 12 of Set 2 | baoding
# Processing Record 13 of Set 2 | villa carlos paz
# Processing Record 14 of Set 2 | ushuaia
# Processing Record 15 of Set 2 | rivadavia
# Processing Record 16 of Set 2 | corvallis
# Processing Record 17 of Set 2 | xining
# Processing Record 18 of Set 2 | sao joao da barra
# Processing Record 19 of Set 2 | whitehorse
# Processing Record 20 of Set 2 | hilo
# Processing Record 21 of Set 2 | sisimiut
# Processing Record 22 of Set 2 | barrow
# Processing Record 23 of Set 2 | ribeira grande
# Processing Record 24 of Set 2 | san cristobal
# Processing Record 25 of Set 2 | chardara
# Processing Record 26 of Set 2 | berlevag
# Processing Record 27 of Set 2 | bengkulu
# Processing Record 28 of Set 2 | salta
# Processing Record 29 of Set 2 | lata
# Processing Record 30 of Set 2 | constitucion
# Processing Record 31 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 2 | launceston
# Processing Record 33 of Set 2 | eldikan
# City not found. Skipping...
# Processing Record 34 of Set 2 | kapaa
# Processing Record 35 of Set 2 | puerto del rosario
# Processing Record 36 of Set 2 | bjornevatn
# Processing Record 37 of Set 2 | taksimo
# Processing Record 38 of Set 2 | aklavik
# Processing Record 39 of Set 2 | providencia
# Processing Record 40 of Set 2 | lebu
# Processing Record 41 of Set 2 | gimli
# Processing Record 42 of Set 2 | khatanga
# Processing Record 43 of Set 2 | alice springs
# Processing Record 44 of Set 2 | skjervoy
# Processing Record 45 of Set 2 | dosso
# Processing Record 46 of Set 2 | madera
# Processing Record 47 of Set 2 | moree
# Processing Record 48 of Set 2 | masuguru
# Processing Record 49 of Set 2 | victoria
# waiting 49.865108099998906 seconds before next batch...
# Resuming...
# Processing Record 0 of Set 3 | evensk
# Processing Record 1 of Set 3 | zhanatas
# City not found. Skipping...
# Processing Record 2 of Set 3 | kuytun
# Processing Record 3 of Set 3 | beidao
# Processing Record 4 of Set 3 | kupang
# Processing Record 5 of Set 3 | sitka
# Processing Record 6 of Set 3 | urdoma
# Processing Record 7 of Set 3 | hirara
# Processing Record 8 of Set 3 | asosa
# Processing Record 9 of Set 3 | christchurch
# Processing Record 10 of Set 3 | quatre cocos
# Processing Record 11 of Set 3 | troitskoye
# Processing Record 12 of Set 3 | ballina
# Processing Record 13 of Set 3 | carutapera
# Processing Record 14 of Set 3 | vao
# Processing Record 15 of Set 3 | chara
# Processing Record 16 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 17 of Set 3 | tiksi
# Processing Record 18 of Set 3 | tuatapere
# Processing Record 19 of Set 3 | port hedland
# Processing Record 20 of Set 3 | nanortalik
# Processing Record 21 of Set 3 | guerrero negro
# Processing Record 22 of Set 3 | opuwo
# Processing Record 23 of Set 3 | port hardy
# Processing Record 24 of Set 3 | flin flon
# Processing Record 25 of Set 3 | felidhoo
# City not found. Skipping...
# Processing Record 26 of Set 3 | praia da vitoria
# Processing Record 27 of Set 3 | komsomolskiy
# Processing Record 28 of Set 3 | airai
# Processing Record 29 of Set 3 | amasya
# Processing Record 30 of Set 3 | qandala
# Processing Record 31 of Set 3 | salalah
# Processing Record 32 of Set 3 | rumuruti
# Processing Record 33 of Set 3 | fortuna
# Processing Record 34 of Set 3 | ornskoldsvik
# Processing Record 35 of Set 3 | los llanos de aridane
# Processing Record 36 of Set 3 | thompson
# Processing Record 37 of Set 3 | dikson
# Processing Record 38 of Set 3 | ponta do sol
# Processing Record 39 of Set 3 | kruisfontein
# Processing Record 40 of Set 3 | gboko
# Processing Record 41 of Set 3 | marsh harbour
# Processing Record 42 of Set 3 | winslow
# Processing Record 43 of Set 3 | coro
# Processing Record 44 of Set 3 | ketchikan
# Processing Record 45 of Set 3 | bermejo
# Processing Record 46 of Set 3 | koyilandi
# City not found. Skipping...
# Processing Record 47 of Set 3 | dickinson
# Processing Record 48 of Set 3 | kloulklubed
# Processing Record 49 of Set 3 | sunrise manor
# waiting 49.85694220000005 seconds before next batch...
# Resuming...
# Processing Record 0 of Set 4 | panzhihua
# Processing Record 1 of Set 4 | kampot
# Processing Record 2 of Set 4 | peoria
# Processing Record 3 of Set 4 | graham
# Processing Record 4 of Set 4 | kavieng
# Processing Record 5 of Set 4 | provideniya
# Processing Record 6 of Set 4 | lavrentiya
# Processing Record 7 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 8 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 4 | wajima
# Processing Record 10 of Set 4 | dunedin
# Processing Record 11 of Set 4 | mergui
# City not found. Skipping...
# Processing Record 12 of Set 4 | narodychi
# Processing Record 13 of Set 4 | fare
# Processing Record 14 of Set 4 | chitungwiza
# Processing Record 15 of Set 4 | damara
# Processing Record 16 of Set 4 | sobolevo
# Processing Record 17 of Set 4 | esperance
# Processing Record 18 of Set 4 | ilulissat
# Processing Record 19 of Set 4 | mataura
# Processing Record 20 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 4 | saint george
# Processing Record 22 of Set 4 | port elizabeth
# Processing Record 23 of Set 4 | kailua
# Processing Record 24 of Set 4 | rocha
# Processing Record 25 of Set 4 | east london
# Processing Record 26 of Set 4 | qaanaaq
# Processing Record 27 of Set 4 | pastavy
# Processing Record 28 of Set 4 | qaqortoq
# Processing Record 29 of Set 4 | puta
# Processing Record 30 of Set 4 | sao filipe
# Processing Record 31 of Set 4 | ambodifototra
# City not found. Skipping...
# Processing Record 32 of Set 4 | caravelas
# Processing Record 33 of Set 4 | general pico
# Processing Record 34 of Set 4 | lorengau
# Processing Record 35 of Set 4 | pamekasan
# Processing Record 36 of Set 4 | cabo san lucas
# Processing Record 37 of Set 4 | mount isa
# Processing Record 38 of Set 4 | mariental
# Processing Record 39 of Set 4 | sao gabriel da cachoeira
# Processing Record 40 of Set 4 | bichena
# Processing Record 41 of Set 4 | hasaki
# Processing Record 42 of Set 4 | pevek
# Processing Record 43 of Set 4 | talcahuano
# Processing Record 44 of Set 4 | san borja
# Processing Record 45 of Set 4 | nizwa
# Processing Record 46 of Set 4 | la rioja
# Processing Record 47 of Set 4 | saint-pierre
# Processing Record 48 of Set 4 | kamaishi
# Processing Record 49 of Set 4 | privolzhye
# waiting 49.648761399999785 seconds before next batch...
# Resuming...
# Processing Record 0 of Set 5 | paamiut
# Processing Record 1 of Set 5 | gushikawa
# Processing Record 2 of Set 5 | geraldton
# Processing Record 3 of Set 5 | luderitz
# Processing Record 4 of Set 5 | poum
# Processing Record 5 of Set 5 | volkhov
# Processing Record 6 of Set 5 | truth or consequences
# Processing Record 7 of Set 5 | okhotsk
# Processing Record 8 of Set 5 | bhanjanagar
# Processing Record 9 of Set 5 | west bay
# Processing Record 10 of Set 5 | ancud
# Processing Record 11 of Set 5 | taltal
# Processing Record 12 of Set 5 | uwayl
# City not found. Skipping...
# Processing Record 13 of Set 5 | sibolga
# Processing Record 14 of Set 5 | sturgis
# Processing Record 15 of Set 5 | nhulunbuy
# Processing Record 16 of Set 5 | bobonong
# City not found. Skipping...
# Processing Record 17 of Set 5 | grand centre
# City not found. Skipping...
# Processing Record 18 of Set 5 | bagdarin
# Processing Record 19 of Set 5 | iqaluit
# Processing Record 20 of Set 5 | alto araguaia
# Processing Record 21 of Set 5 | novyy rogachik
# Processing Record 22 of Set 5 | bougouni
# Processing Record 23 of Set 5 | makakilo city
# Processing Record 24 of Set 5 | touba
# Processing Record 25 of Set 5 | paita
# Processing Record 26 of Set 5 | axim
# Processing Record 27 of Set 5 | manokwari
# Processing Record 28 of Set 5 | harper
# Processing Record 29 of Set 5 | mabay
# Processing Record 30 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 5 | horsham
# Processing Record 32 of Set 5 | port-cartier
# Processing Record 33 of Set 5 | yokadouma
# Processing Record 34 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 5 | suclayin
# Processing Record 36 of Set 5 | laguna
# Processing Record 37 of Set 5 | brae
# Processing Record 38 of Set 5 | irbil
# Processing Record 39 of Set 5 | hualmay
# Processing Record 40 of Set 5 | mahadday weyne
# City not found. Skipping...
# Processing Record 41 of Set 5 | miri
# Processing Record 42 of Set 5 | namibe
# Processing Record 43 of Set 5 | ixtapa
# Processing Record 44 of Set 5 | palana
# Processing Record 45 of Set 5 | castro
# Processing Record 46 of Set 5 | meulaboh
# Processing Record 47 of Set 5 | kirakira
# Processing Record 48 of Set 5 | kulhudhuffushi
# Processing Record 49 of Set 5 | gerash
# waiting 49.498208799996064 seconds before next batch...
# Resuming...
# Processing Record 0 of Set 6 | wuwei
# Processing Record 1 of Set 6 | port blair
# Processing Record 2 of Set 6 | wahran
# City not found. Skipping...
# Processing Record 3 of Set 6 | riverton
# Processing Record 4 of Set 6 | longyearbyen
# Processing Record 5 of Set 6 | sherlovaya gora
# Processing Record 6 of Set 6 | susanville
# Processing Record 7 of Set 6 | tottori
# Processing Record 8 of Set 6 | rawannawi
# City not found. Skipping...
# Processing Record 9 of Set 6 | saldanha
# Processing Record 10 of Set 6 | darhan
# Processing Record 11 of Set 6 | noyabrsk
# Processing Record 12 of Set 6 | acajutla
# Processing Record 13 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 6 | manggar
# Processing Record 15 of Set 6 | maceio
# Processing Record 16 of Set 6 | semey
# Processing Record 17 of Set 6 | kinsale
# Processing Record 18 of Set 6 | shingu
# Processing Record 19 of Set 6 | souillac
# Processing Record 20 of Set 6 | bogovarovo
# Processing Record 21 of Set 6 | saint-joseph
# Processing Record 22 of Set 6 | kahului
# Processing Record 23 of Set 6 | orchard homes
# Processing Record 24 of Set 6 | sangar
# Processing Record 25 of Set 6 | omboue
# Processing Record 26 of Set 6 | champerico
# Processing Record 27 of Set 6 | mazamari
# Processing Record 28 of Set 6 | parras
# City not found. Skipping...
# Processing Record 29 of Set 6 | stoyba
# City not found. Skipping...
# Processing Record 30 of Set 6 | gao
# Processing Record 31 of Set 6 | alexandria
# Processing Record 32 of Set 6 | cedar city
# Processing Record 33 of Set 6 | galveston
# Processing Record 34 of Set 6 | zhifang
# Processing Record 35 of Set 6 | wanning
# Processing Record 36 of Set 6 | song phi nong
# Processing Record 37 of Set 6 | karratha
# Processing Record 38 of Set 6 | sola
# Processing Record 39 of Set 6 | grindavik
# Processing Record 40 of Set 6 | georgetown
# Processing Record 41 of Set 6 | portland
# Processing Record 42 of Set 6 | berekua
# Processing Record 43 of Set 6 | florianopolis
# Processing Record 44 of Set 6 | loandjili
# Processing Record 45 of Set 6 | svetlogorsk
# Processing Record 46 of Set 6 | platteville
# Processing Record 47 of Set 6 | aginskoye
# Processing Record 48 of Set 6 | pavda
# City not found. Skipping...
# Processing Record 49 of Set 6 | sorvag
# City not found. Skipping...
# waiting 50.1482834999988 seconds before next batch...
# Resuming...
# Processing Record 0 of Set 7 | jiddah
# City not found. Skipping...
# Processing Record 1 of Set 7 | bandarbeyla
# Processing Record 2 of Set 7 | chulman
# Processing Record 3 of Set 7 | sinnamary
# Processing Record 4 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 5 of Set 7 | illela
# Processing Record 6 of Set 7 | muros
# Processing Record 7 of Set 7 | mayo
# Processing Record 8 of Set 7 | yarmouth
# Processing Record 9 of Set 7 | denpasar
# Processing Record 10 of Set 7 | podbelsk
# City not found. Skipping...
# Processing Record 11 of Set 7 | nuuk
# Processing Record 12 of Set 7 | aguimes
# Processing Record 13 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 14 of Set 7 | baracoa
# Processing Record 15 of Set 7 | srednekolymsk
# Processing Record 16 of Set 7 | wooster
# Processing Record 17 of Set 7 | cockburn town
# Processing Record 18 of Set 7 | cherskiy
# Processing Record 19 of Set 7 | coihaique
# Processing Record 20 of Set 7 | half moon bay
# Processing Record 21 of Set 7 | codrington
# Processing Record 22 of Set 7 | faanui
# Processing Record 23 of Set 7 | severnoye
# Processing Record 24 of Set 7 | masvingo
# Processing Record 25 of Set 7 | port lincoln
# Processing Record 26 of Set 7 | west plains
# Processing Record 27 of Set 7 | namatanai
# Processing Record 28 of Set 7 | marrakesh
# Processing Record 29 of Set 7 | usinsk
# Processing Record 30 of Set 7 | mayahi
# Processing Record 31 of Set 7 | hithadhoo
# Processing Record 32 of Set 7 | burnie
# Processing Record 33 of Set 7 | palestine
# Processing Record 34 of Set 7 | unai
# Processing Record 35 of Set 7 | cawayan
# Processing Record 36 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 37 of Set 7 | mahebourg
# Processing Record 38 of Set 7 | hanna
# Processing Record 39 of Set 7 | broome
# Processing Record 40 of Set 7 | aksehir
# Processing Record 41 of Set 7 | mitu
# Processing Record 42 of Set 7 | aranos
# Processing Record 43 of Set 7 | tizapan el alto
# Processing Record 44 of Set 7 | athabasca
# Processing Record 45 of Set 7 | weligama
# Processing Record 46 of Set 7 | taoudenni
# Processing Record 47 of Set 7 | klaksvik
# Processing Record 48 of Set 7 | luanda
# Processing Record 49 of Set 7 | nalut
# waiting 47.810782599997765 seconds before next batch...
# Resuming...
# Processing Record 0 of Set 8 | dawlatabad
# Processing Record 1 of Set 8 | pacific grove
# Processing Record 2 of Set 8 | lagoa
# Processing Record 3 of Set 8 | cidreira
# Processing Record 4 of Set 8 | santa cruz
# Processing Record 5 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 8 | mazyr
# Processing Record 7 of Set 8 | isabela
# Processing Record 8 of Set 8 | prince rupert
# Processing Record 9 of Set 8 | tessalit
# Processing Record 10 of Set 8 | moacsa
# Processing Record 11 of Set 8 | kristiansund
# Processing Record 12 of Set 8 | bilecik
# Processing Record 13 of Set 8 | korgen
# Processing Record 14 of Set 8 | izumo
# Processing Record 15 of Set 8 | swan river
# Processing Record 16 of Set 8 | alberton
# Processing Record 17 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 18 of Set 8 | samalaeulu
# City not found. Skipping...
# Processing Record 19 of Set 8 | lithakia
# Processing Record 20 of Set 8 | mount gambier
# Processing Record 21 of Set 8 | maningrida
# Processing Record 22 of Set 8 | alizai
# Processing Record 23 of Set 8 | haines junction
# Processing Record 24 of Set 8 | cap malheureux
# Processing Record 25 of Set 8 | kiama
# Processing Record 26 of Set 8 | alghero
# Processing Record 27 of Set 8 | pangai
# Processing Record 28 of Set 8 | vila velha
# Processing Record 29 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 30 of Set 8 | pisco
# Processing Record 31 of Set 8 | ostersund
# Processing Record 32 of Set 8 | coahuayana
# Processing Record 33 of Set 8 | satipo
# Processing Record 34 of Set 8 | nantucket
# Processing Record 35 of Set 8 | itarema
# Processing Record 36 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 37 of Set 8 | sur
# Processing Record 38 of Set 8 | vila franca do campo
# Processing Record 39 of Set 8 | manaure
# Processing Record 40 of Set 8 | moose factory
# Processing Record 41 of Set 8 | nsoko
# Processing Record 42 of Set 8 | helong
# Processing Record 43 of Set 8 | petropavlovka
# Processing Record 44 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 8 | jiuquan
# Processing Record 46 of Set 8 | rio grande
# Processing Record 47 of Set 8 | maniitsoq
# Processing Record 48 of Set 8 | fjerritslev
# Processing Record 49 of Set 8 | dingle
# waiting 49.51826090000395 seconds before next batch...
# Resuming...
# Processing Record 0 of Set 9 | deogarh
# Processing Record 1 of Set 9 | henties bay
# Processing Record 2 of Set 9 | fuerte olimpo
# Processing Record 3 of Set 9 | khatra
# Processing Record 4 of Set 9 | belaya gora
# Processing Record 5 of Set 9 | jinchang
# Processing Record 6 of Set 9 | bow island
# Processing Record 7 of Set 9 | pochutla
# Processing Record 8 of Set 9 | balikpapan
# Processing Record 9 of Set 9 | san luis
# Processing Record 10 of Set 9 | aksarka
# Processing Record 11 of Set 9 | byron bay
# Processing Record 12 of Set 9 | pangnirtung
# Processing Record 13 of Set 9 | dhadar
# Processing Record 14 of Set 9 | avera
# Processing Record 15 of Set 9 | shestakovo
# Processing Record 16 of Set 9 | neiafu
# Processing Record 17 of Set 9 | barela
# Processing Record 18 of Set 9 | marawi
# Processing Record 19 of Set 9 | bemidji
# Processing Record 20 of Set 9 | brooks
# Processing Record 21 of Set 9 | baruun-urt
# Processing Record 22 of Set 9 | muncar
# Processing Record 23 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 24 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 25 of Set 9 | aguia branca
# Processing Record 26 of Set 9 | quarai
# Processing Record 27 of Set 9 | adrar
# Processing Record 28 of Set 9 | lazaro cardenas
# Processing Record 29 of Set 9 | gambiran
# Processing Record 30 of Set 9 | bouna
# Processing Record 31 of Set 9 | sukhobuzimskoye
# Processing Record 32 of Set 9 | hassleholm
# Processing Record 33 of Set 9 | azogues
# Processing Record 34 of Set 9 | talnakh
# Processing Record 35 of Set 9 | dhidhdhoo
# Processing Record 36 of Set 9 | barauli
# Processing Record 37 of Set 9 | jaranwala
# Processing Record 38 of Set 9 | marquette
# Processing Record 39 of Set 9 | hamilton
# Processing Record 40 of Set 9 | puerto lempira
# Processing Record 41 of Set 9 | chernyshevskiy
# Processing Record 42 of Set 9 | damulog
# Processing Record 43 of Set 9 | dubrovka
# Processing Record 44 of Set 9 | mwinilunga
# Processing Record 45 of Set 9 | adra
# Processing Record 46 of Set 9 | pampas
# Processing Record 47 of Set 9 | pedernales
# Processing Record 48 of Set 9 | bonthe
# Processing Record 49 of Set 9 | laishevo
# waiting 47.10937779999949 seconds before next batch...
# Resuming...
# Processing Record 0 of Set 10 | pirajui
# Processing Record 1 of Set 10 | pokhara
# Processing Record 2 of Set 10 | yar-sale
# Processing Record 3 of Set 10 | erenhot
# Processing Record 4 of Set 10 | zaysan
# Processing Record 5 of Set 10 | nemuro
# Processing Record 6 of Set 10 | cooma
# Processing Record 7 of Set 10 | gornozavodsk
# Processing Record 8 of Set 10 | nyrob
# Processing Record 9 of Set 10 | feijo
# Processing Record 10 of Set 10 | kenora
# Processing Record 11 of Set 10 | diffa
# Processing Record 12 of Set 10 | husavik
# Processing Record 13 of Set 10 | ust-kuyga
# Processing Record 14 of Set 10 | hobyo
# Processing Record 15 of Set 10 | saint-augustin
# Processing Record 16 of Set 10 | rockhampton
# Processing Record 17 of Set 10 | chhatarpur
# Processing Record 18 of Set 10 | havoysund
# Processing Record 19 of Set 10 | ayorou
# Processing Record 20 of Set 10 | seoul
# Processing Record 21 of Set 10 | lida
# Processing Record 22 of Set 10 | pervomayskoye
# Processing Record 23 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 24 of Set 10 | falealupo
# City not found. Skipping...
# Processing Record 25 of Set 10 | xiamen
# Processing Record 26 of Set 10 | maumere
# Processing Record 27 of Set 10 | silver city
# Processing Record 28 of Set 10 | te anau
# Processing Record 29 of Set 10 | lebedinyy
# Processing Record 30 of Set 10 | dwarka
# Processing Record 31 of Set 10 | lebanon
# Processing Record 32 of Set 10 | borujan
# City not found. Skipping...
# Processing Record 33 of Set 10 | luwingu
# Processing Record 34 of Set 10 | quimper
# Processing Record 35 of Set 10 | luena
# Processing Record 36 of Set 10 | palmer
# Processing Record 37 of Set 10 | havelock
# Processing Record 38 of Set 10 | kota belud
# Processing Record 39 of Set 10 | mocuba
# Processing Record 40 of Set 10 | smidovich
# Processing Record 41 of Set 10 | tautira
# Processing Record 42 of Set 10 | moerai
# Processing Record 43 of Set 10 | faya
# Processing Record 44 of Set 10 | viedma
# Processing Record 45 of Set 10 | nicoya
# Processing Record 46 of Set 10 | la suiza
# Processing Record 47 of Set 10 | lazo
# Processing Record 48 of Set 10 | karaul
# City not found. Skipping...
# Processing Record 49 of Set 10 | bolu
# waiting 47.542015099999844 seconds before next batch...
# Resuming...
# Processing Record 0 of Set 11 | nagato
# Processing Record 1 of Set 11 | ossora
# Processing Record 2 of Set 11 | lai
# Processing Record 3 of Set 11 | burica
# City not found. Skipping...
# Processing Record 4 of Set 11 | bull savanna
# Processing Record 5 of Set 11 | pinega
# Processing Record 6 of Set 11 | carmen
# Processing Record 7 of Set 11 | santiago de cao
# Processing Record 8 of Set 11 | suao
# City not found. Skipping...
# Processing Record 9 of Set 11 | angra
# City not found. Skipping...
# Processing Record 10 of Set 11 | kambi
# Processing Record 11 of Set 11 | jiwani
# Processing Record 12 of Set 11 | yeppoon
# Processing Record 13 of Set 11 | suntar
# Processing Record 14 of Set 11 | goderich
# Processing Record 15 of Set 11 | karakendzha
# City not found. Skipping...
# Processing Record 16 of Set 11 | mikhaylovskoye
# Processing Record 17 of Set 11 | madimba
# Processing Record 18 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 11 | mahon
# Processing Record 20 of Set 11 | stromness
# Processing Record 21 of Set 11 | ahuimanu
# Processing Record 22 of Set 11 | morristown
# Processing Record 23 of Set 11 | necochea
# Processing Record 24 of Set 11 | prieska
# Processing Record 25 of Set 11 | mehamn
# Processing Record 26 of Set 11 | goure
# Processing Record 27 of Set 11 | itacare
# Processing Record 28 of Set 11 | yuzawa
# Processing Record 29 of Set 11 | mackay
# Processing Record 30 of Set 11 | koumac
# Processing Record 31 of Set 11 | beloha
# Processing Record 32 of Set 11 | bathsheba
# Processing Record 33 of Set 11 | yarim
# Processing Record 34 of Set 11 | katangli
# Processing Record 35 of Set 11 | kaputa
# Processing Record 36 of Set 11 | cozumel
# Processing Record 37 of Set 11 | katsuura
# Processing Record 38 of Set 11 | egvekinot
# Processing Record 39 of Set 11 | bima
# Processing Record 40 of Set 11 | kardymovo
# Processing Record 41 of Set 11 | chicama
# Processing Record 42 of Set 11 | bilibino
# Processing Record 43 of Set 11 | ndioum
# Processing Record 44 of Set 11 | limbang
# Processing Record 45 of Set 11 | asau
# Processing Record 46 of Set 11 | strezhevoy
# Processing Record 47 of Set 11 | fairbanks
# Processing Record 48 of Set 11 | jand
# Processing Record 49 of Set 11 | yakeshi
# waiting 48.346368300000904 seconds before next batch...
# Resuming...
# Processing Record 0 of Set 12 | trincomalee
# Processing Record 1 of Set 12 | bac lieu
# waiting 59.44016360000387 seconds before next batch...
# Resuming...

# %%
weather_data_cities
# Out:
# [{'coord': {'lon': 33.2787, 'lat': 45.1582},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 64.94,
#    'feels_like': 64.33,
#    'temp_min': 64.94,
#    'temp_max': 64.94,
#    'pressure': 1020,
#    'humidity': 68,
#    'sea_level': 1020,
#    'grnd_level': 1019},
#   'visibility': 10000,
#   'wind': {'speed': 10.38, 'deg': 284, 'gust': 15.9},
#   'clouds': {'all': 59},
#   'dt': 1632683939,
#   'sys': {'type': 2,
#    'id': 2037874,
#    'country': 'UA',
#    'sunrise': 1632627519,
#    'sunset': 1632670665},
#   'timezone': 10800,
#   'id': 687726,
#   'name': 'Zaozyornoye',
#   'cod': 200},
#  {'coord': {'lon': 168.3333, 'lat': -46.6},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 38.79,
#    'feels_like': 33.13,
#    'temp_min': 38.79,
#    'temp_max': 38.79,
#    'pressure': 1021,
#    'humidity': 80,
#    'sea_level': 1021,
#    'grnd_level': 1017},
#   'visibility': 10000,
#   'wind': {'speed': 7.96, 'deg': 340, 'gust': 9.71},
#   'clouds': {'all': 21},
#   'dt': 1632683947,
#   'sys': {'country': 'NZ', 'sunrise': 1632680788, 'sunset': 1632725343},
#   'timezone': 46800,
#   'id': 2206939,
#   'name': 'Bluff',
#   'cod': 200},
#  {'coord': {'lon': 17.0832, 'lat': -22.5594},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 77.2,
#    'feels_like': 75.36,
#    'temp_min': 76.1,
#    'temp_max': 77.2,
#    'pressure': 1021,
#    'humidity': 16},
#   'visibility': 10000,
#   'wind': {'speed': 4.61, 'deg': 250},
#   'clouds': {'all': 2},
#   'dt': 1632683948,
#   'sys': {'type': 1,
#    'id': 2319,
#    'country': 'NA',
#    'sunrise': 1632631032,
#    'sunset': 1632674924},
#   'timezone': 7200,
#   'id': 3352136,
#   'name': 'Windhoek',
#   'cod': 200},
#  {'coord': {'lon': -52.3333, 'lat': 4.9333},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 86.09,
#    'feels_like': 95.74,
#    'temp_min': 86.09,
#    'temp_max': 89.64,
#    'pressure': 1012,
#    'humidity': 71},
#   'visibility': 10000,
#   'wind': {'speed': 5.99, 'deg': 70, 'gust': 11.99},
#   'clouds': {'all': 88},
#   'dt': 1632683948,
#   'sys': {'type': 2,
#    'id': 2038747,
#    'country': 'GF',
#    'sunrise': 1632647862,
#    'sunset': 1632691405},
#   'timezone': -10800,
#   'id': 3382160,
#   'name': 'Cayenne',
#   'cod': 200},
#  {'coord': {'lon': -20.2734, 'lat': 63.4427},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 43.25,
#    'feels_like': 40.19,
#    'temp_min': 43.25,
#    'temp_max': 43.25,
#    'pressure': 988,
#    'humidity': 81,
#    'sea_level': 988,
#    'grnd_level': 987},
#   'visibility': 10000,
#   'wind': {'speed': 5.14, 'deg': 309, 'gust': 5.75},
#   'clouds': {'all': 98},
#   'dt': 1632683948,
#   'sys': {'country': 'IS', 'sunrise': 1632640540, 'sunset': 1632683343},
#   'timezone': 0,
#   'id': 3412093,
#   'name': 'Vestmannaeyjar',
#   'cod': 200},
#  {'coord': {'lon': -79.2353, 'lat': 42.097},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 65.44,
#    'feels_like': 63.75,
#    'temp_min': 61.34,
#    'temp_max': 69.12,
#    'pressure': 1014,
#    'humidity': 44},
#   'visibility': 10000,
#   'wind': {'speed': 11.99, 'deg': 250, 'gust': 20},
#   'clouds': {'all': 75},
#   'dt': 1632683780,
#   'sys': {'type': 2,
#    'id': 2008828,
#    'country': 'US',
#    'sunrise': 1632654525,
#    'sunset': 1632697653},
#   'timezone': -14400,
#   'id': 5122534,
#   'name': 'Jamestown',
#   'cod': 200},
#  {'coord': {'lon': -133.0374, 'lat': 69.4541},
#   'weather': [{'id': 600,
#     'main': 'Snow',
#     'description': 'light snow',
#     'icon': '13d'},
#    {'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}],
#   'base': 'stations',
#   'main': {'temp': 33.8,
#    'feels_like': 23.52,
#    'temp_min': 33.8,
#    'temp_max': 33.8,
#    'pressure': 1009,
#    'humidity': 93},
#   'visibility': 9656,
#   'wind': {'speed': 16.11, 'deg': 300, 'gust': 21.85},
#   'rain': {'1h': 0.2},
#   'clouds': {'all': 90},
#   'dt': 1632683949,
#   'sys': {'type': 1,
#    'id': 942,
#    'country': 'CA',
#    'sunrise': 1632667767,
#    'sunset': 1632710229},
#   'timezone': -21600,
#   'id': 6170031,
#   'name': 'Tuktoyaktuk',
#   'cod': 200},
#  {'coord': {'lon': -68.0591, 'lat': -38.9516},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 60.69,
#    'feels_like': 57.63,
#    'temp_min': 60.69,
#    'temp_max': 60.69,
#    'pressure': 1020,
#    'humidity': 25},
#   'visibility': 10000,
#   'wind': {'speed': 6.91, 'deg': 320},
#   'clouds': {'all': 0},
#   'dt': 1632683949,
#   'sys': {'type': 1,
#    'id': 8310,
#    'country': 'AR',
#    'sunrise': 1632651280,
#    'sunset': 1632695534},
#   'timezone': -10800,
#   'id': 3843123,
#   'name': 'Neuquén',
#   'cod': 200},
#  {'coord': {'lon': -57.5575, 'lat': -38.0023},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 55.38,
#    'feels_like': 53.64,
#    'temp_min': 53.87,
#    'temp_max': 58.08,
#    'pressure': 1016,
#    'humidity': 64},
#   'visibility': 10000,
#   'wind': {'speed': 8.99, 'deg': 225, 'gust': 15.99},
#   'clouds': {'all': 75},
#   'dt': 1632683949,
#   'sys': {'type': 2,
#    'id': 264934,
#    'country': 'AR',
#    'sunrise': 1632648775,
#    'sunset': 1632692999},
#   'timezone': -10800,
#   'id': 3430863,
#   'name': 'Mar del Plata',
#   'cod': 200},
#  {'coord': {'lon': 139.9, 'lat': 69.3},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 27.52,
#    'feels_like': 14.92,
#    'temp_min': 27.52,
#    'temp_max': 27.52,
#    'pressure': 1019,
#    'humidity': 87,
#    'sea_level': 1019,
#    'grnd_level': 948},
#   'visibility': 10000,
#   'wind': {'speed': 20.11, 'deg': 282, 'gust': 32.93},
#   'clouds': {'all': 100},
#   'dt': 1632683949,
#   'sys': {'country': 'RU', 'sunrise': 1632688713, 'sunset': 1632731063},
#   'timezone': 36000,
#   'id': 2028164,
#   'name': 'Deputatsky',
#   'cod': 200},
#  {'coord': {'lon': -15.2082, 'lat': 64.2539},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 43.95,
#    'feels_like': 40.8,
#    'temp_min': 43.95,
#    'temp_max': 43.95,
#    'pressure': 988,
#    'humidity': 74,
#    'sea_level': 988,
#    'grnd_level': 988},
#   'visibility': 10000,
#   'wind': {'speed': 5.46, 'deg': 41, 'gust': 4.76},
#   'clouds': {'all': 50},
#   'dt': 1632683866,
#   'sys': {'country': 'IS', 'sunrise': 1632639332, 'sunset': 1632682120},
#   'timezone': 0,
#   'id': 2630299,
#   'name': 'Hofn',
#   'cod': 200},
#  {'coord': {'lon': 20.0403, 'lat': -34.5322},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 58.32,
#    'feels_like': 57.99,
#    'temp_min': 58.32,
#    'temp_max': 59.29,
#    'pressure': 1013,
#    'humidity': 88},
#   'visibility': 10000,
#   'wind': {'speed': 4.61, 'deg': 190},
#   'clouds': {'all': 1},
#   'dt': 1632683871,
#   'sys': {'type': 1,
#    'id': 1966,
#    'country': 'ZA',
#    'sunrise': 1632630212,
#    'sunset': 1632674325},
#   'timezone': 7200,
#   'id': 1015776,
#   'name': 'Bredasdorp',
#   'cod': 200},
#  {'coord': {'lon': -70.9167, 'lat': -53.15},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 48.31,
#    'feels_like': 41.7,
#    'temp_min': 48.11,
#    'temp_max': 48.31,
#    'pressure': 1008,
#    'humidity': 49},
#   'visibility': 10000,
#   'wind': {'speed': 18.41, 'deg': 300},
#   'clouds': {'all': 40},
#   'dt': 1632683866,
#   'sys': {'type': 1,
#    'id': 8487,
#    'country': 'CL',
#    'sunrise': 1632651713,
#    'sunset': 1632696473},
#   'timezone': -10800,
#   'id': 3874787,
#   'name': 'Punta Arenas',
#   'cod': 200},
#  {'coord': {'lon': 13.45, 'lat': 4.2333},
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 69.1,
#    'feels_like': 70.18,
#    'temp_min': 69.1,
#    'temp_max': 69.1,
#    'pressure': 1012,
#    'humidity': 95,
#    'sea_level': 1012,
#    'grnd_level': 942},
#   'visibility': 10000,
#   'wind': {'speed': 1.9, 'deg': 290, 'gust': 2.01},
#   'rain': {'1h': 1.02},
#   'clouds': {'all': 97},
#   'dt': 1632683950,
#   'sys': {'country': 'CM', 'sunrise': 1632632073, 'sunset': 1632675626},
#   'timezone': 3600,
#   'id': 2232497,
#   'name': 'Doumé',
#   'cod': 200},
#  {'coord': {'lon': -90.3518, 'lat': -0.7393},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 78.76,
#    'feels_like': 78.76,
#    'temp_min': 78.76,
#    'temp_max': 78.76,
#    'pressure': 1014,
#    'humidity': 83,
#    'sea_level': 1014,
#    'grnd_level': 1007},
#   'visibility': 10000,
#   'wind': {'speed': 9.24, 'deg': 179, 'gust': 9.78},
#   'clouds': {'all': 82},
#   'dt': 1632683867,
#   'sys': {'type': 1,
#    'id': 8521,
#    'country': 'EC',
#    'sunrise': 1632656952,
#    'sunset': 1632700560},
#   'timezone': -21600,
#   'id': 3652764,
#   'name': 'Puerto Ayora',
#   'cod': 200},
#  {'coord': {'lon': 86.1469, 'lat': 41.7597},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 63.66,
#    'feels_like': 60.94,
#    'temp_min': 63.66,
#    'temp_max': 63.66,
#    'pressure': 1011,
#    'humidity': 26,
#    'sea_level': 1011,
#    'grnd_level': 906},
#   'visibility': 10000,
#   'wind': {'speed': 3.49, 'deg': 228, 'gust': 4.97},
#   'clouds': {'all': 0},
#   'dt': 1632683950,
#   'sys': {'country': 'CN', 'sunrise': 1632701264, 'sunset': 1632744307},
#   'timezone': 28800,
#   'id': 1529376,
#   'name': 'Korla',
#   'cod': 200},
#  {'coord': {'lon': -134.9692, 'lat': -23.1203},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 73.54,
#    'feels_like': 74.12,
#    'temp_min': 73.54,
#    'temp_max': 73.54,
#    'pressure': 1026,
#    'humidity': 75,
#    'sea_level': 1026,
#    'grnd_level': 1023},
#   'visibility': 10000,
#   'wind': {'speed': 18.63, 'deg': 90, 'gust': 20.51},
#   'clouds': {'all': 6},
#   'dt': 1632683864,
#   'sys': {'country': 'PF', 'sunrise': 1632667495, 'sunset': 1632711428},
#   'timezone': -32400,
#   'id': 4030556,
#   'name': 'Rikitea',
#   'cod': 200},
#  {'coord': {'lon': 87.9833, 'lat': 65.8167},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 34.14,
#    'feels_like': 29.28,
#    'temp_min': 34.14,
#    'temp_max': 34.14,
#    'pressure': 1035,
#    'humidity': 84,
#    'sea_level': 1035,
#    'grnd_level': 1029},
#   'visibility': 10000,
#   'wind': {'speed': 5.37, 'deg': 34, 'gust': 5.26},
#   'clouds': {'all': 32},
#   'dt': 1632683951,
#   'sys': {'country': 'RU', 'sunrise': 1632701121, 'sunset': 1632743569},
#   'timezone': 25200,
#   'id': 1488903,
#   'name': 'Turukhansk',
#   'cod': 200},
#  {'coord': {'lon': 10.7002, 'lat': 46.6166},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 60.33,
#    'feels_like': 60.62,
#    'temp_min': 56.66,
#    'temp_max': 62.02,
#    'pressure': 1020,
#    'humidity': 97,
#    'sea_level': 1020,
#    'grnd_level': 922},
#   'visibility': 3592,
#   'wind': {'speed': 2.24, 'deg': 175, 'gust': 2.89},
#   'rain': {'1h': 0.29},
#   'clouds': {'all': 100},
#   'dt': 1632683951,
#   'sys': {'type': 1,
#    'id': 6813,
#    'country': 'IT',
#    'sunrise': 1632632951,
#    'sunset': 1632676068},
#   'timezone': 7200,
#   'id': 3175096,
#   'name': 'Laas',
#   'cod': 200},
#  {'coord': {'lon': 31.1099, 'lat': 48.1706},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 54.97,
#    'feels_like': 53.08,
#    'temp_min': 54.97,
#    'temp_max': 54.97,
#    'pressure': 1020,
#    'humidity': 62,
#    'sea_level': 1020,
#    'grnd_level': 1008},
#   'visibility': 10000,
#   'wind': {'speed': 8.05, 'deg': 353, 'gust': 19.73},
#   'clouds': {'all': 31},
#   'dt': 1632683951,
#   'sys': {'country': 'UA', 'sunrise': 1632628058, 'sunset': 1632671167},
#   'timezone': 10800,
#   'id': 702507,
#   'name': 'Lysa Hora',
#   'cod': 200},
#  {'coord': {'lon': 123.0595, 'lat': 0.5412},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 74.16,
#    'feels_like': 75.22,
#    'temp_min': 74.16,
#    'temp_max': 74.16,
#    'pressure': 1009,
#    'humidity': 84,
#    'sea_level': 1009,
#    'grnd_level': 1008},
#   'visibility': 10000,
#   'wind': {'speed': 2.01, 'deg': 43, 'gust': 2.42},
#   'clouds': {'all': 100},
#   'dt': 1632683951,
#   'sys': {'country': 'ID', 'sunrise': 1632692133, 'sunset': 1632735724},
#   'timezone': 28800,
#   'id': 1643837,
#   'name': 'Gorontalo',
#   'cod': 200},
#  {'coord': {'lon': -91.2068, 'lat': 29.6994},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 82.13,
#    'feels_like': 83.55,
#    'temp_min': 80.01,
#    'temp_max': 84.99,
#    'pressure': 1019,
#    'humidity': 54},
#   'visibility': 10000,
#   'wind': {'speed': 8.05, 'deg': 90},
#   'clouds': {'all': 1},
#   'dt': 1632683952,
#   'sys': {'type': 1,
#    'id': 5422,
#    'country': 'US',
#    'sunrise': 1632657326,
#    'sunset': 1632700597},
#   'timezone': -18000,
#   'id': 4333811,
#   'name': 'Morgan City',
#   'cod': 200},
#  {'coord': {'lon': 147.9167, 'lat': 70.6333},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 28.58,
#    'feels_like': 16.86,
#    'temp_min': 28.58,
#    'temp_max': 28.58,
#    'pressure': 1012,
#    'humidity': 85,
#    'sea_level': 1012,
#    'grnd_level': 1008},
#   'visibility': 10000,
#   'wind': {'speed': 15.9, 'deg': 351, 'gust': 23.87},
#   'clouds': {'all': 100},
#   'dt': 1632683952,
#   'sys': {'country': 'RU', 'sunrise': 1632686821, 'sunset': 1632729108},
#   'timezone': 39600,
#   'id': 2126123,
#   'name': 'Chokurdakh',
#   'cod': 200},
#  {'coord': {'lon': -73.414, 'lat': 41.3712},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 69.15,
#    'feels_like': 68.36,
#    'temp_min': 65.88,
#    'temp_max': 72.36,
#    'pressure': 1010,
#    'humidity': 55},
#   'visibility': 10000,
#   'wind': {'speed': 8.05, 'deg': 300},
#   'clouds': {'all': 20},
#   'dt': 1632683952,
#   'sys': {'type': 2,
#    'id': 2004826,
#    'country': 'US',
#    'sunrise': 1632653122,
#    'sunset': 1632696262},
#   'timezone': -14400,
#   'id': 5282297,
#   'name': 'Bethel',
#   'cod': 200},
#  {'coord': {'lon': 178.4167, 'lat': 69.3833},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 22.24,
#    'feels_like': 12.45,
#    'temp_min': 22.24,
#    'temp_max': 22.24,
#    'pressure': 1008,
#    'humidity': 80,
#    'sea_level': 1008,
#    'grnd_level': 1007},
#   'visibility': 10000,
#   'wind': {'speed': 8.72, 'deg': 205, 'gust': 9.24},
#   'clouds': {'all': 94},
#   'dt': 1632683953,
#   'sys': {'country': 'RU', 'sunrise': 1632679447, 'sunset': 1632721845},
#   'timezone': 43200,
#   'id': 2123814,
#   'name': 'Leningradskiy',
#   'cod': 200},
#  {'coord': {'lon': 147.0587, 'lat': -42.7826},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 38.75,
#    'feels_like': 38.75,
#    'temp_min': 35.92,
#    'temp_max': 38.91,
#    'pressure': 1021,
#    'humidity': 75},
#   'visibility': 10000,
#   'wind': {'speed': 2.95, 'deg': 298, 'gust': 2.91},
#   'clouds': {'all': 13},
#   'dt': 1632683860,
#   'sys': {'type': 2,
#    'id': 2031307,
#    'country': 'AU',
#    'sunrise': 1632685954,
#    'sunset': 1632730386},
#   'timezone': 36000,
#   'id': 2155415,
#   'name': 'New Norfolk',
#   'cod': 200},
#  {'coord': {'lon': 26.891, 'lat': -33.5906},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 64.89,
#    'feels_like': 65.35,
#    'temp_min': 64.89,
#    'temp_max': 64.89,
#    'pressure': 1016,
#    'humidity': 91,
#    'sea_level': 1016,
#    'grnd_level': 1014},
#   'visibility': 10000,
#   'wind': {'speed': 17.22, 'deg': 85, 'gust': 27.38},
#   'clouds': {'all': 26},
#   'dt': 1632683863,
#   'sys': {'country': 'ZA', 'sunrise': 1632628580, 'sunset': 1632672670},
#   'timezone': 7200,
#   'id': 964432,
#   'name': 'Port Alfred',
#   'cod': 200},
#  {'coord': {'lon': -13.6773, 'lat': 9.538},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 78.87,
#    'feels_like': 78.87,
#    'temp_min': 74.35,
#    'temp_max': 78.87,
#    'pressure': 1010,
#    'humidity': 83},
#   'visibility': 10000,
#   'wind': {'speed': 6.91, 'deg': 340},
#   'rain': {'1h': 0.11},
#   'clouds': {'all': 75},
#   'dt': 1632683953,
#   'sys': {'type': 1,
#    'id': 2451,
#    'country': 'GN',
#    'sunrise': 1632638610,
#    'sunset': 1632682107},
#   'timezone': 0,
#   'id': 2422465,
#   'name': 'Conakry',
#   'cod': 200},
#  {'coord': {'lon': 172.7902, 'lat': 3.0707},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 83.7,
#    'feels_like': 90.77,
#    'temp_min': 83.7,
#    'temp_max': 83.7,
#    'pressure': 1008,
#    'humidity': 73,
#    'sea_level': 1008,
#    'grnd_level': 1007},
#   'visibility': 10000,
#   'wind': {'speed': 16.24, 'deg': 105, 'gust': 17.27},
#   'clouds': {'all': 100},
#   'dt': 1632683863,
#   'sys': {'country': 'KI', 'sunrise': 1632680216, 'sunset': 1632723776},
#   'timezone': 43200,
#   'id': 2110227,
#   'name': 'Butaritari',
#   'cod': 200},
#  {'coord': {'lon': 18.4232, 'lat': -33.9258},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 61.65,
#    'feels_like': 60.94,
#    'temp_min': 60.35,
#    'temp_max': 62.28,
#    'pressure': 1015,
#    'humidity': 73},
#   'visibility': 10000,
#   'wind': {'speed': 1.99, 'deg': 0, 'gust': 3},
#   'clouds': {'all': 26},
#   'dt': 1632683653,
#   'sys': {'type': 2,
#    'id': 2033665,
#    'country': 'ZA',
#    'sunrise': 1632630606,
#    'sunset': 1632674706},
#   'timezone': 7200,
#   'id': 3369157,
#   'name': 'Cape Town',
#   'cod': 200},
#  {'coord': {'lon': -120.4579, 'lat': 34.6391},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 60.75,
#    'feels_like': 60.51,
#    'temp_min': 59.72,
#    'temp_max': 62.91,
#    'pressure': 1018,
#    'humidity': 85},
#   'visibility': 10000,
#   'wind': {'speed': 4.61, 'deg': 300},
#   'clouds': {'all': 90},
#   'dt': 1632683953,
#   'sys': {'type': 1,
#    'id': 4747,
#    'country': 'US',
#    'sunrise': 1632664378,
#    'sunset': 1632707582},
#   'timezone': -25200,
#   'id': 5367788,
#   'name': 'Lompoc',
#   'cod': 200},
#  {'coord': {'lon': -52.7314, 'lat': 47.6666},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 62.15,
#    'feels_like': 60.98,
#    'temp_min': 59.29,
#    'temp_max': 63.37,
#    'pressure': 1020,
#    'humidity': 62},
#   'visibility': 10000,
#   'wind': {'speed': 13.8, 'deg': 260},
#   'clouds': {'all': 90},
#   'dt': 1632683954,
#   'sys': {'type': 1,
#    'id': 998,
#    'country': 'CA',
#    'sunrise': 1632648196,
#    'sunset': 1632691263},
#   'timezone': -9000,
#   'id': 6167817,
#   'name': 'Torbay',
#   'cod': 200},
#  {'coord': {'lon': 179.3167, 'lat': 63.05},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 36.7,
#    'feels_like': 33.04,
#    'temp_min': 36.7,
#    'temp_max': 36.7,
#    'pressure': 1013,
#    'humidity': 65,
#    'sea_level': 1013,
#    'grnd_level': 1011},
#   'visibility': 10000,
#   'wind': {'speed': 4.47, 'deg': 247, 'gust': 4.92},
#   'clouds': {'all': 99},
#   'dt': 1632683954,
#   'sys': {'country': 'RU', 'sunrise': 1632679106, 'sunset': 1632721755},
#   'timezone': 43200,
#   'id': 2126710,
#   'name': 'Beringovskiy',
#   'cod': 200},
#  {'coord': {'lon': -68.5914, 'lat': 70.4692},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 29.86,
#    'feels_like': 23.05,
#    'temp_min': 29.86,
#    'temp_max': 29.86,
#    'pressure': 1025,
#    'humidity': 80,
#    'sea_level': 1025,
#    'grnd_level': 1025},
#   'visibility': 10000,
#   'wind': {'speed': 6.8, 'deg': 159, 'gust': 8.39},
#   'clouds': {'all': 18},
#   'dt': 1632683854,
#   'sys': {'country': 'CA', 'sunrise': 1632652281, 'sunset': 1632694788},
#   'timezone': -14400,
#   'id': 5924351,
#   'name': 'Clyde River',
#   'cod': 200},
#  {'coord': {'lon': -53.4616, 'lat': -33.6971},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 67.62,
#    'feels_like': 67.23,
#    'temp_min': 67.62,
#    'temp_max': 67.62,
#    'pressure': 1017,
#    'humidity': 67,
#    'sea_level': 1017,
#    'grnd_level': 1014},
#   'visibility': 10000,
#   'wind': {'speed': 5.53, 'deg': 79, 'gust': 5.59},
#   'clouds': {'all': 0},
#   'dt': 1632683954,
#   'sys': {'country': 'UY', 'sunrise': 1632647845, 'sunset': 1632691965},
#   'timezone': -10800,
#   'id': 3443061,
#   'name': 'Chui',
#   'cod': 200},
#  {'coord': {'lon': -175.2, 'lat': -21.2},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 69.96,
#    'feels_like': 70.79,
#    'temp_min': 69.96,
#    'temp_max': 69.96,
#    'pressure': 1015,
#    'humidity': 88},
#   'visibility': 10000,
#   'wind': {'speed': 2.3, 'deg': 0},
#   'clouds': {'all': 75},
#   'dt': 1632683868,
#   'sys': {'type': 1,
#    'id': 7285,
#    'country': 'TO',
#    'sunrise': 1632763503,
#    'sunset': 1632807484},
#   'timezone': 46800,
#   'id': 4032243,
#   'name': 'Vaini',
#   'cod': 200},
#  {'coord': {'lon': -114.3525, 'lat': 62.456},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 41.13,
#    'feels_like': 38.62,
#    'temp_min': 39.56,
#    'temp_max': 43.41,
#    'pressure': 1008,
#    'humidity': 83},
#   'visibility': 10000,
#   'wind': {'speed': 4, 'deg': 293, 'gust': 5.01},
#   'clouds': {'all': 75},
#   'dt': 1632683837,
#   'sys': {'type': 2,
#    'id': 2041581,
#    'country': 'CA',
#    'sunrise': 1632663148,
#    'sunset': 1632705882},
#   'timezone': -21600,
#   'id': 6185377,
#   'name': 'Yellowknife',
#   'cod': 200},
#  {'coord': {'lon': -37.6368, 'lat': 65.6145},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 37.56,
#    'feels_like': 37.56,
#    'temp_min': 37.56,
#    'temp_max': 37.56,
#    'pressure': 1014,
#    'humidity': 69,
#    'sea_level': 1014,
#    'grnd_level': 1009},
#   'visibility': 10000,
#   'wind': {'speed': 2.68, 'deg': 13, 'gust': 2.93},
#   'clouds': {'all': 33},
#   'dt': 1632683955,
#   'sys': {'type': 1,
#    'id': 81,
#    'country': 'GL',
#    'sunrise': 1632644745,
#    'sunset': 1632687470},
#   'timezone': -7200,
#   'id': 3424607,
#   'name': 'Tasiilaq',
#   'cod': 200},
#  {'coord': {'lon': -159.775, 'lat': -21.2078},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 77.05,
#    'feels_like': 77.7,
#    'temp_min': 77.05,
#    'temp_max': 77.05,
#    'pressure': 1015,
#    'humidity': 69},
#   'visibility': 10000,
#   'wind': {'speed': 2.3, 'deg': 180},
#   'clouds': {'all': 90},
#   'dt': 1632683814,
#   'sys': {'type': 1,
#    'id': 7271,
#    'country': 'CK',
#    'sunrise': 1632673461,
#    'sunset': 1632717366},
#   'timezone': -36000,
#   'id': 4035715,
#   'name': 'Avarua',
#   'cod': 200},
#  {'coord': {'lon': -134.4197, 'lat': 58.3019},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 49.96,
#    'feels_like': 49.24,
#    'temp_min': 46.4,
#    'temp_max': 52.84,
#    'pressure': 997,
#    'humidity': 83},
#   'visibility': 10000,
#   'wind': {'speed': 3.44, 'deg': 280},
#   'clouds': {'all': 75},
#   'dt': 1632683955,
#   'sys': {'type': 2,
#    'id': 2012911,
#    'country': 'US',
#    'sunrise': 1632667920,
#    'sunset': 1632710740},
#   'timezone': -28800,
#   'id': 5554072,
#   'name': 'Juneau',
#   'cod': 200},
#  {'coord': {'lon': -89.6667, 'lat': 21.2833},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 94.1,
#    'feels_like': 106.7,
#    'temp_min': 93.31,
#    'temp_max': 94.1,
#    'pressure': 1014,
#    'humidity': 59,
#    'sea_level': 1014,
#    'grnd_level': 1014},
#   'visibility': 10000,
#   'wind': {'speed': 12.46, 'deg': 25, 'gust': 11.21},
#   'clouds': {'all': 8},
#   'dt': 1632683955,
#   'sys': {'type': 2,
#    'id': 2007869,
#    'country': 'MX',
#    'sunrise': 1632656910,
#    'sunset': 1632700273},
#   'timezone': -18000,
#   'id': 3521108,
#   'name': 'Progreso',
#   'cod': 200},
#  {'coord': {'lon': -67.5, 'lat': -45.8667},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 55.26,
#    'feels_like': 51.6,
#    'temp_min': 55.26,
#    'temp_max': 55.26,
#    'pressure': 1017,
#    'humidity': 24},
#   'visibility': 10000,
#   'wind': {'speed': 13.8, 'deg': 230},
#   'clouds': {'all': 0},
#   'dt': 1632683701,
#   'sys': {'type': 1,
#    'id': 8284,
#    'country': 'AR',
#    'sunrise': 1632651042,
#    'sunset': 1632695504},
#   'timezone': -10800,
#   'id': 3860443,
#   'name': 'Comodoro Rivadavia',
#   'cod': 200},
#  {'coord': {'lon': 31.1107, 'lat': 70.3705},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 48.18,
#    'feels_like': 42.33,
#    'temp_min': 46.15,
#    'temp_max': 48.4,
#    'pressure': 1014,
#    'humidity': 76},
#   'visibility': 10000,
#   'wind': {'speed': 14.97, 'deg': 200},
#   'rain': {'1h': 0.93},
#   'clouds': {'all': 75},
#   'dt': 1632683956,
#   'sys': {'type': 1,
#    'id': 1666,
#    'country': 'NO',
#    'sunrise': 1632628284,
#    'sunset': 1632670940},
#   'timezone': 7200,
#   'id': 777019,
#   'name': 'Vardø',
#   'cod': 200},
#  {'coord': {'lon': 40.2278, 'lat': 40.2589},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 50.65,
#    'feels_like': 47.95,
#    'temp_min': 50.65,
#    'temp_max': 50.65,
#    'pressure': 1020,
#    'humidity': 54,
#    'sea_level': 1020,
#    'grnd_level': 846},
#   'visibility': 10000,
#   'wind': {'speed': 1.03, 'deg': 17, 'gust': 1.07},
#   'clouds': {'all': 0},
#   'dt': 1632683782,
#   'sys': {'country': 'TR', 'sunrise': 1632625823, 'sunset': 1632669027},
#   'timezone': 10800,
#   'id': 750938,
#   'name': 'Bayburt',
#   'cod': 200},
#  {'coord': {'lon': 142.15, 'lat': -34.2},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 44.56,
#    'feels_like': 41.34,
#    'temp_min': 44.56,
#    'temp_max': 44.56,
#    'pressure': 1019,
#    'humidity': 61},
#   'visibility': 10000,
#   'wind': {'speed': 5.75, 'deg': 120},
#   'clouds': {'all': 49},
#   'dt': 1632683956,
#   'sys': {'type': 1,
#    'id': 9550,
#    'country': 'AU',
#    'sunrise': 1632687253,
#    'sunset': 1632731443},
#   'timezone': 36000,
#   'id': 2157698,
#   'name': 'Mildura',
#   'cod': 200},
#  {'coord': {'lon': 100.3543, 'lat': -0.9492},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 76.14,
#    'feels_like': 77.92,
#    'temp_min': 76.14,
#    'temp_max': 76.14,
#    'pressure': 1009,
#    'humidity': 95,
#    'sea_level': 1009,
#    'grnd_level': 1008},
#   'visibility': 10000,
#   'wind': {'speed': 2.26, 'deg': 311, 'gust': 2.84},
#   'clouds': {'all': 100},
#   'dt': 1632683941,
#   'sys': {'country': 'ID', 'sunrise': 1632697571, 'sunset': 1632741182},
#   'timezone': 25200,
#   'id': 1633419,
#   'name': 'Padang',
#   'cod': 200},
#  {'coord': {'lon': 19.2345, 'lat': -34.4187},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 59.81,
#    'feels_like': 59.72,
#    'temp_min': 59.81,
#    'temp_max': 60.91,
#    'pressure': 1014,
#    'humidity': 90,
#    'sea_level': 1014,
#    'grnd_level': 1010},
#   'visibility': 10000,
#   'wind': {'speed': 8.97, 'deg': 129, 'gust': 10},
#   'clouds': {'all': 1},
#   'dt': 1632683957,
#   'sys': {'type': 2,
#    'id': 2006131,
#    'country': 'ZA',
#    'sunrise': 1632630407,
#    'sunset': 1632674517},
#   'timezone': 7200,
#   'id': 3366880,
#   'name': 'Hermanus',
#   'cod': 200},
#  {'coord': {'lon': -99.8901, 'lat': 16.8634},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 85.98,
#    'feels_like': 94.17,
#    'temp_min': 85.98,
#    'temp_max': 85.98,
#    'pressure': 1012,
#    'humidity': 68,
#    'sea_level': 1012,
#    'grnd_level': 1010},
#   'visibility': 10000,
#   'wind': {'speed': 6.04, 'deg': 233, 'gust': 6.26},
#   'clouds': {'all': 99},
#   'dt': 1632684090,
#   'sys': {'country': 'MX', 'sunrise': 1632659340, 'sunset': 1632702749},
#   'timezone': -18000,
#   'id': 3533462,
#   'name': 'Acapulco de Juárez',
#   'cod': 200},
#  {'coord': {'lon': -106.9667, 'lat': 26.1},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 69.04,
#    'feels_like': 68.14,
#    'temp_min': 69.04,
#    'temp_max': 69.04,
#    'pressure': 1016,
#    'humidity': 53,
#    'sea_level': 1016,
#    'grnd_level': 779},
#   'visibility': 10000,
#   'wind': {'speed': 7.81, 'deg': 258, 'gust': 5.21},
#   'clouds': {'all': 2},
#   'dt': 1632684091,
#   'sys': {'country': 'MX', 'sunrise': 1632661089, 'sunset': 1632704396},
#   'timezone': -21600,
#   'id': 4005370,
#   'name': 'Guadalupe y Calvo',
#   'cod': 200},
#  {'coord': {'lon': 128.9203, 'lat': 61.4681},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 30.63,
#    'feels_like': 24.62,
#    'temp_min': 30.63,
#    'temp_max': 30.63,
#    'pressure': 1019,
#    'humidity': 93,
#    'sea_level': 1019,
#    'grnd_level': 997},
#   'visibility': 10000,
#   'wind': {'speed': 5.97, 'deg': 65, 'gust': 18.92},
#   'clouds': {'all': 100},
#   'dt': 1632684091,
#   'sys': {'country': 'RU', 'sunrise': 1632691198, 'sunset': 1632733847},
#   'timezone': 32400,
#   'id': 2019867,
#   'name': 'Mokhsogollokh',
#   'cod': 200},
#  {'coord': {'lon': -56.1549, 'lat': 72.7868},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 25.41,
#    'feels_like': 25.41,
#    'temp_min': 25.41,
#    'temp_max': 25.41,
#    'pressure': 1023,
#    'humidity': 64,
#    'sea_level': 1023,
#    'grnd_level': 1023},
#   'visibility': 10000,
#   'wind': {'speed': 2.55, 'deg': 90, 'gust': 1.83},
#   'clouds': {'all': 0},
#   'dt': 1632684091,
#   'sys': {'country': 'GL', 'sunrise': 1632649346, 'sunset': 1632691755},
#   'timezone': -7200,
#   'id': 3418910,
#   'name': 'Upernavik',
#   'cod': 200},
#  {'coord': {'lon': -71.3436, 'lat': -29.9533},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 64.13,
#    'feels_like': 63.39,
#    'temp_min': 64.13,
#    'temp_max': 64.13,
#    'pressure': 1015,
#    'humidity': 67},
#   'visibility': 10000,
#   'wind': {'speed': 16.11, 'deg': 280},
#   'clouds': {'all': 0},
#   'dt': 1632684092,
#   'sys': {'type': 1,
#    'id': 8514,
#    'country': 'CL',
#    'sunrise': 1632652172,
#    'sunset': 1632696218},
#   'timezone': -10800,
#   'id': 3893629,
#   'name': 'Coquimbo',
#   'cod': 200},
#  {'coord': {'lon': 108.0108, 'lat': 61.2767},
#   'weather': [{'id': 601,
#     'main': 'Snow',
#     'description': 'snow',
#     'icon': '13n'}],
#   'base': 'stations',
#   'main': {'temp': 32.54,
#    'feels_like': 22.93,
#    'temp_min': 32.54,
#    'temp_max': 32.54,
#    'pressure': 1016,
#    'humidity': 95,
#    'sea_level': 1016,
#    'grnd_level': 981},
#   'visibility': 201,
#   'wind': {'speed': 13.29, 'deg': 33, 'gust': 31.18},
#   'snow': {'1h': 0.69},
#   'clouds': {'all': 100},
#   'dt': 1632684092,
#   'sys': {'country': 'RU', 'sunrise': 1632696222, 'sunset': 1632738857},
#   'timezone': 28800,
#   'id': 2012956,
#   'name': 'Yerbogachën',
#   'cod': 200},
#  {'coord': {'lon': 21.5482, 'lat': 29.0331},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 77.68,
#    'feels_like': 76.66,
#    'temp_min': 77.68,
#    'temp_max': 77.68,
#    'pressure': 1017,
#    'humidity': 32,
#    'sea_level': 1017,
#    'grnd_level': 1012},
#   'visibility': 10000,
#   'wind': {'speed': 5.64, 'deg': 5, 'gust': 5.97},
#   'clouds': {'all': 0},
#   'dt': 1632684092,
#   'sys': {'country': 'LY', 'sunrise': 1632630251, 'sunset': 1632673562},
#   'timezone': 7200,
#   'id': 86049,
#   'name': 'Jalu',
#   'cod': 200},
#  {'coord': {'lon': 115.3333, 'lat': -33.65},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 57.04,
#    'feels_like': 56.68,
#    'temp_min': 55.09,
#    'temp_max': 57.04,
#    'pressure': 1010,
#    'humidity': 90,
#    'sea_level': 1010,
#    'grnd_level': 1010},
#   'visibility': 10000,
#   'wind': {'speed': 14.36, 'deg': 184, 'gust': 25.72},
#   'clouds': {'all': 76},
#   'dt': 1632683862,
#   'sys': {'type': 2,
#    'id': 2020551,
#    'country': 'AU',
#    'sunrise': 1632693690,
#    'sunset': 1632737875},
#   'timezone': 28800,
#   'id': 2075265,
#   'name': 'Busselton',
#   'cod': 200},
#  {'coord': {'lon': -71.535, 'lat': -16.3989},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 75.27,
#    'feels_like': 73.06,
#    'temp_min': 75.27,
#    'temp_max': 75.27,
#    'pressure': 1025,
#    'humidity': 12},
#   'visibility': 10000,
#   'wind': {'speed': 11.5, 'deg': 270},
#   'clouds': {'all': 0},
#   'dt': 1632684093,
#   'sys': {'type': 1,
#    'id': 8696,
#    'country': 'PE',
#    'sunrise': 1632652335,
#    'sunset': 1632696148},
#   'timezone': -18000,
#   'id': 3947322,
#   'name': 'Arequipa',
#   'cod': 200},
#  {'coord': {'lon': 121.6247, 'lat': 63.7553},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 30.81,
#    'feels_like': 24.06,
#    'temp_min': 30.81,
#    'temp_max': 30.81,
#    'pressure': 1021,
#    'humidity': 82,
#    'sea_level': 1021,
#    'grnd_level': 1008},
#   'visibility': 10000,
#   'wind': {'speed': 7, 'deg': 40, 'gust': 18.86},
#   'clouds': {'all': 100},
#   'dt': 1632684093,
#   'sys': {'country': 'RU', 'sunrise': 1632692990, 'sunset': 1632735556},
#   'timezone': 32400,
#   'id': 2013392,
#   'name': 'Vilyuysk',
#   'cod': 200},
#  {'coord': {'lon': 173.1667, 'lat': -35.1667},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 50.94,
#    'feels_like': 49.62,
#    'temp_min': 50.94,
#    'temp_max': 50.94,
#    'pressure': 1015,
#    'humidity': 83,
#    'sea_level': 1015,
#    'grnd_level': 1013},
#   'visibility': 10000,
#   'wind': {'speed': 7.29, 'deg': 147, 'gust': 11.12},
#   'clouds': {'all': 99},
#   'dt': 1632684093,
#   'sys': {'country': 'NZ', 'sunrise': 1632679805, 'sunset': 1632724007},
#   'timezone': 46800,
#   'id': 2194098,
#   'name': 'Ahipara',
#   'cod': 200},
#  {'coord': {'lon': -152.4072, 'lat': 57.79},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 47.71,
#    'feels_like': 42.71,
#    'temp_min': 47.71,
#    'temp_max': 47.71,
#    'pressure': 1007,
#    'humidity': 61},
#   'visibility': 10000,
#   'wind': {'speed': 11.5, 'deg': 310, 'gust': 18.41},
#   'clouds': {'all': 1},
#   'dt': 1632684094,
#   'sys': {'type': 1,
#    'id': 7668,
#    'country': 'US',
#    'sunrise': 1632672237,
#    'sunset': 1632715054},
#   'timezone': -28800,
#   'id': 5866583,
#   'name': 'Saint Paul Harbor',
#   'cod': 200},
#  {'coord': {'lon': 130.9889, 'lat': -25.2406},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 67.84,
#    'feels_like': 65.3,
#    'temp_min': 67.84,
#    'temp_max': 67.84,
#    'pressure': 1010,
#    'humidity': 21},
#   'visibility': 10000,
#   'wind': {'speed': 0, 'deg': 0},
#   'clouds': {'all': 27},
#   'dt': 1632684094,
#   'sys': {'type': 1,
#    'id': 9487,
#    'country': 'AU',
#    'sunrise': 1632690028,
#    'sunset': 1632734024},
#   'timezone': 34200,
#   'id': 6355222,
#   'name': 'Yulara',
#   'cod': 200},
#  {'coord': {'lon': -46.05, 'lat': 60.9167},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 44.82,
#    'feels_like': 44.82,
#    'temp_min': 44.82,
#    'temp_max': 44.82,
#    'pressure': 1017,
#    'humidity': 46,
#    'sea_level': 1017,
#    'grnd_level': 1014},
#   'visibility': 10000,
#   'wind': {'speed': 2.26, 'deg': 338, 'gust': 2.64},
#   'clouds': {'all': 0},
#   'dt': 1632683864,
#   'sys': {'type': 1,
#    'id': 47,
#    'country': 'GL',
#    'sunrise': 1632646707,
#    'sunset': 1632689545},
#   'timezone': -7200,
#   'id': 3421719,
#   'name': 'Narsaq',
#   'cod': 200},
#  {'coord': {'lon': 57.7575, 'lat': -20.3428},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 70.05,
#    'feels_like': 71.17,
#    'temp_min': 70.05,
#    'temp_max': 70.21,
#    'pressure': 1022,
#    'humidity': 94},
#   'visibility': 8000,
#   'wind': {'speed': 12.66, 'deg': 100},
#   'rain': {'1h': 0.52},
#   'clouds': {'all': 75},
#   'dt': 1632684075,
#   'sys': {'type': 1,
#    'id': 2061,
#    'country': 'MU',
#    'sunrise': 1632621294,
#    'sunset': 1632665143},
#   'timezone': 14400,
#   'id': 1106677,
#   'name': 'Bambous Virieux',
#   'cod': 200},
#  {'coord': {'lon': 40.6678, 'lat': 55.25},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 48.18,
#    'feels_like': 43.83,
#    'temp_min': 48.18,
#    'temp_max': 48.18,
#    'pressure': 1010,
#    'humidity': 95,
#    'sea_level': 1010,
#    'grnd_level': 995},
#   'visibility': 10000,
#   'wind': {'speed': 9.89, 'deg': 22, 'gust': 21.63},
#   'clouds': {'all': 100},
#   'dt': 1632684094,
#   'sys': {'country': 'RU', 'sunrise': 1632625811, 'sunset': 1632668828},
#   'timezone': 10800,
#   'id': 476055,
#   'name': 'Velikodvorskiy',
#   'cod': 200},
#  {'coord': {'lon': -73.9662, 'lat': 42.6001},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 66.42,
#    'feels_like': 65.01,
#    'temp_min': 62.37,
#    'temp_max': 69.39,
#    'pressure': 1009,
#    'humidity': 48},
#   'visibility': 10000,
#   'wind': {'speed': 1.99, 'deg': 10, 'gust': 8.01},
#   'clouds': {'all': 6},
#   'dt': 1632684095,
#   'sys': {'type': 2,
#    'id': 19530,
#    'country': 'US',
#    'sunrise': 1632653262,
#    'sunset': 1632696386},
#   'timezone': -14400,
#   'id': 5106841,
#   'name': 'Albany',
#   'cod': 200},
#  {'coord': {'lon': -66.3821, 'lat': 50.2001},
#   'weather': [{'id': 741, 'main': 'Fog', 'description': 'fog', 'icon': '50d'}],
#   'base': 'stations',
#   'main': {'temp': 57.49,
#    'feels_like': 57.54,
#    'temp_min': 57.06,
#    'temp_max': 58.24,
#    'pressure': 1003,
#    'humidity': 98},
#   'visibility': 402,
#   'wind': {'speed': 13, 'deg': 140, 'gust': 25.99},
#   'clouds': {'all': 90},
#   'dt': 1632684046,
#   'sys': {'type': 2,
#    'id': 2006302,
#    'country': 'CA',
#    'sunrise': 1632651494,
#    'sunset': 1632694515},
#   'timezone': -14400,
#   'id': 6144312,
#   'name': 'Sept-Îles',
#   'cod': 200},
#  {'coord': {'lon': -165.4064, 'lat': 64.5011},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 35.67,
#    'feels_like': 28.67,
#    'temp_min': 35.11,
#    'temp_max': 35.67,
#    'pressure': 1010,
#    'humidity': 75},
#   'visibility': 10000,
#   'wind': {'speed': 9.22, 'deg': 300},
#   'clouds': {'all': 75},
#   'dt': 1632683867,
#   'sys': {'type': 1,
#    'id': 7770,
#    'country': 'US',
#    'sunrise': 1632675456,
#    'sunset': 1632718074},
#   'timezone': -28800,
#   'id': 5870133,
#   'name': 'Nome',
#   'cod': 200},
#  {'coord': {'lon': -5.0242, 'lat': 5.1367},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 74.3,
#    'feels_like': 75.79,
#    'temp_min': 74.3,
#    'temp_max': 74.3,
#    'pressure': 1013,
#    'humidity': 93,
#    'sea_level': 1013,
#    'grnd_level': 1013},
#   'visibility': 10000,
#   'wind': {'speed': 5.91, 'deg': 242, 'gust': 8.95},
#   'clouds': {'all': 100},
#   'dt': 1632684095,
#   'sys': {'country': 'CI', 'sunrise': 1632636511, 'sunset': 1632680054},
#   'timezone': 0,
#   'id': 2288105,
#   'name': 'Grand-Lahou',
#   'cod': 200},
#  {'coord': {'lon': 37.9549, 'lat': 36.5281},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 66.97,
#    'feels_like': 64.45,
#    'temp_min': 66.97,
#    'temp_max': 66.97,
#    'pressure': 1013,
#    'humidity': 23,
#    'sea_level': 1013,
#    'grnd_level': 960},
#   'visibility': 10000,
#   'wind': {'speed': 7.56, 'deg': 246, 'gust': 7.65},
#   'clouds': {'all': 0},
#   'dt': 1632684095,
#   'sys': {'type': 1,
#    'id': 6952,
#    'country': 'SY',
#    'sunrise': 1632626349,
#    'sunset': 1632669591},
#   'timezone': 10800,
#   'id': 167357,
#   'name': 'Manbij',
#   'cod': 200},
#  {'coord': {'lon': 140.0242, 'lat': 40.2039},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 57.83,
#    'feels_like': 57.25,
#    'temp_min': 57.83,
#    'temp_max': 57.83,
#    'pressure': 1020,
#    'humidity': 84,
#    'sea_level': 1020,
#    'grnd_level': 1018},
#   'visibility': 10000,
#   'wind': {'speed': 6.24, 'deg': 92, 'gust': 7.58},
#   'clouds': {'all': 23},
#   'dt': 1632684096,
#   'sys': {'country': 'JP', 'sunrise': 1632688313, 'sunset': 1632731403},
#   'timezone': 32400,
#   'id': 2128867,
#   'name': 'Noshiro',
#   'cod': 200},
#  {'coord': {'lon': 30.7861, 'lat': 59.7035},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 49.64,
#    'feels_like': 47.5,
#    'temp_min': 47.39,
#    'temp_max': 49.89,
#    'pressure': 1023,
#    'humidity': 92,
#    'sea_level': 1023,
#    'grnd_level': 1019},
#   'visibility': 10000,
#   'wind': {'speed': 5.53, 'deg': 345, 'gust': 18.59},
#   'clouds': {'all': 97},
#   'dt': 1632684096,
#   'sys': {'type': 2,
#    'id': 2034996,
#    'country': 'RU',
#    'sunrise': 1632628223,
#    'sunset': 1632671157},
#   'timezone': 10800,
#   'id': 546105,
#   'name': 'Nikolskoye',
#   'cod': 200},
#  {'coord': {'lon': 9.4083, 'lat': 41.2142},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 78.85,
#    'feels_like': 78.85,
#    'temp_min': 75.36,
#    'temp_max': 78.85,
#    'pressure': 1017,
#    'humidity': 86,
#    'sea_level': 1017,
#    'grnd_level': 1017},
#   'visibility': 10000,
#   'wind': {'speed': 10.87, 'deg': 259, 'gust': 14.52},
#   'clouds': {'all': 41},
#   'dt': 1632684096,
#   'sys': {'type': 1,
#    'id': 6728,
#    'country': 'IT',
#    'sunrise': 1632633230,
#    'sunset': 1632676409},
#   'timezone': 7200,
#   'id': 3175217,
#   'name': 'La Maddalena',
#   'cod': 200},
#  {'coord': {'lon': -42.0278, 'lat': -22.9661},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01d'}],
#   'base': 'stations',
#   'main': {'temp': 75.06,
#    'feels_like': 75.69,
#    'temp_min': 75.06,
#    'temp_max': 78.76,
#    'pressure': 1017,
#    'humidity': 73},
#   'visibility': 10000,
#   'wind': {'speed': 18.41, 'deg': 80},
#   'clouds': {'all': 0},
#   'dt': 1632684097,
#   'sys': {'type': 1,
#    'id': 8326,
#    'country': 'BR',
#    'sunrise': 1632645206,
#    'sunset': 1632689116},
#   'timezone': -10800,
#   'id': 3471451,
#   'name': 'Arraial do Cabo',
#   'cod': 200},
#  {'coord': {'lon': 46.6433, 'lat': 41.6336},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 57.67,
#    'feels_like': 55.72,
#    'temp_min': 57.67,
#    'temp_max': 57.67,
#    'pressure': 1023,
#    'humidity': 55},
#   'visibility': 10000,
#   'wind': {'speed': 11.5, 'deg': 110},
#   'clouds': {'all': 2},
#   'dt': 1632684097,
#   'sys': {'type': 1,
#    'id': 8843,
#    'country': 'AZ',
#    'sunrise': 1632624289,
#    'sunset': 1632667481},
#   'timezone': 14400,
#   'id': 584596,
#   'name': 'Zaqatala',
#   'cod': 200},
#  {'coord': {'lon': 28.5833, 'lat': 43.8},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 64.76,
#    'feels_like': 64.56,
#    'temp_min': 61.93,
#    'temp_max': 66.09,
#    'pressure': 1020,
#    'humidity': 77,
#    'sea_level': 1020,
#    'grnd_level': 1020},
#   'visibility': 10000,
#   'wind': {'speed': 8.21, 'deg': 193, 'gust': 12.53},
#   'clouds': {'all': 0},
#   'dt': 1632684097,
#   'sys': {'type': 2,
#    'id': 2035671,
#    'country': 'RO',
#    'sunrise': 1632628639,
#    'sunset': 1632671798},
#   'timezone': 10800,
#   'id': 673921,
#   'name': 'Mangalia',
#   'cod': 200},
#  {'coord': {'lon': 55.7679, 'lat': -21.3585},
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 69.76,
#    'feels_like': 70.57,
#    'temp_min': 68.22,
#    'temp_max': 71.19,
#    'pressure': 1024,
#    'humidity': 88,
#    'sea_level': 1024,
#    'grnd_level': 1017},
#   'visibility': 10000,
#   'wind': {'speed': 13.96, 'deg': 91, 'gust': 15.86},
#   'rain': {'1h': 0.4},
#   'clouds': {'all': 55},
#   'dt': 1632684097,
#   'sys': {'type': 1,
#    'id': 2127,
#    'country': 'RE',
#    'sunrise': 1632621764,
#    'sunset': 1632665628},
#   'timezone': 14400,
#   'id': 935215,
#   'name': 'Saint-Philippe',
#   'cod': 200},
#  {'coord': {'lon': -91.917, 'lat': 50.1001},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 64.47,
#    'feels_like': 62.73,
#    'temp_min': 64.47,
#    'temp_max': 64.78,
#    'pressure': 1005,
#    'humidity': 45},
#   'visibility': 10000,
#   'wind': {'speed': 4.61, 'deg': 290},
#   'clouds': {'all': 40},
#   'dt': 1632684098,
#   'sys': {'type': 1,
#    'id': 979,
#    'country': 'CA',
#    'sunrise': 1632657628,
#    'sunset': 1632700635},
#   'timezone': -18000,
#   'id': 6148373,
#   'name': 'Sioux Lookout',
#   'cod': 200},
#  {'coord': {'lon': -0.2417, 'lat': 11.0616},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 84.2,
#    'feels_like': 87.06,
#    'temp_min': 84.2,
#    'temp_max': 84.2,
#    'pressure': 1010,
#    'humidity': 57,
#    'sea_level': 1010,
#    'grnd_level': 982},
#   'visibility': 10000,
#   'wind': {'speed': 6.13, 'deg': 128, 'gust': 6.42},
#   'clouds': {'all': 81},
#   'dt': 1632684098,
#   'sys': {'country': 'GH', 'sunrise': 1632635394, 'sunset': 1632678876},
#   'timezone': 0,
#   'id': 2303287,
#   'name': 'Bawku',
#   'cod': 200},
#  {'coord': {'lon': 113.6333, 'lat': -24.8667},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
# ...
#    'humidity': 15,
#    'sea_level': 1009,
#    'grnd_level': 961},
#   'visibility': 10000,
#   'wind': {'speed': 4.14, 'deg': 42, 'gust': 4.72},
#   'clouds': {'all': 47},
#   'dt': 1632684696,
#   'sys': {'type': 2,
#    'id': 2021605,
#    'country': 'NE',
#    'sunrise': 1632632885,
#    'sunset': 1632676340},
#   'timezone': 3600,
#   'id': 2444219,
#   'name': 'Gouré',
#   'cod': 200},
#  {'coord': {'lon': -38.9967, 'lat': -14.2775},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 73.29,
#    'feels_like': 73.89,
#    'temp_min': 73.29,
#    'temp_max': 73.29,
#    'pressure': 1019,
#    'humidity': 76,
#    'sea_level': 1019,
#    'grnd_level': 1017},
#   'visibility': 10000,
#   'wind': {'speed': 7.65, 'deg': 122, 'gust': 10.92},
#   'clouds': {'all': 33},
#   'dt': 1632684697,
#   'sys': {'type': 1,
#    'id': 8386,
#    'country': 'BR',
#    'sunrise': 1632644545,
#    'sunset': 1632688323},
#   'timezone': -10800,
#   'id': 3460940,
#   'name': 'Itacaré',
#   'cod': 200},
#  {'coord': {'lon': 140.5, 'lat': 39.1667},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 55.72,
#    'feels_like': 55.33,
#    'temp_min': 55.72,
#    'temp_max': 55.72,
#    'pressure': 1020,
#    'humidity': 92,
#    'sea_level': 1020,
#    'grnd_level': 1007},
#   'visibility': 10000,
#   'wind': {'speed': 4.16, 'deg': 124, 'gust': 5.26},
#   'clouds': {'all': 10},
#   'dt': 1632684697,
#   'sys': {'country': 'JP', 'sunrise': 1632688191, 'sunset': 1632731297},
#   'timezone': 32400,
#   'id': 2110460,
#   'name': 'Yuzawa',
#   'cod': 200},
#  {'coord': {'lon': 149.2, 'lat': -21.15},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 60.85,
#    'feels_like': 61.05,
#    'temp_min': 60.78,
#    'temp_max': 67.05,
#    'pressure': 1015,
#    'humidity': 94},
#   'visibility': 10000,
#   'wind': {'speed': 5.75, 'deg': 270},
#   'clouds': {'all': 75},
#   'dt': 1632684614,
#   'sys': {'type': 1,
#    'id': 9498,
#    'country': 'AU',
#    'sunrise': 1632685699,
#    'sunset': 1632729614},
#   'timezone': 36000,
#   'id': 2159220,
#   'name': 'Mackay',
#   'cod': 200},
#  {'coord': {'lon': 164.2833, 'lat': -20.5667},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 71.26,
#    'feels_like': 71.19,
#    'temp_min': 71.26,
#    'temp_max': 71.26,
#    'pressure': 1015,
#    'humidity': 66,
#    'sea_level': 1015,
#    'grnd_level': 1015},
#   'visibility': 10000,
#   'wind': {'speed': 2.17, 'deg': 143, 'gust': 2.95},
#   'clouds': {'all': 100},
#   'dt': 1632684697,
#   'sys': {'country': 'NC', 'sunrise': 1632682087, 'sunset': 1632725988},
#   'timezone': 39600,
#   'id': 2140558,
#   'name': 'Koumac',
#   'cod': 200},
#  {'coord': {'lon': 45.05, 'lat': -25.1667},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 70.93,
#    'feels_like': 71.02,
#    'temp_min': 70.93,
#    'temp_max': 70.93,
#    'pressure': 1018,
#    'humidity': 70,
#    'sea_level': 1018,
#    'grnd_level': 999},
#   'visibility': 10000,
#   'wind': {'speed': 7.43, 'deg': 102, 'gust': 19.08},
#   'clouds': {'all': 38},
#   'dt': 1632684697,
#   'sys': {'country': 'MG', 'sunrise': 1632624304, 'sunset': 1632668231},
#   'timezone': 10800,
#   'id': 1067565,
#   'name': 'Beloha',
#   'cod': 200},
#  {'coord': {'lon': -59.5167, 'lat': 13.2167},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03d'}],
#   'base': 'stations',
#   'main': {'temp': 88.41,
#    'feels_like': 99.1,
#    'temp_min': 88.41,
#    'temp_max': 88.41,
#    'pressure': 1012,
#    'humidity': 66},
#   'visibility': 10000,
#   'wind': {'speed': 8.05, 'deg': 120},
#   'clouds': {'all': 40},
#   'dt': 1632684438,
#   'sys': {'type': 1,
#    'id': 8772,
#    'country': 'BB',
#    'sunrise': 1632649631,
#    'sunset': 1632693084},
#   'timezone': -14400,
#   'id': 3374083,
#   'name': 'Bathsheba',
#   'cod': 200},
#  {'coord': {'lon': 44.3779, 'lat': 14.298},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 59.58,
#    'feels_like': 56.41,
#    'temp_min': 59.58,
#    'temp_max': 59.58,
#    'pressure': 1015,
#    'humidity': 25,
#    'sea_level': 1015,
#    'grnd_level': 750},
#   'visibility': 10000,
#   'wind': {'speed': 2.53, 'deg': 62, 'gust': 3},
#   'clouds': {'all': 0},
#   'dt': 1632684698,
#   'sys': {'country': 'YE', 'sunrise': 1632624701, 'sunset': 1632668157},
#   'timezone': 10800,
#   'id': 69559,
#   'name': 'Yarim',
#   'cod': 200},
#  {'coord': {'lon': 143.2326, 'lat': 51.7102},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 47.37,
#    'feels_like': 45.86,
#    'temp_min': 47.37,
#    'temp_max': 47.37,
#    'pressure': 1019,
#    'humidity': 82,
#    'sea_level': 1019,
#    'grnd_level': 1016},
#   'visibility': 10000,
#   'wind': {'speed': 3.96, 'deg': 344, 'gust': 4.21},
#   'clouds': {'all': 74},
#   'dt': 1632684698,
#   'sys': {'country': 'RU', 'sunrise': 1632687639, 'sunset': 1632730538},
#   'timezone': 39600,
#   'id': 2122783,
#   'name': 'Katangli',
#   'cod': 200},
#  {'coord': {'lon': 29.6619, 'lat': -8.4689},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 77.68,
#    'feels_like': 77.22,
#    'temp_min': 77.68,
#    'temp_max': 77.68,
#    'pressure': 1011,
#    'humidity': 44,
#    'sea_level': 1011,
#    'grnd_level': 908},
#   'visibility': 10000,
#   'wind': {'speed': 2.8, 'deg': 86, 'gust': 4.68},
#   'clouds': {'all': 14},
#   'dt': 1632684698,
#   'sys': {'country': 'ZM', 'sunrise': 1632628112, 'sunset': 1632671807},
#   'timezone': 7200,
#   'id': 176758,
#   'name': 'Kaputa',
#   'cod': 200},
#  {'coord': {'lon': -86.9458, 'lat': 20.5083},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 80.37,
#    'feels_like': 86.49,
#    'temp_min': 77.07,
#    'temp_max': 87.78,
#    'pressure': 1015,
#    'humidity': 89},
#   'visibility': 8047,
#   'wind': {'speed': 11.5, 'deg': 160},
#   'clouds': {'all': 75},
#   'dt': 1632684699,
#   'sys': {'type': 2,
#    'id': 2011957,
#    'country': 'MX',
#    'sunrise': 1632656253,
#    'sunset': 1632699625},
#   'timezone': -18000,
#   'id': 3530103,
#   'name': 'San Miguel de Cozumel',
#   'cod': 200},
#  {'coord': {'lon': 140.3, 'lat': 35.1333},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 65.46,
#    'feels_like': 65.23,
#    'temp_min': 65.19,
#    'temp_max': 66.31,
#    'pressure': 1018,
#    'humidity': 75,
#    'sea_level': 1018,
#    'grnd_level': 1018},
#   'visibility': 10000,
#   'wind': {'speed': 13.8, 'deg': 13, 'gust': 19.51},
#   'clouds': {'all': 30},
#   'dt': 1632684699,
#   'sys': {'type': 2,
#    'id': 20334,
#    'country': 'JP',
#    'sunrise': 1632688211,
#    'sunset': 1632731373},
#   'timezone': 32400,
#   'id': 2112309,
#   'name': 'Katsuura',
#   'cod': 200},
#  {'coord': {'lon': -179.1667, 'lat': 66.3167},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02n'}],
#   'base': 'stations',
#   'main': {'temp': 21.72,
#    'feels_like': 17.37,
#    'temp_min': 21.72,
#    'temp_max': 21.72,
#    'pressure': 1011,
#    'humidity': 77,
#    'sea_level': 1011,
#    'grnd_level': 957},
#   'visibility': 10000,
#   'wind': {'speed': 3.2, 'deg': 359, 'gust': 3.15},
#   'clouds': {'all': 15},
#   'dt': 1632684699,
#   'sys': {'country': 'RU', 'sunrise': 1632765390, 'sunset': 1632807500},
#   'timezone': 43200,
#   'id': 4031742,
#   'name': 'Egvekinot',
#   'cod': 200},
#  {'coord': {'lon': 118.7167, 'lat': -8.4667},
#   'weather': [{'id': 802,
#     'main': 'Clouds',
#     'description': 'scattered clouds',
#     'icon': '03n'}],
#   'base': 'stations',
#   'main': {'temp': 74.21,
#    'feels_like': 75.61,
#    'temp_min': 74.21,
#    'temp_max': 74.21,
#    'pressure': 1010,
#    'humidity': 91,
#    'sea_level': 1010,
#    'grnd_level': 1010},
#   'visibility': 10000,
#   'wind': {'speed': 4.09, 'deg': 168, 'gust': 5.39},
#   'clouds': {'all': 31},
#   'dt': 1632684699,
#   'sys': {'country': 'ID', 'sunrise': 1632693113, 'sunset': 1632736829},
#   'timezone': 28800,
#   'id': 1648759,
#   'name': 'Bima',
#   'cod': 200},
#  {'coord': {'lon': 32.4311, 'lat': 54.8902},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 46.17,
#    'feels_like': 40.96,
#    'temp_min': 46.17,
#    'temp_max': 46.17,
#    'pressure': 1020,
#    'humidity': 89,
#    'sea_level': 1020,
#    'grnd_level': 996},
#   'visibility': 10000,
#   'wind': {'speed': 10.89, 'deg': 352, 'gust': 22.57},
#   'clouds': {'all': 55},
#   'dt': 1632684700,
#   'sys': {'country': 'RU', 'sunrise': 1632627787, 'sunset': 1632670804},
#   'timezone': 10800,
#   'id': 552558,
#   'name': 'Kardymovo',
#   'cod': 200},
#  {'coord': {'lon': -79.1469, 'lat': -7.8447},
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'base': 'stations',
#   'main': {'temp': 61.34,
#    'feels_like': 60.08,
#    'temp_min': 61.34,
#    'temp_max': 61.34,
#    'pressure': 1012,
#    'humidity': 62,
#    'sea_level': 1012,
#    'grnd_level': 996},
#   'visibility': 10000,
#   'wind': {'speed': 10.36, 'deg': 219, 'gust': 7.87},
#   'clouds': {'all': 17},
#   'dt': 1632684700,
#   'sys': {'type': 1,
#    'id': 8690,
#    'country': 'PE',
#    'sunrise': 1632654220,
#    'sunset': 1632697915},
#   'timezone': -18000,
#   'id': 3698359,
#   'name': 'Chicama',
#   'cod': 200},
#  {'coord': {'lon': 166.4372, 'lat': 68.0546},
#   'weather': [{'id': 601,
#     'main': 'Snow',
#     'description': 'snow',
#     'icon': '13d'}],
#   'base': 'stations',
#   'main': {'temp': 26.92,
#    'feels_like': 15.87,
#    'temp_min': 26.92,
#    'temp_max': 26.92,
#    'pressure': 1008,
#    'humidity': 97,
#    'sea_level': 1008,
#    'grnd_level': 972},
#   'visibility': 105,
#   'wind': {'speed': 13.15, 'deg': 202, 'gust': 23.53},
#   'snow': {'1h': 0.67},
#   'clouds': {'all': 100},
#   'dt': 1632684700,
#   'sys': {'country': 'RU', 'sunrise': 1632682298, 'sunset': 1632724743},
#   'timezone': 43200,
#   'id': 2126682,
#   'name': 'Bilibino',
#   'cod': 200},
#  {'coord': {'lon': -14.6471, 'lat': 16.5129},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 93.09,
#    'feels_like': 90.91,
#    'temp_min': 93.09,
#    'temp_max': 93.09,
#    'pressure': 1009,
#    'humidity': 27,
#    'sea_level': 1009,
#    'grnd_level': 1008},
#   'visibility': 10000,
#   'wind': {'speed': 7.29, 'deg': 333, 'gust': 11.7},
#   'clouds': {'all': 98},
#   'dt': 1632684701,
#   'sys': {'type': 1,
#    'id': 2427,
#    'country': 'SN',
#    'sunrise': 1632638878,
#    'sunset': 1632682304},
#   'timezone': 0,
#   'id': 2247684,
#   'name': 'Ndioum',
#   'cod': 200},
#  {'coord': {'lon': 115, 'lat': 4.75},
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 77.07,
#    'feels_like': 79.09,
#    'temp_min': 75.51,
#    'temp_max': 77.11,
#    'pressure': 1007,
#    'humidity': 98,
#    'sea_level': 1007,
#    'grnd_level': 1006},
#   'visibility': 10000,
#   'wind': {'speed': 2.04, 'deg': 162, 'gust': 1.83},
#   'clouds': {'all': 77},
#   'dt': 1632684701,
#   'sys': {'type': 2,
#    'id': 265576,
#    'country': 'MY',
#    'sunrise': 1632694094,
#    'sunset': 1632737631},
#   'timezone': 28800,
#   'id': 1737714,
#   'name': 'Limbang',
#   'cod': 200},
#  {'coord': {'lon': 26.4, 'lat': 46.4333},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 57.2,
#    'feels_like': 56.66,
#    'temp_min': 56.95,
#    'temp_max': 61.39,
#    'pressure': 1021,
#    'humidity': 86},
#   'visibility': 10000,
#   'wind': {'speed': 2.73, 'deg': 4, 'gust': 3},
#   'clouds': {'all': 1},
#   'dt': 1632684701,
#   'sys': {'type': 2,
#    'id': 2033571,
#    'country': 'RO',
#    'sunrise': 1632629179,
#    'sunset': 1632672306},
#   'timezone': 10800,
#   'id': 686090,
#   'name': 'Asău',
#   'cod': 200},
#  {'coord': {'lon': 77.5889, 'lat': 60.7333},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 33.78,
#    'feels_like': 27.66,
#    'temp_min': 33.78,
#    'temp_max': 33.78,
#    'pressure': 1032,
#    'humidity': 90,
#    'sea_level': 1032,
#    'grnd_level': 1026},
#   'visibility': 10000,
#   'wind': {'speed': 6.98, 'deg': 30, 'gust': 14.5},
#   'clouds': {'all': 7},
#   'dt': 1632684701,
#   'sys': {'type': 1,
#    'id': 8986,
#    'country': 'RU',
#    'sunrise': 1632703527,
#    'sunset': 1632746151},
#   'timezone': 25200,
#   'id': 1490796,
#   'name': 'Strezhevoy',
#   'cod': 200},
#  {'coord': {'lon': -147.7164, 'lat': 64.8378},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'base': 'stations',
#   'main': {'temp': 31.15,
#    'feels_like': 31.15,
#    'temp_min': 28.92,
#    'temp_max': 33.1,
#    'pressure': 1013,
#    'humidity': 87},
#   'visibility': 10000,
#   'wind': {'speed': 0, 'deg': 0},
#   'clouds': {'all': 90},
#   'dt': 1632684610,
#   'sys': {'type': 2,
#    'id': 2017395,
#    'country': 'US',
#    'sunrise': 1632671207,
#    'sunset': 1632713833},
#   'timezone': -28800,
#   'id': 5861897,
#   'name': 'Fairbanks',
#   'cod': 200},
#  {'coord': {'lon': 72.0193, 'lat': 33.4299},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 86.14,
#    'feels_like': 87.82,
#    'temp_min': 86.14,
#    'temp_max': 86.14,
#    'pressure': 1005,
#    'humidity': 49,
#    'sea_level': 1005,
#    'grnd_level': 968},
#   'visibility': 10000,
#   'wind': {'speed': 5.17, 'deg': 85, 'gust': 6.42},
#   'clouds': {'all': 0},
#   'dt': 1632684702,
#   'sys': {'country': 'PK', 'sunrise': 1632704595, 'sunset': 1632747756},
#   'timezone': 18000,
#   'id': 1176218,
#   'name': 'Jand',
#   'cod': 200},
#  {'coord': {'lon': 120.7333, 'lat': 49.2833},
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'base': 'stations',
#   'main': {'temp': 41.67,
#    'feels_like': 35.73,
#    'temp_min': 41.67,
#    'temp_max': 41.67,
#    'pressure': 1012,
#    'humidity': 91,
#    'sea_level': 1012,
#    'grnd_level': 934},
#   'visibility': 10000,
#   'wind': {'speed': 9.98, 'deg': 269, 'gust': 23.47},
#   'clouds': {'all': 3},
#   'dt': 1632684702,
#   'sys': {'country': 'CN', 'sunrise': 1632693021, 'sunset': 1632735952},
#   'timezone': 28800,
#   'id': 2033536,
#   'name': 'Yakeshi',
#   'cod': 200},
#  {'coord': {'lon': 81.2335, 'lat': 8.5711},
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'base': 'stations',
#   'main': {'temp': 80.8,
#    'feels_like': 85.62,
#    'temp_min': 80.8,
#    'temp_max': 80.8,
#    'pressure': 1004,
#    'humidity': 78,
#    'sea_level': 1004,
#    'grnd_level': 1003},
#   'visibility': 10000,
#   'wind': {'speed': 22.66, 'deg': 235, 'gust': 34.38},
#   'clouds': {'all': 100},
#   'dt': 1632684751,
#   'sys': {'country': 'LK', 'sunrise': 1632702221, 'sunset': 1632745707},
#   'timezone': 19800,
#   'id': 1226260,
#   'name': 'Trincomalee',
#   'cod': 200},
#  {'coord': {'lon': 105.7244, 'lat': 9.285},
#   'weather': [{'id': 502,
#     'main': 'Rain',
#     'description': 'heavy intensity rain',
#     'icon': '10n'}],
#   'base': 'stations',
#   'main': {'temp': 79.12,
#    'feels_like': 79.12,
#    'temp_min': 79.12,
#    'temp_max': 79.12,
#    'pressure': 1007,
#    'humidity': 86,
#    'sea_level': 1007,
#    'grnd_level': 1007},
#   'visibility': 10000,
#   'wind': {'speed': 6.93, 'deg': 108, 'gust': 8.63},
#   'rain': {'1h': 5.76},
#   'clouds': {'all': 31},
#   'dt': 1632684751,
#   'sys': {'country': 'VN', 'sunrise': 1632696349, 'sunset': 1632739827},
#   'timezone': 25200,
#   'id': 1591474,
#   'name': 'Bac Lieu',
#   'cod': 200}]

# %%
# Now build a list of only the data we want to work with from the json
weather_data_list = []

for city in weather_data_cities:
    weather_data_dict = {}
    weather_data_dict['City'] = city['name']
    weather_data_dict['Lat'] = city['coord']['lat']
    weather_data_dict['Lng'] = city['coord']['lon']
    weather_data_dict['Max Temp'] = city['main']['temp_max']
    weather_data_dict['Humidity'] = city['main']['humidity']
    weather_data_dict['Cloudiness'] = city['clouds']['all']
    weather_data_dict['Wind Speed'] = city['wind']['speed']
    weather_data_dict['Country'] = city['sys']['country']
    weather_data_dict['Date'] = city['dt']
    weather_data_list.append(weather_data_dict)
    
weather_data_list, len(weather_data_list)
# Out:
# ([{'City': 'Zaozyornoye',
#    'Lat': 45.1582,
#    'Lng': 33.2787,
#    'Max Temp': 64.94,
#    'Humidity': 68,
#    'Cloudiness': 59,
#    'Wind Speed': 10.38,
#    'Country': 'UA',
#    'Date': 1632683939},
#   {'City': 'Bluff',
#    'Lat': -46.6,
#    'Lng': 168.3333,
#    'Max Temp': 38.79,
#    'Humidity': 80,
#    'Cloudiness': 21,
#    'Wind Speed': 7.96,
#    'Country': 'NZ',
#    'Date': 1632683947},
#   {'City': 'Windhoek',
#    'Lat': -22.5594,
#    'Lng': 17.0832,
#    'Max Temp': 77.2,
#    'Humidity': 16,
#    'Cloudiness': 2,
#    'Wind Speed': 4.61,
#    'Country': 'NA',
#    'Date': 1632683948},
#   {'City': 'Cayenne',
#    'Lat': 4.9333,
#    'Lng': -52.3333,
#    'Max Temp': 89.64,
#    'Humidity': 71,
#    'Cloudiness': 88,
#    'Wind Speed': 5.99,
#    'Country': 'GF',
#    'Date': 1632683948},
#   {'City': 'Vestmannaeyjar',
#    'Lat': 63.4427,
#    'Lng': -20.2734,
#    'Max Temp': 43.25,
#    'Humidity': 81,
#    'Cloudiness': 98,
#    'Wind Speed': 5.14,
#    'Country': 'IS',
#    'Date': 1632683948},
#   {'City': 'Jamestown',
#    'Lat': 42.097,
#    'Lng': -79.2353,
#    'Max Temp': 69.12,
#    'Humidity': 44,
#    'Cloudiness': 75,
#    'Wind Speed': 11.99,
#    'Country': 'US',
#    'Date': 1632683780},
#   {'City': 'Tuktoyaktuk',
#    'Lat': 69.4541,
#    'Lng': -133.0374,
#    'Max Temp': 33.8,
#    'Humidity': 93,
#    'Cloudiness': 90,
#    'Wind Speed': 16.11,
#    'Country': 'CA',
#    'Date': 1632683949},
#   {'City': 'Neuquén',
#    'Lat': -38.9516,
#    'Lng': -68.0591,
#    'Max Temp': 60.69,
#    'Humidity': 25,
#    'Cloudiness': 0,
#    'Wind Speed': 6.91,
#    'Country': 'AR',
#    'Date': 1632683949},
#   {'City': 'Mar del Plata',
#    'Lat': -38.0023,
#    'Lng': -57.5575,
#    'Max Temp': 58.08,
#    'Humidity': 64,
#    'Cloudiness': 75,
#    'Wind Speed': 8.99,
#    'Country': 'AR',
#    'Date': 1632683949},
#   {'City': 'Deputatsky',
#    'Lat': 69.3,
#    'Lng': 139.9,
#    'Max Temp': 27.52,
#    'Humidity': 87,
#    'Cloudiness': 100,
#    'Wind Speed': 20.11,
#    'Country': 'RU',
#    'Date': 1632683949},
#   {'City': 'Hofn',
#    'Lat': 64.2539,
#    'Lng': -15.2082,
#    'Max Temp': 43.95,
#    'Humidity': 74,
#    'Cloudiness': 50,
#    'Wind Speed': 5.46,
#    'Country': 'IS',
#    'Date': 1632683866},
#   {'City': 'Bredasdorp',
#    'Lat': -34.5322,
#    'Lng': 20.0403,
#    'Max Temp': 59.29,
#    'Humidity': 88,
#    'Cloudiness': 1,
#    'Wind Speed': 4.61,
#    'Country': 'ZA',
#    'Date': 1632683871},
#   {'City': 'Punta Arenas',
#    'Lat': -53.15,
#    'Lng': -70.9167,
#    'Max Temp': 48.31,
#    'Humidity': 49,
#    'Cloudiness': 40,
#    'Wind Speed': 18.41,
#    'Country': 'CL',
#    'Date': 1632683866},
#   {'City': 'Doumé',
#    'Lat': 4.2333,
#    'Lng': 13.45,
#    'Max Temp': 69.1,
#    'Humidity': 95,
#    'Cloudiness': 97,
#    'Wind Speed': 1.9,
#    'Country': 'CM',
#    'Date': 1632683950},
#   {'City': 'Puerto Ayora',
#    'Lat': -0.7393,
#    'Lng': -90.3518,
#    'Max Temp': 78.76,
#    'Humidity': 83,
#    'Cloudiness': 82,
#    'Wind Speed': 9.24,
#    'Country': 'EC',
#    'Date': 1632683867},
#   {'City': 'Korla',
#    'Lat': 41.7597,
#    'Lng': 86.1469,
#    'Max Temp': 63.66,
#    'Humidity': 26,
#    'Cloudiness': 0,
#    'Wind Speed': 3.49,
#    'Country': 'CN',
#    'Date': 1632683950},
#   {'City': 'Rikitea',
#    'Lat': -23.1203,
#    'Lng': -134.9692,
#    'Max Temp': 73.54,
#    'Humidity': 75,
#    'Cloudiness': 6,
#    'Wind Speed': 18.63,
#    'Country': 'PF',
#    'Date': 1632683864},
#   {'City': 'Turukhansk',
#    'Lat': 65.8167,
#    'Lng': 87.9833,
#    'Max Temp': 34.14,
#    'Humidity': 84,
#    'Cloudiness': 32,
#    'Wind Speed': 5.37,
#    'Country': 'RU',
#    'Date': 1632683951},
#   {'City': 'Laas',
#    'Lat': 46.6166,
#    'Lng': 10.7002,
#    'Max Temp': 62.02,
#    'Humidity': 97,
#    'Cloudiness': 100,
#    'Wind Speed': 2.24,
#    'Country': 'IT',
#    'Date': 1632683951},
#   {'City': 'Lysa Hora',
#    'Lat': 48.1706,
#    'Lng': 31.1099,
#    'Max Temp': 54.97,
#    'Humidity': 62,
#    'Cloudiness': 31,
#    'Wind Speed': 8.05,
#    'Country': 'UA',
#    'Date': 1632683951},
#   {'City': 'Gorontalo',
#    'Lat': 0.5412,
#    'Lng': 123.0595,
#    'Max Temp': 74.16,
#    'Humidity': 84,
#    'Cloudiness': 100,
#    'Wind Speed': 2.01,
#    'Country': 'ID',
#    'Date': 1632683951},
#   {'City': 'Morgan City',
#    'Lat': 29.6994,
#    'Lng': -91.2068,
#    'Max Temp': 84.99,
#    'Humidity': 54,
#    'Cloudiness': 1,
#    'Wind Speed': 8.05,
#    'Country': 'US',
#    'Date': 1632683952},
#   {'City': 'Chokurdakh',
#    'Lat': 70.6333,
#    'Lng': 147.9167,
#    'Max Temp': 28.58,
#    'Humidity': 85,
#    'Cloudiness': 100,
#    'Wind Speed': 15.9,
#    'Country': 'RU',
#    'Date': 1632683952},
#   {'City': 'Bethel',
#    'Lat': 41.3712,
#    'Lng': -73.414,
#    'Max Temp': 72.36,
#    'Humidity': 55,
#    'Cloudiness': 20,
#    'Wind Speed': 8.05,
#    'Country': 'US',
#    'Date': 1632683952},
#   {'City': 'Leningradskiy',
#    'Lat': 69.3833,
#    'Lng': 178.4167,
#    'Max Temp': 22.24,
#    'Humidity': 80,
#    'Cloudiness': 94,
#    'Wind Speed': 8.72,
#    'Country': 'RU',
#    'Date': 1632683953},
#   {'City': 'New Norfolk',
#    'Lat': -42.7826,
#    'Lng': 147.0587,
#    'Max Temp': 38.91,
#    'Humidity': 75,
#    'Cloudiness': 13,
#    'Wind Speed': 2.95,
#    'Country': 'AU',
#    'Date': 1632683860},
#   {'City': 'Port Alfred',
#    'Lat': -33.5906,
#    'Lng': 26.891,
#    'Max Temp': 64.89,
#    'Humidity': 91,
#    'Cloudiness': 26,
#    'Wind Speed': 17.22,
#    'Country': 'ZA',
#    'Date': 1632683863},
#   {'City': 'Conakry',
#    'Lat': 9.538,
#    'Lng': -13.6773,
#    'Max Temp': 78.87,
#    'Humidity': 83,
#    'Cloudiness': 75,
#    'Wind Speed': 6.91,
#    'Country': 'GN',
#    'Date': 1632683953},
#   {'City': 'Butaritari',
#    'Lat': 3.0707,
#    'Lng': 172.7902,
#    'Max Temp': 83.7,
#    'Humidity': 73,
#    'Cloudiness': 100,
#    'Wind Speed': 16.24,
#    'Country': 'KI',
#    'Date': 1632683863},
#   {'City': 'Cape Town',
#    'Lat': -33.9258,
#    'Lng': 18.4232,
#    'Max Temp': 62.28,
#    'Humidity': 73,
#    'Cloudiness': 26,
#    'Wind Speed': 1.99,
#    'Country': 'ZA',
#    'Date': 1632683653},
#   {'City': 'Lompoc',
#    'Lat': 34.6391,
#    'Lng': -120.4579,
#    'Max Temp': 62.91,
#    'Humidity': 85,
#    'Cloudiness': 90,
#    'Wind Speed': 4.61,
#    'Country': 'US',
#    'Date': 1632683953},
#   {'City': 'Torbay',
#    'Lat': 47.6666,
#    'Lng': -52.7314,
#    'Max Temp': 63.37,
#    'Humidity': 62,
#    'Cloudiness': 90,
#    'Wind Speed': 13.8,
#    'Country': 'CA',
#    'Date': 1632683954},
#   {'City': 'Beringovskiy',
#    'Lat': 63.05,
#    'Lng': 179.3167,
#    'Max Temp': 36.7,
#    'Humidity': 65,
#    'Cloudiness': 99,
#    'Wind Speed': 4.47,
#    'Country': 'RU',
#    'Date': 1632683954},
#   {'City': 'Clyde River',
#    'Lat': 70.4692,
#    'Lng': -68.5914,
#    'Max Temp': 29.86,
#    'Humidity': 80,
#    'Cloudiness': 18,
#    'Wind Speed': 6.8,
#    'Country': 'CA',
#    'Date': 1632683854},
#   {'City': 'Chui',
#    'Lat': -33.6971,
#    'Lng': -53.4616,
#    'Max Temp': 67.62,
#    'Humidity': 67,
#    'Cloudiness': 0,
#    'Wind Speed': 5.53,
#    'Country': 'UY',
#    'Date': 1632683954},
#   {'City': 'Vaini',
#    'Lat': -21.2,
#    'Lng': -175.2,
#    'Max Temp': 69.96,
#    'Humidity': 88,
#    'Cloudiness': 75,
#    'Wind Speed': 2.3,
#    'Country': 'TO',
#    'Date': 1632683868},
#   {'City': 'Yellowknife',
#    'Lat': 62.456,
#    'Lng': -114.3525,
#    'Max Temp': 43.41,
#    'Humidity': 83,
#    'Cloudiness': 75,
#    'Wind Speed': 4,
#    'Country': 'CA',
#    'Date': 1632683837},
#   {'City': 'Tasiilaq',
#    'Lat': 65.6145,
#    'Lng': -37.6368,
#    'Max Temp': 37.56,
#    'Humidity': 69,
#    'Cloudiness': 33,
#    'Wind Speed': 2.68,
#    'Country': 'GL',
#    'Date': 1632683955},
#   {'City': 'Avarua',
#    'Lat': -21.2078,
#    'Lng': -159.775,
#    'Max Temp': 77.05,
#    'Humidity': 69,
#    'Cloudiness': 90,
#    'Wind Speed': 2.3,
#    'Country': 'CK',
#    'Date': 1632683814},
#   {'City': 'Juneau',
#    'Lat': 58.3019,
#    'Lng': -134.4197,
#    'Max Temp': 52.84,
#    'Humidity': 83,
#    'Cloudiness': 75,
#    'Wind Speed': 3.44,
#    'Country': 'US',
#    'Date': 1632683955},
#   {'City': 'Progreso',
#    'Lat': 21.2833,
#    'Lng': -89.6667,
#    'Max Temp': 94.1,
#    'Humidity': 59,
#    'Cloudiness': 8,
#    'Wind Speed': 12.46,
#    'Country': 'MX',
#    'Date': 1632683955},
#   {'City': 'Comodoro Rivadavia',
#    'Lat': -45.8667,
#    'Lng': -67.5,
#    'Max Temp': 55.26,
#    'Humidity': 24,
#    'Cloudiness': 0,
#    'Wind Speed': 13.8,
#    'Country': 'AR',
#    'Date': 1632683701},
#   {'City': 'Vardø',
#    'Lat': 70.3705,
#    'Lng': 31.1107,
#    'Max Temp': 48.4,
#    'Humidity': 76,
#    'Cloudiness': 75,
#    'Wind Speed': 14.97,
#    'Country': 'NO',
#    'Date': 1632683956},
#   {'City': 'Bayburt',
#    'Lat': 40.2589,
#    'Lng': 40.2278,
#    'Max Temp': 50.65,
#    'Humidity': 54,
#    'Cloudiness': 0,
#    'Wind Speed': 1.03,
#    'Country': 'TR',
#    'Date': 1632683782},
#   {'City': 'Mildura',
#    'Lat': -34.2,
#    'Lng': 142.15,
#    'Max Temp': 44.56,
#    'Humidity': 61,
#    'Cloudiness': 49,
#    'Wind Speed': 5.75,
#    'Country': 'AU',
#    'Date': 1632683956},
#   {'City': 'Padang',
#    'Lat': -0.9492,
#    'Lng': 100.3543,
#    'Max Temp': 76.14,
#    'Humidity': 95,
#    'Cloudiness': 100,
#    'Wind Speed': 2.26,
#    'Country': 'ID',
#    'Date': 1632683941},
#   {'City': 'Hermanus',
#    'Lat': -34.4187,
#    'Lng': 19.2345,
#    'Max Temp': 60.91,
#    'Humidity': 90,
#    'Cloudiness': 1,
#    'Wind Speed': 8.97,
#    'Country': 'ZA',
#    'Date': 1632683957},
#   {'City': 'Acapulco de Juárez',
#    'Lat': 16.8634,
#    'Lng': -99.8901,
#    'Max Temp': 85.98,
#    'Humidity': 68,
#    'Cloudiness': 99,
#    'Wind Speed': 6.04,
#    'Country': 'MX',
#    'Date': 1632684090},
#   {'City': 'Guadalupe y Calvo',
#    'Lat': 26.1,
#    'Lng': -106.9667,
#    'Max Temp': 69.04,
#    'Humidity': 53,
#    'Cloudiness': 2,
#    'Wind Speed': 7.81,
#    'Country': 'MX',
#    'Date': 1632684091},
#   {'City': 'Mokhsogollokh',
#    'Lat': 61.4681,
#    'Lng': 128.9203,
#    'Max Temp': 30.63,
#    'Humidity': 93,
#    'Cloudiness': 100,
#    'Wind Speed': 5.97,
#    'Country': 'RU',
#    'Date': 1632684091},
#   {'City': 'Upernavik',
#    'Lat': 72.7868,
#    'Lng': -56.1549,
#    'Max Temp': 25.41,
#    'Humidity': 64,
#    'Cloudiness': 0,
#    'Wind Speed': 2.55,
#    'Country': 'GL',
#    'Date': 1632684091},
#   {'City': 'Coquimbo',
#    'Lat': -29.9533,
#    'Lng': -71.3436,
#    'Max Temp': 64.13,
#    'Humidity': 67,
#    'Cloudiness': 0,
#    'Wind Speed': 16.11,
#    'Country': 'CL',
#    'Date': 1632684092},
#   {'City': 'Yerbogachën',
#    'Lat': 61.2767,
#    'Lng': 108.0108,
#    'Max Temp': 32.54,
#    'Humidity': 95,
#    'Cloudiness': 100,
#    'Wind Speed': 13.29,
#    'Country': 'RU',
#    'Date': 1632684092},
#   {'City': 'Jalu',
#    'Lat': 29.0331,
#    'Lng': 21.5482,
#    'Max Temp': 77.68,
#    'Humidity': 32,
#    'Cloudiness': 0,
#    'Wind Speed': 5.64,
#    'Country': 'LY',
#    'Date': 1632684092},
#   {'City': 'Busselton',
#    'Lat': -33.65,
#    'Lng': 115.3333,
#    'Max Temp': 57.04,
#    'Humidity': 90,
#    'Cloudiness': 76,
#    'Wind Speed': 14.36,
#    'Country': 'AU',
#    'Date': 1632683862},
#   {'City': 'Arequipa',
#    'Lat': -16.3989,
#    'Lng': -71.535,
#    'Max Temp': 75.27,
#    'Humidity': 12,
#    'Cloudiness': 0,
#    'Wind Speed': 11.5,
#    'Country': 'PE',
#    'Date': 1632684093},
#   {'City': 'Vilyuysk',
#    'Lat': 63.7553,
#    'Lng': 121.6247,
#    'Max Temp': 30.81,
#    'Humidity': 82,
#    'Cloudiness': 100,
#    'Wind Speed': 7,
#    'Country': 'RU',
#    'Date': 1632684093},
#   {'City': 'Ahipara',
#    'Lat': -35.1667,
#    'Lng': 173.1667,
#    'Max Temp': 50.94,
#    'Humidity': 83,
#    'Cloudiness': 99,
#    'Wind Speed': 7.29,
#    'Country': 'NZ',
#    'Date': 1632684093},
#   {'City': 'Saint Paul Harbor',
#    'Lat': 57.79,
#    'Lng': -152.4072,
#    'Max Temp': 47.71,
#    'Humidity': 61,
#    'Cloudiness': 1,
#    'Wind Speed': 11.5,
#    'Country': 'US',
#    'Date': 1632684094},
#   {'City': 'Yulara',
#    'Lat': -25.2406,
#    'Lng': 130.9889,
#    'Max Temp': 67.84,
#    'Humidity': 21,
#    'Cloudiness': 27,
#    'Wind Speed': 0,
#    'Country': 'AU',
#    'Date': 1632684094},
#   {'City': 'Narsaq',
#    'Lat': 60.9167,
#    'Lng': -46.05,
#    'Max Temp': 44.82,
#    'Humidity': 46,
#    'Cloudiness': 0,
#    'Wind Speed': 2.26,
#    'Country': 'GL',
#    'Date': 1632683864},
#   {'City': 'Bambous Virieux',
#    'Lat': -20.3428,
#    'Lng': 57.7575,
#    'Max Temp': 70.21,
#    'Humidity': 94,
#    'Cloudiness': 75,
#    'Wind Speed': 12.66,
#    'Country': 'MU',
#    'Date': 1632684075},
#   {'City': 'Velikodvorskiy',
#    'Lat': 55.25,
#    'Lng': 40.6678,
#    'Max Temp': 48.18,
#    'Humidity': 95,
#    'Cloudiness': 100,
#    'Wind Speed': 9.89,
#    'Country': 'RU',
#    'Date': 1632684094},
#   {'City': 'Albany',
#    'Lat': 42.6001,
#    'Lng': -73.9662,
#    'Max Temp': 69.39,
#    'Humidity': 48,
#    'Cloudiness': 6,
#    'Wind Speed': 1.99,
#    'Country': 'US',
#    'Date': 1632684095},
#   {'City': 'Sept-Îles',
#    'Lat': 50.2001,
#    'Lng': -66.3821,
#    'Max Temp': 58.24,
#    'Humidity': 98,
#    'Cloudiness': 90,
#    'Wind Speed': 13,
#    'Country': 'CA',
#    'Date': 1632684046},
#   {'City': 'Nome',
#    'Lat': 64.5011,
#    'Lng': -165.4064,
#    'Max Temp': 35.67,
#    'Humidity': 75,
#    'Cloudiness': 75,
#    'Wind Speed': 9.22,
#    'Country': 'US',
#    'Date': 1632683867},
#   {'City': 'Grand-Lahou',
#    'Lat': 5.1367,
#    'Lng': -5.0242,
#    'Max Temp': 74.3,
#    'Humidity': 93,
#    'Cloudiness': 100,
#    'Wind Speed': 5.91,
#    'Country': 'CI',
#    'Date': 1632684095},
#   {'City': 'Manbij',
#    'Lat': 36.5281,
#    'Lng': 37.9549,
#    'Max Temp': 66.97,
#    'Humidity': 23,
#    'Cloudiness': 0,
#    'Wind Speed': 7.56,
#    'Country': 'SY',
#    'Date': 1632684095},
#   {'City': 'Noshiro',
#    'Lat': 40.2039,
#    'Lng': 140.0242,
#    'Max Temp': 57.83,
#    'Humidity': 84,
#    'Cloudiness': 23,
#    'Wind Speed': 6.24,
#    'Country': 'JP',
#    'Date': 1632684096},
#   {'City': 'Nikolskoye',
#    'Lat': 59.7035,
#    'Lng': 30.7861,
#    'Max Temp': 49.89,
#    'Humidity': 92,
#    'Cloudiness': 97,
#    'Wind Speed': 5.53,
#    'Country': 'RU',
#    'Date': 1632684096},
#   {'City': 'La Maddalena',
#    'Lat': 41.2142,
#    'Lng': 9.4083,
#    'Max Temp': 78.85,
#    'Humidity': 86,
#    'Cloudiness': 41,
#    'Wind Speed': 10.87,
#    'Country': 'IT',
#    'Date': 1632684096},
#   {'City': 'Arraial do Cabo',
#    'Lat': -22.9661,
#    'Lng': -42.0278,
#    'Max Temp': 78.76,
#    'Humidity': 73,
#    'Cloudiness': 0,
#    'Wind Speed': 18.41,
#    'Country': 'BR',
#    'Date': 1632684097},
#   {'City': 'Zaqatala',
#    'Lat': 41.6336,
#    'Lng': 46.6433,
#    'Max Temp': 57.67,
#    'Humidity': 55,
#    'Cloudiness': 2,
#    'Wind Speed': 11.5,
#    'Country': 'AZ',
#    'Date': 1632684097},
#   {'City': 'Mangalia',
#    'Lat': 43.8,
#    'Lng': 28.5833,
#    'Max Temp': 66.09,
#    'Humidity': 77,
#    'Cloudiness': 0,
#    'Wind Speed': 8.21,
#    'Country': 'RO',
#    'Date': 1632684097},
#   {'City': 'Saint-Philippe',
#    'Lat': -21.3585,
#    'Lng': 55.7679,
#    'Max Temp': 71.19,
#    'Humidity': 88,
#    'Cloudiness': 55,
#    'Wind Speed': 13.96,
#    'Country': 'RE',
#    'Date': 1632684097},
#   {'City': 'Sioux Lookout',
#    'Lat': 50.1001,
#    'Lng': -91.917,
#    'Max Temp': 64.78,
#    'Humidity': 45,
#    'Cloudiness': 40,
#    'Wind Speed': 4.61,
#    'Country': 'CA',
#    'Date': 1632684098},
#   {'City': 'Bawku',
#    'Lat': 11.0616,
#    'Lng': -0.2417,
#    'Max Temp': 84.2,
#    'Humidity': 57,
#    'Cloudiness': 81,
#    'Wind Speed': 6.13,
#    'Country': 'GH',
#    'Date': 1632684098},
#   {'City': 'Carnarvon',
#    'Lat': -24.8667,
#    'Lng': 113.6333,
#    'Max Temp': 62.67,
#    'Humidity': 77,
#    'Cloudiness': 75,
#    'Wind Speed': 11.5,
#    'Country': 'AU',
#    'Date': 1632683856},
#   {'City': 'Mugur-Aksy',
#    'Lat': 50.35,
#    'Lng': 90.5,
#    'Max Temp': 21.15,
#    'Humidity': 75,
#    'Cloudiness': 42,
#    'Wind Speed': 6.67,
#    'Country': 'RU',
#    'Date': 1632684098},
#   {'City': 'Atuona',
#    'Lat': -9.8,
#    'Lng': -139.0333,
#    'Max Temp': 78.55,
#    'Humidity': 67,
#    'Cloudiness': 4,
#    'Wind Speed': 17.76,
#    'Country': 'PF',
#    'Date': 1632684099},
#   {'City': 'Ibrā’',
#    'Lat': 22.6906,
#    'Lng': 58.5334,
#    'Max Temp': 84.36,
#    'Humidity': 52,
#    'Cloudiness': 17,
#    'Wind Speed': 7.7,
#    'Country': 'OM',
#    'Date': 1632684099},
#   {'City': 'Kinablangan',
#    'Lat': 7.6947,
#    'Lng': 126.5503,
#    'Max Temp': 77.77,
#    'Humidity': 85,
#    'Cloudiness': 100,
#    'Wind Speed': 3.09,
#    'Country': 'PH',
#    'Date': 1632684099},
#   {'City': 'Pryazha',
#    'Lat': 61.6926,
#    'Lng': 33.6216,
#    'Max Temp': 49.23,
#    'Humidity': 97,
#    'Cloudiness': 76,
#    'Wind Speed': 3.67,
#    'Country': 'RU',
#    'Date': 1632684100},
#   {'City': 'Birao',
#    'Lat': 10.2849,
#    'Lng': 22.7882,
#    'Max Temp': 71.44,
#    'Humidity': 81,
#    'Cloudiness': 26,
#    'Wind Speed': 3.44,
#    'Country': 'CF',
#    'Date': 1632684100},
#   {'City': 'Sault Ste. Marie',
#    'Lat': 46.5168,
#    'Lng': -84.3333,
#    'Max Temp': 66.76,
#    'Humidity': 55,
#    'Cloudiness': 90,
#    'Wind Speed': 10.36,
#    'Country': 'CA',
#    'Date': 1632684100},
#   {'City': 'Hobart',
#    'Lat': -42.8794,
#    'Lng': 147.3294,
#    'Max Temp': 39.27,
#    'Humidity': 89,
#    'Cloudiness': 3,
#    'Wind Speed': 1.99,
#    'Country': 'AU',
#    'Date': 1632683584},
#   {'City': "Severo-Kuril'sk",
#    'Lat': 50.6789,
#    'Lng': 156.125,
#    'Max Temp': 48.67,
#    'Humidity': 92,
#    'Cloudiness': 100,
#    'Wind Speed': 11.32,
#    'Country': 'RU',
#    'Date': 1632684100},
#   {'City': 'Fort Nelson',
#    'Lat': 58.8053,
#    'Lng': -122.7002,
#    'Max Temp': 47.79,
#    'Humidity': 49,
#    'Cloudiness': 90,
#    'Wind Speed': 6.91,
#    'Country': 'CA',
#    'Date': 1632684101},
#   {'City': 'Gijang',
#    'Lat': 35.2442,
#    'Lng': 129.2139,
#    'Max Temp': 69.53,
#    'Humidity': 82,
#    'Cloudiness': 100,
#    'Wind Speed': 12.12,
#    'Country': 'KR',
#    'Date': 1632684151},
#   {'City': 'Kaitangata',
#    'Lat': -46.2817,
#    'Lng': 169.8464,
#    'Max Temp': 33.22,
#    'Humidity': 90,
#    'Cloudiness': 22,
#    'Wind Speed': 5.26,
#    'Country': 'NZ',
#    'Date': 1632684151},
#   {'City': 'Gizo Government Station',
#    'Lat': -8.103,
#    'Lng': 156.8419,
#    'Max Temp': 80.69,
#    'Humidity': 78,
#    'Cloudiness': 100,
#    'Wind Speed': 5.17,
#    'Country': 'SB',
#    'Date': 1632684151},
#   {'City': 'Norman Wells',
#    'Lat': 65.282,
#    'Lng': -126.8329,
#    'Max Temp': 37.44,
#    'Humidity': 65,
#    'Cloudiness': 75,
#    'Wind Speed': 11.5,
#    'Country': 'CA',
#    'Date': 1632684152},
#   {'City': 'Naze',
#    'Lat': 28.3667,
#    'Lng': 129.4833,
#    'Max Temp': 77.22,
#    'Humidity': 83,
#    'Cloudiness': 16,
#    'Wind Speed': 11.07,
#    'Country': 'JP',
#    'Date': 1632684152},
#   {'City': 'Nara',
#    'Lat': 34.6851,
#    'Lng': 135.8049,
#    'Max Temp': 69.08,
#    'Humidity': 74,
#    'Cloudiness': 91,
#    'Wind Speed': 5.82,
#    'Country': 'JP',
#    'Date': 1632684152},
#   {'City': 'Dali',
#    'Lat': 25.7,
#    'Lng': 100.1833,
#    'Max Temp': 59.13,
#    'Humidity': 91,
#    'Cloudiness': 88,
#    'Wind Speed': 2.8,
#    'Country': 'CN',
#    'Date': 1632684152},
#   {'City': 'Saint Anthony',
#    'Lat': 45.0205,
#    'Lng': -93.218,
#    'Max Temp': 82.15,
#    'Humidity': 50,
#    'Cloudiness': 1,
#    'Wind Speed': 1.01,
#    'Country': 'US',
#    'Date': 1632683917},
#   {'City': 'Olinda',
#    'Lat': -8.0089,
#    'Lng': -34.8553,
#    'Max Temp': 80.33,
#    'Humidity': 65,
#    'Cloudiness': 75,
#    'Wind Speed': 17.27,
#    'Country': 'BR',
#    'Date': 1632684153},
#   {'City': 'Ulmu',
#    'Lat': 44.95,
#    'Lng': 27.3167,
#    'Max Temp': 66.63,
#    'Humidity': 46,
#    'Cloudiness': 0,
#    'Wind Speed': 5.28,
#    'Country': 'RO',
#    'Date': 1632684153},
#   {'City': 'Saskylakh',
#    'Lat': 71.9167,
#    'Lng': 114.0833,
#    'Max Temp': 34.09,
#    'Humidity': 98,
#    'Cloudiness': 100,
#    'Wind Speed': 9.89,
#    'Country': 'RU',
#    'Date': 1632683863},
#   {'City': 'Buraidah',
#    'Lat': 26.326,
#    'Lng': 43.975,
#    'Max Temp': 86.45,
#    'Humidity': 25,
#    'Cloudiness': 3,
#    'Wind Speed': 11.59,
#    'Country': 'SA',
#    'Date': 1632684153},
#   {'City': 'Baoding',
#    'Lat': 38.8511,
#    'Lng': 115.4903,
#    'Max Temp': 63.75,
#    'Humidity': 96,
#    'Cloudiness': 93,
#    'Wind Speed': 4.63,
#    'Country': 'CN',
#    'Date': 1632684154},
#   {'City': 'Villa Carlos Paz',
#    'Lat': -31.4241,
#    'Lng': -64.4978,
#    'Max Temp': 78.06,
#    'Humidity': 23,
#    'Cloudiness': 0,
#    'Wind Speed': 10.6,
#    'Country': 'AR',
#    'Date': 1632683931},
#   {'City': 'Ushuaia',
#    'Lat': -54.8,
#    'Lng': -68.3,
#    'Max Temp': 46.06,
#    'Humidity': 46,
#    'Cloudiness': 20,
#    'Wind Speed': 6.91,
#    'Country': 'AR',
#    'Date': 1632683733},
#   {'City': 'Rivadavia',
#    'Lat': -33.1905,
#    'Lng': -68.4608,
#    'Max Temp': 68.47,
#    'Humidity': 20,
#    'Cloudiness': 0,
#    'Wind Speed': 10.58,
#    'Country': 'AR',
#    'Date': 1632684154},
#   {'City': 'Corvallis',
#    'Lat': 44.5646,
#    'Lng': -123.262,
#    'Max Temp': 70.86,
#    'Humidity': 62,
#    'Cloudiness': 1,
#    'Wind Speed': 1.01,
#    'Country': 'US',
#    'Date': 1632683969},
#   {'City': 'Xining',
#    'Lat': 36.6167,
#    'Lng': 101.7667,
#    'Max Temp': 50.72,
#    'Humidity': 76,
#    'Cloudiness': 100,
#    'Wind Speed': 0.81,
#    'Country': 'CN',
#    'Date': 1632684154},
#   {'City': 'São João da Barra',
#    'Lat': -21.6403,
#    'Lng': -41.0511,
#    'Max Temp': 78.89,
#    'Humidity': 76,
#    'Cloudiness': 2,
#    'Wind Speed': 21,
#    'Country': 'BR',
#    'Date': 1632684155},
#   {'City': 'Whitehorse',
#    'Lat': 60.7161,
#    'Lng': -135.0538,
#    'Max Temp': 38.17,
#    'Humidity': 70,
#    'Cloudiness': 75,
#    'Wind Speed': 4,
#    'Country': 'CA',
#    'Date': 1632684023},
#   {'City': 'Hilo',
#    'Lat': 19.7297,
#    'Lng': -155.09,
#    'Max Temp': 78.8,
#    'Humidity': 91,
#    'Cloudiness': 90,
#    'Wind Speed': 6.91,
#    'Country': 'US',
#    'Date': 1632683583},
#   {'City': 'Sisimiut',
#    'Lat': 66.9395,
#    'Lng': -53.6735,
#    'Max Temp': 31.28,
#    'Humidity': 45,
#    'Cloudiness': 0,
#    'Wind Speed': 6.62,
#    'Country': 'GL',
#    'Date': 1632684155},
#   {'City': 'Barrow',
#    'Lat': 71.2906,
#    'Lng': -156.7887,
#    'Max Temp': 26.62,
#    'Humidity': 80,
#    'Cloudiness': 90,
#    'Wind Speed': 9.22,
#    'Country': 'US',
#    'Date': 1632684076},
#   {'City': 'Ribeira Grande',
#    'Lat': 38.5167,
#    'Lng': -28.7,
#    'Max Temp': 68.4,
#    'Humidity': 77,
#    'Cloudiness': 75,
#    'Wind Speed': 20.71,
#    'Country': 'PT',
#    'Date': 1632684128},
#   {'City': 'San Cristobal',
#    'Lat': 7.7669,
#    'Lng': -72.225,
#    'Max Temp': 93.38,
#    'Humidity': 39,
#    'Cloudiness': 76,
#    'Wind Speed': 8.57,
#    'Country': 'VE',
#    'Date': 1632684156},
#   {'City': 'Chardara',
#    'Lat': 41.2547,
#    'Lng': 67.9692,
#    'Max Temp': 73.71,
#    'Humidity': 21,
#    'Cloudiness': 0,
#    'Wind Speed': 10.27,
#    'Country': 'KZ',
#    'Date': 1632684156},
#   {'City': 'Berlevåg',
#    'Lat': 70.8578,
#    'Lng': 29.0864,
#    'Max Temp': 48.2,
#    'Humidity': 81,
#    'Cloudiness': 75,
#    'Wind Speed': 12.66,
#    'Country': 'NO',
#    'Date': 1632684156},
#   {'City': 'Bengkulu',
#    'Lat': -3.8004,
#    'Lng': 102.2655,
#    'Max Temp': 75.38,
#    'Humidity': 89,
#    'Cloudiness': 100,
#    'Wind Speed': 3.65,
#    'Country': 'ID',
#    'Date': 1632684077},
#   {'City': 'Salta',
#    'Lat': -24.7859,
#    'Lng': -65.4117,
#    'Max Temp': 90.19,
#    'Humidity': 17,
#    'Cloudiness': 0,
#    'Wind Speed': 8.99,
#    'Country': 'AR',
#    'Date': 1632684156},
#   {'City': 'Lata',
#    'Lat': 40.1629,
#    'Lng': -8.3327,
#    'Max Temp': 69.04,
#    'Humidity': 85,
#    'Cloudiness': 100,
#    'Wind Speed': 1.79,
#    'Country': 'PT',
#    'Date': 1632684157},
#   {'City': 'Constitución',
#    'Lat': -35.3333,
#    'Lng': -72.4167,
#    'Max Temp': 59.27,
#    'Humidity': 56,
#    'Cloudiness': 62,
#    'Wind Speed': 17.16,
#    'Country': 'CL',
#    'Date': 1632684056},
#   {'City': 'Launceston',
#    'Lat': -41.45,
#    'Lng': 147.1667,
#    'Max Temp': 37.62,
#    'Humidity': 92,
#    'Cloudiness': 75,
#    'Wind Speed': 5.75,
#    'Country': 'AU',
#    'Date': 1632684157},
#   {'City': 'Kapaa',
#    'Lat': 22.0752,
#    'Lng': -159.319,
#    'Max Temp': 80.92,
#    'Humidity': 78,
#    'Cloudiness': 20,
#    'Wind Speed': 4,
#    'Country': 'US',
#    'Date': 1632683862},
#   {'City': 'Puerto del Rosario',
#    'Lat': 28.5004,
#    'Lng': -13.8627,
#    'Max Temp': 74.95,
#    'Humidity': 78,
#    'Cloudiness': 20,
#    'Wind Speed': 12.66,
#    'Country': 'ES',
#    'Date': 1632684158},
#   {'City': 'Bjørnevatn',
#    'Lat': 69.6672,
#    'Lng': 29.9847,
#    'Max Temp': 47.82,
#    'Humidity': 76,
#    'Cloudiness': 20,
#    'Wind Speed': 18.41,
#    'Country': 'NO',
#    'Date': 1632684158},
#   {'City': 'Taksimo',
#    'Lat': 56.3444,
#    'Lng': 114.8794,
#    'Max Temp': 39.81,
#    'Humidity': 95,
#    'Cloudiness': 100,
#    'Wind Speed': 4.72,
#    'Country': 'RU',
#    'Date': 1632684158},
#   {'City': 'Aklavik',
#    'Lat': 68.2191,
#    'Lng': -135.0107,
#    'Max Temp': 32,
#    'Humidity': 74,
#    'Cloudiness': 75,
#    'Wind Speed': 3.44,
#    'Country': 'CA',
#    'Date': 1632684158},
#   {'City': 'La Providencia',
#    'Lat': 28.7167,
#    'Lng': -111.5833,
#    'Max Temp': 94.6,
#    'Humidity': 49,
#    'Cloudiness': 6,
#    'Wind Speed': 5.01,
#    'Country': 'MX',
#    'Date': 1632684159},
#   {'City': 'Lebu',
#    'Lat': -37.6167,
#    'Lng': -73.65,
#    'Max Temp': 52.02,
#    'Humidity': 58,
#    'Cloudiness': 79,
#    'Wind Speed': 21.21,
#    'Country': 'CL',
#    'Date': 1632684159},
#   {'City': 'Gimli',
#    'Lat': 50.6336,
#    'Lng': -96.9907,
#    'Max Temp': 68.43,
#    'Humidity': 72,
#    'Cloudiness': 6,
#    'Wind Speed': 13.8,
#    'Country': 'CA',
#    'Date': 1632684159},
#   {'City': 'Khatanga',
#    'Lat': 71.9667,
#    'Lng': 102.5,
#    'Max Temp': 32.09,
#    'Humidity': 86,
#    'Cloudiness': 100,
#    'Wind Speed': 8.14,
#    'Country': 'RU',
#    'Date': 1632683868},
#   {'City': 'Alice Springs',
#    'Lat': -23.7,
#    'Lng': 133.8833,
#    'Max Temp': 65.75,
#    'Humidity': 19,
#    'Cloudiness': 3,
#    'Wind Speed': 9.22,
#    'Country': 'AU',
#    'Date': 1632683870},
#   {'City': 'Skjervøy',
#    'Lat': 70.0311,
#    'Lng': 20.9714,
#    'Max Temp': 48.67,
#    'Humidity': 81,
#    'Cloudiness': 100,
#    'Wind Speed': 9.1,
#    'Country': 'NO',
#    'Date': 1632684133},
#   {'City': 'Dosso',
#    'Lat': 13.049,
#    'Lng': 3.1937,
#    'Max Temp': 90.18,
#    'Humidity': 33,
#    'Cloudiness': 100,
#    'Wind Speed': 7.29,
#    'Country': 'NE',
#    'Date': 1632684160},
#   {'City': 'Madera',
#    'Lat': 37.1666,
#    'Lng': -119.8343,
#    'Max Temp': 91.87,
#    'Humidity': 33,
#    'Cloudiness': 19,
#    'Wind Speed': 1.99,
#    'Country': 'US',
#    'Date': 1632684046},
#   {'City': 'Moree',
#    'Lat': -29.4667,
#    'Lng': 149.85,
#    'Max Temp': 50.02,
#    'Humidity': 76,
#    'Cloudiness': 0,
#    'Wind Speed': 9.22,
#    'Country': 'AU',
#    'Date': 1632684160},
#   {'City': 'Masuguru',
#    'Lat': -11.3667,
#    'Lng': 38.4167,
#    'Max Temp': 81.05,
#    'Humidity': 48,
#    'Cloudiness': 80,
#    'Wind Speed': 10.04,
#    'Country': 'TZ',
#    'Date': 1632684160},
#   {'City': 'Hong Kong',
#    'Lat': 22.2855,
#    'Lng': 114.1577,
#    'Max Temp': 84.33,
#    'Humidity': 79,
#    'Cloudiness': 8,
#    'Wind Speed': 1.01,
#    'Country': 'HK',
#    'Date': 1632683865},
#   {'City': 'Evensk',
#    'Lat': 61.95,
#    'Lng': 159.2333,
#    'Max Temp': 36.32,
#    'Humidity': 79,
#    'Cloudiness': 71,
#    'Wind Speed': 10,
#    'Country': 'RU',
#    'Date': 1632684135},
#   {'City': 'Kuytun',
#    'Lat': 54.3419,
#    'Lng': 101.5036,
#    'Max Temp': 30.49,
#    'Humidity': 71,
#    'Cloudiness': 15,
#    'Wind Speed': 2.89,
#    'Country': 'RU',
#    'Date': 1632684211},
#   {'City': 'Beidao',
#    'Lat': 34.5686,
#    'Lng': 105.8933,
#    'Max Temp': 58.32,
#    'Humidity': 87,
#    'Cloudiness': 100,
#    'Wind Speed': 2.64,
#    'Country': 'CN',
#    'Date': 1632684211},
#   {'City': 'Kupang',
#    'Lat': -10.1667,
#    'Lng': 123.5833,
#    'Max Temp': 75.6,
#    'Humidity': 83,
#    'Cloudiness': 67,
#    'Wind Speed': 6.53,
#    'Country': 'ID',
#    'Date': 1632684211},
#   {'City': 'Sitka',
#    'Lat': 57.0531,
#    'Lng': -135.33,
#    'Max Temp': 53.49,
#    'Humidity': 66,
#    'Cloudiness': 40,
#    'Wind Speed': 5.75,
#    'Country': 'US',
#    'Date': 1632684212},
#   {'City': 'Urdoma',
#    'Lat': 61.7533,
#    'Lng': 48.5442,
#    'Max Temp': 43.11,
#    'Humidity': 95,
#    'Cloudiness': 100,
#    'Wind Speed': 7.23,
#    'Country': 'RU',
#    'Date': 1632684212},
#   {'City': 'Hirara',
#    'Lat': 24.8,
#    'Lng': 125.2833,
#    'Max Temp': 82.96,
#    'Humidity': 79,
#    'Cloudiness': 2,
#    'Wind Speed': 12.37,
#    'Country': 'JP',
#    'Date': 1632684212},
#   {'City': 'Āsosa',
#    'Lat': 10.0667,
#    'Lng': 34.5333,
#    'Max Temp': 58.55,
#    'Humidity': 90,
#    'Cloudiness': 30,
#    'Wind Speed': 3.89,
#    'Country': 'ET',
#    'Date': 1632684213},
#   {'City': 'Christchurch',
#    'Lat': -43.5333,
#    'Lng': 172.6333,
#    'Max Temp': 41.32,
#    'Humidity': 91,
#    'Cloudiness': 90,
#    'Wind Speed': 1.99,
#    'Country': 'NZ',
#    'Date': 1632684000},
#   {'City': 'Quatre Cocos',
#    'Lat': -20.2078,
#    'Lng': 57.7625,
#    'Max Temp': 70.09,
#    'Humidity': 85,
#    'Cloudiness': 58,
#    'Wind Speed': 15.17,
#    'Country': 'MU',
#    'Date': 1632684213},
#   {'City': 'Troitskoye',
#    'Lat': 52.9821,
#    'Lng': 84.6757,
#    'Max Temp': 33.89,
#    'Humidity': 78,
#    'Cloudiness': 100,
#    'Wind Speed': 6.17,
#    'Country': 'RU',
#    'Date': 1632684213},
#   {'City': 'Ballina',
#    'Lat': -28.8667,
#    'Lng': 153.5667,
#    'Max Temp': 58.96,
#    'Humidity': 82,
#    'Cloudiness': 90,
#    'Wind Speed': 5.75,
#    'Country': 'AU',
#    'Date': 1632684214},
#   {'City': 'Carutapera',
#    'Lat': -1.195,
#    'Lng': -46.02,
#    'Max Temp': 84.99,
#    'Humidity': 62,
#    'Cloudiness': 51,
#    'Wind Speed': 11.05,
#    'Country': 'BR',
#    'Date': 1632684214},
#   {'City': 'Vao',
#    'Lat': -22.6667,
#    'Lng': 167.4833,
#    'Max Temp': 67.64,
#    'Humidity': 67,
#    'Cloudiness': 100,
#    'Wind Speed': 3.91,
#    'Country': 'NC',
#    'Date': 1632684214},
#   {'City': 'Chara',
#    'Lat': 56.9064,
#    'Lng': 118.2631,
#    'Max Temp': 42.28,
#    'Humidity': 97,
#    'Cloudiness': 100,
#    'Wind Speed': 1.57,
#    'Country': 'RU',
#    'Date': 1632684136},
#   {'City': 'Tiksi',
#    'Lat': 71.6872,
#    'Lng': 128.8694,
#    'Max Temp': 34.05,
#    'Humidity': 96,
#    'Cloudiness': 100,
#    'Wind Speed': 10.74,
#    'Country': 'RU',
#    'Date': 1632684214},
#   {'City': 'Tuatapere',
#    'Lat': -46.1333,
#    'Lng': 167.6833,
#    'Max Temp': 34.41,
#    'Humidity': 85,
#    'Cloudiness': 7,
#    'Wind Speed': 4.18,
#    'Country': 'NZ',
#    'Date': 1632683861},
#   {'City': 'Port Hedland',
#    'Lat': -20.3167,
#    'Lng': 118.5667,
#    'Max Temp': 64.45,
#    'Humidity': 82,
#    'Cloudiness': 6,
#    'Wind Speed': 6.91,
#    'Country': 'AU',
#    'Date': 1632684215},
#   {'City': 'Nanortalik',
#    'Lat': 60.1432,
#    'Lng': -45.2371,
#    'Max Temp': 39.56,
#    'Humidity': 68,
#    'Cloudiness': 10,
#    'Wind Speed': 4.59,
#    'Country': 'GL',
#    'Date': 1632684215},
#   {'City': 'Guerrero Negro',
#    'Lat': 27.9769,
#    'Lng': -114.0611,
#    'Max Temp': 75.15,
#    'Humidity': 60,
#    'Cloudiness': 6,
#    'Wind Speed': 15.12,
#    'Country': 'MX',
#    'Date': 1632684215},
#   {'City': 'Opuwo',
#    'Lat': -18.0607,
#    'Lng': 13.84,
#    'Max Temp': 75.07,
#    'Humidity': 30,
#    'Cloudiness': 1,
#    'Wind Speed': 8.66,
#    'Country': 'NA',
#    'Date': 1632684081},
#   {'City': 'Port Hardy',
#    'Lat': 50.6996,
#    'Lng': -127.4199,
#    'Max Temp': 55.58,
#    'Humidity': 88,
#    'Cloudiness': 75,
#    'Wind Speed': 18.41,
#    'Country': 'CA',
#    'Date': 1632684216},
#   {'City': 'Flin Flon',
#    'Lat': 54.7682,
#    'Lng': -101.865,
#    'Max Temp': 62.44,
#    'Humidity': 55,
#    'Cloudiness': 40,
#    'Wind Speed': 5.75,
#    'Country': 'CA',
#    'Date': 1632684216},
#   {'City': 'Praia da Vitória',
#    'Lat': 38.7333,
#    'Lng': -27.0667,
#    'Max Temp': 69.76,
#    'Humidity': 88,
#    'Cloudiness': 75,
#    'Wind Speed': 20.92,
#    'Country': 'PT',
#    'Date': 1632683988},
#   {'City': 'Yangi Marg`ilon',
#    'Lat': 40.4272,
#    'Lng': 71.7189,
#    'Max Temp': 66.92,
#    'Humidity': 27,
#    'Cloudiness': 0,
#    'Wind Speed': 11.5,
#    'Country': 'UZ',
#    'Date': 1632684216},
#   {'City': 'Airai',
#    'Lat': -8.9266,
#    'Lng': 125.4092,
#    'Max Temp': 57.79,
#    'Humidity': 74,
#    'Cloudiness': 69,
#    'Wind Speed': 2.44,
#    'Country': 'TL',
#    'Date': 1632684217},
#   {'City': 'Amasya Province',
#    'Lat': 40.6667,
#    'Lng': 35.8333,
#    'Max Temp': 56.88,
#    'Humidity': 72,
#    'Cloudiness': 3,
#    'Wind Speed': 3.71,
#    'Country': 'TR',
#    'Date': 1632684217},
#   {'City': 'Qandala',
#    'Lat': 11.472,
#    'Lng': 49.8728,
#    'Max Temp': 89.02,
#    'Humidity': 55,
#    'Cloudiness': 0,
#    'Wind Speed': 4.21,
#    'Country': 'SO',
#    'Date': 1632684217},
#   {'City': 'Salalah',
#    'Lat': 17.0151,
#    'Lng': 54.0924,
#    'Max Temp': 84.29,
#    'Humidity': 84,
#    'Cloudiness': 75,
#    'Wind Speed': 9.22,
#    'Country': 'OM',
#    'Date': 1632684217},
#   {'City': 'Rumuruti',
#    'Lat': 0.267,
#    'Lng': 36.5389,
#    'Max Temp': 65.17,
#    'Humidity': 64,
#    'Cloudiness': 94,
#    'Wind Speed': 3.56,
#    'Country': 'KE',
#    'Date': 1632684218},
#   {'City': 'Fortuna',
#    'Lat': 40.5982,
#    'Lng': -124.1573,
#    'Max Temp': 66.92,
#    'Humidity': 68,
#    'Cloudiness': 1,
#    'Wind Speed': 4,
#    'Country': 'US',
#    'Date': 1632684218},
#   {'City': 'Örnsköldsvik',
#    'Lat': 63.2909,
#    'Lng': 18.7153,
#    'Max Temp': 47.35,
#    'Humidity': 100,
#    'Cloudiness': 90,
#    'Wind Speed': 2.3,
#    'Country': 'SE',
#    'Date': 1632684164},
#   {'City': 'Los Llanos de Aridane',
#    'Lat': 28.6585,
#    'Lng': -17.9182,
#    'Max Temp': 71.35,
#    'Humidity': 85,
#    'Cloudiness': 75,
#    'Wind Speed': 10.36,
#    'Country': 'ES',
#    'Date': 1632684218},
#   {'City': 'Thompson',
#    'Lat': 55.7435,
#    'Lng': -97.8558,
#    'Max Temp': 60.96,
#    'Humidity': 59,
#    'Cloudiness': 40,
#    'Wind Speed': 9.22,
#    'Country': 'CA',
#    'Date': 1632683920},
#   {'City': 'Dikson',
#    'Lat': 73.5069,
#    'Lng': 80.5464,
#    'Max Temp': 36.54,
#    'Humidity': 85,
#    'Cloudiness': 100,
#    'Wind Speed': 21.61,
#    'Country': 'RU',
#    'Date': 1632683869},
#   {'City': 'Ponta do Sol',
#    'Lat': 32.6667,
#    'Lng': -17.1,
#    'Max Temp': 75,
#    'Humidity': 72,
#    'Cloudiness': 58,
#    'Wind Speed': 1.28,
#    'Country': 'PT',
#    'Date': 1632684080},
#   {'City': 'Kruisfontein',
#    'Lat': -34.0033,
#    'Lng': 24.7314,
#    'Max Temp': 60.89,
#    'Humidity': 94,
#    'Cloudiness': 64,
#    'Wind Speed': 8.72,
#    'Country': 'ZA',
#    'Date': 1632684191},
#   {'City': 'Gboko',
#    'Lat': 7.3179,
#    'Lng': 8.9951,
#    'Max Temp': 76.28,
#    'Humidity': 85,
#    'Cloudiness': 100,
#    'Wind Speed': 7.29,
#    'Country': 'NG',
#    'Date': 1632684219},
#   {'City': 'Marsh Harbour',
#    'Lat': 26.5412,
#    'Lng': -77.0636,
#    'Max Temp': 81.25,
#    'Humidity': 66,
#    'Cloudiness': 74,
#    'Wind Speed': 14,
#    'Country': 'BS',
#    'Date': 1632684031},
#   {'City': 'Winslow',
#    'Lat': 35.0242,
#    'Lng': -110.6974,
#    'Max Temp': 63.97,
#    'Humidity': 71,
#    'Cloudiness': 90,
#    'Wind Speed': 1.99,
#    'Country': 'US',
#    'Date': 1632684219},
#   {'City': 'Coro',
#    'Lat': 11.4045,
#    'Lng': -69.6734,
#    'Max Temp': 92.52,
#    'Humidity': 56,
#    'Cloudiness': 13,
#    'Wind Speed': 20.67,
#    'Country': 'VE',
#    'Date': 1632684220},
#   {'City': 'Ketchikan',
#    'Lat': 55.3422,
#    'Lng': -131.6461,
#    'Max Temp': 50.47,
#    'Humidity': 81,
#    'Cloudiness': 90,
#    'Wind Speed': 6.91,
#    'Country': 'US',
#    'Date': 1632684044},
#   {'City': 'Bermejo',
#    'Lat': -32.8833,
#    'Lng': -68.8,
#    'Max Temp': 67.91,
#    'Humidity': 28,
#    'Cloudiness': 0,
#    'Wind Speed': 6.91,
#    'Country': 'AR',
#    'Date': 1632684220},
#   {'City': 'Dickinson',
#    'Lat': 29.4608,
#    'Lng': -95.0513,
#    'Max Temp': 87.22,
#    'Humidity': 60,
#    'Cloudiness': 20,
#    'Wind Speed': 1.01,
#    'Country': 'US',
#    'Date': 1632683991},
#   {'City': 'Kloulklubed',
#    'Lat': 7.0419,
#    'Lng': 134.2556,
#    'Max Temp': 83.21,
#    'Humidity': 77,
#    'Cloudiness': 59,
#    'Wind Speed': 10.02,
#    'Country': 'PW',
#    'Date': 1632684220},
#   {'City': 'Sunrise Manor',
#    'Lat': 36.2111,
#    'Lng': -115.0731,
#    'Max Temp': 92.82,
#    'Humidity': 29,
#    'Cloudiness': 1,
#    'Wind Speed': 4.61,
#    'Country': 'US',
#    'Date': 1632684221},
#   {'City': 'Panzhihua',
#    'Lat': 26.5851,
#    'Lng': 101.7128,
#    'Max Temp': 68.25,
#    'Humidity': 88,
#    'Cloudiness': 98,
#    'Wind Speed': 0.47,
#    'Country': 'CN',
#    'Date': 1632684271},
#   {'City': 'Kampot',
#    'Lat': 10.6167,
#    'Lng': 104.1833,
#    'Max Temp': 77.05,
#    'Humidity': 93,
#    'Cloudiness': 100,
#    'Wind Speed': 3.31,
#    'Country': 'KH',
#    'Date': 1632684271},
#   {'City': 'Peoria',
#    'Lat': 40.7667,
#    'Lng': -89.7668,
#    'Max Temp': 84.61,
#    'Humidity': 34,
#    'Cloudiness': 1,
#    'Wind Speed': 16.11,
#    'Country': 'US',
#    'Date': 1632683993},
#   {'City': 'Graham',
#    'Lat': 47.0529,
#    'Lng': -122.2943,
#    'Max Temp': 65.14,
#    'Humidity': 70,
#    'Cloudiness': 90,
#    'Wind Speed': 0,
#    'Country': 'US',
#    'Date': 1632684086},
#   {'City': 'Kavieng',
#    'Lat': -2.5744,
#    'Lng': 150.7967,
#    'Max Temp': 81.25,
#    'Humidity': 79,
#    'Cloudiness': 100,
#    'Wind Speed': 6.78,
#    'Country': 'PG',
#    'Date': 1632684192},
#   {'City': 'Provideniya',
#    'Lat': 64.3833,
#    'Lng': -173.3,
#    'Max Temp': 37.51,
#    'Humidity': 81,
#    'Cloudiness': 75,
#    'Wind Speed': 11.18,
#    'Country': 'RU',
#    'Date': 1632684271},
#   {'City': 'Lavrentiya',
#    'Lat': 65.5833,
#    'Lng': -171,
#    'Max Temp': 30.06,
#    'Humidity': 80,
#    'Cloudiness': 97,
#    'Wind Speed': 6.49,
#    'Country': 'RU',
#    'Date': 1632684272},
#   {'City': 'Wajima',
#    'Lat': 37.4,
#    'Lng': 136.9,
#    'Max Temp': 68.38,
#    'Humidity': 83,
#    'Cloudiness': 9,
#    'Wind Speed': 3,
#    'Country': 'JP',
#    'Date': 1632684272},
#   {'City': 'Dunedin',
#    'Lat': -45.8742,
#    'Lng': 170.5036,
#    'Max Temp': 36.81,
#    'Humidity': 83,
#    'Cloudiness': 9,
#    'Wind Speed': 4.72,
#    'Country': 'NZ',
#    'Date': 1632684272},
#   {'City': 'Narodychi',
#    'Lat': 51.2029,
#    'Lng': 29.0823,
#    'Max Temp': 48.6,
#    'Humidity': 83,
#    'Cloudiness': 0,
#    'Wind Speed': 6.51,
#    'Country': 'UA',
#    'Date': 1632684273},
#   {'City': 'Fare',
#    'Lat': -16.7,
#    'Lng': -151.0167,
#    'Max Temp': 79.14,
#    'Humidity': 77,
#    'Cloudiness': 5,
#    'Wind Speed': 14.38,
#    'Country': 'PF',
#    'Date': 1632684273},
#   {'City': 'Chitungwiza',
#    'Lat': -18.0127,
#    'Lng': 31.0756,
#    'Max Temp': 67.44,
#    'Humidity': 35,
#    'Cloudiness': 19,
#    'Wind Speed': 7.18,
#    'Country': 'ZW',
#    'Date': 1632684273},
#   {'City': 'Damara',
#    'Lat': 4.9608,
#    'Lng': 18.7035,
#    'Max Temp': 76.42,
#    'Humidity': 92,
#    'Cloudiness': 29,
#    'Wind Speed': 1.39,
#    'Country': 'CF',
#    'Date': 1632684274},
#   {'City': 'Sobolevo',
#    'Lat': 54.4299,
#    'Lng': 31.8996,
#    'Max Temp': 44.29,
#    'Humidity': 95,
#    'Cloudiness': 14,
#    'Wind Speed': 10.83,
#    'Country': 'RU',
#    'Date': 1632684274},
#   {'City': 'Esperance',
#    'Lat': -33.8667,
#    'Lng': 121.9,
#    'Max Temp': 56.21,
#    'Humidity': 89,
#    'Cloudiness': 40,
#    'Wind Speed': 16.33,
#    'Country': 'AU',
#    'Date': 1632684127},
#   {'City': 'Ilulissat',
#    'Lat': 69.2167,
#    'Lng': -51.1,
#    'Max Temp': 21.22,
#    'Humidity': 49,
#    'Cloudiness': 0,
#    'Wind Speed': 4.61,
#    'Country': 'GL',
#    'Date': 1632684253},
#   {'City': 'Mataura',
#    'Lat': -46.1927,
#    'Lng': 168.8643,
#    'Max Temp': 30.04,
#    'Humidity': 97,
#    'Cloudiness': 4,
#    'Wind Speed': 2.39,
#    'Country': 'NZ',
#    'Date': 1632684274},
#   {'City': 'Saint George',
#    'Lat': 37.1041,
#    'Lng': -113.5841,
#    'Max Temp': 88.54,
#    'Humidity': 27,
#    'Cloudiness': 98,
#    'Wind Speed': 1.99,
#    'Country': 'US',
#    'Date': 1632684180},
#   {'City': 'Port Elizabeth',
#    'Lat': -33.918,
#    'Lng': 25.5701,
#    'Max Temp': 64.69,
#    'Humidity': 88,
#    'Cloudiness': 90,
#    'Wind Speed': 0,
#    'Country': 'ZA',
#    'Date': 1632684006},
#   {'City': 'Kailua',
#    'Lat': 21.4022,
#    'Lng': -157.7394,
#    'Max Temp': 87.78,
#    'Humidity': 75,
#    'Cloudiness': 90,
#    'Wind Speed': 10.36,
#    'Country': 'US',
#    'Date': 1632684275},
#   {'City': 'Rocha',
#    'Lat': -34.4833,
#    'Lng': -54.3333,
#    'Max Temp': 69.35,
#    'Humidity': 64,
#    'Cloudiness': 2,
#    'Wind Speed': 7.11,
#    'Country': 'UY',
#    'Date': 1632684275},
#   {'City': 'East London',
#    'Lat': -33.0153,
#    'Lng': 27.9116,
#    'Max Temp': 67.57,
#    'Humidity': 77,
#    'Cloudiness': 69,
#    'Wind Speed': 14.41,
#    'Country': 'ZA',
#    'Date': 1632684010},
#   {'City': 'Qaanaaq',
#    'Lat': 77.484,
#    'Lng': -69.3632,
#    'Max Temp': 20.52,
#    'Humidity': 67,
#    'Cloudiness': 20,
#    'Wind Speed': 6.87,
#    'Country': 'GL',
#    'Date': 1632683861},
#   {'City': 'Pastavy',
#    'Lat': 55.1168,
#    'Lng': 26.8326,
#    'Max Temp': 45.46,
#    'Humidity': 83,
#    'Cloudiness': 9,
#    'Wind Speed': 5.01,
#    'Country': 'BY',
#    'Date': 1632684276},
#   {'City': 'Qaqortoq',
#    'Lat': 60.7167,
#    'Lng': -46.0333,
#    'Max Temp': 45.1,
#    'Humidity': 53,
#    'Cloudiness': 1,
#    'Wind Speed': 0.78,
#    'Country': 'GL',
#    'Date': 1632684276},
#   {'City': 'Puta',
#    'Lat': 40.2967,
#    'Lng': 49.6603,
#    'Max Temp': 59.02,
#    'Humidity': 57,
#    'Cloudiness': 8,
#    'Wind Speed': 8.7,
#    'Country': 'AZ',
#    'Date': 1632684276},
#   {'City': 'São Filipe',
#    'Lat': 14.8961,
#    'Lng': -24.4956,
#    'Max Temp': 79.43,
#    'Humidity': 75,
#    'Cloudiness': 44,
#    'Wind Speed': 5.88,
#    'Country': 'CV',
#    'Date': 1632683862},
#   {'City': 'Caravelas',
#    'Lat': -17.7125,
#    'Lng': -39.2481,
#    'Max Temp': 76.77,
#    'Humidity': 59,
#    'Cloudiness': 100,
#    'Wind Speed': 9.33,
#    'Country': 'BR',
#    'Date': 1632684277},
#   {'City': 'General Pico',
#    'Lat': -35.6566,
#    'Lng': -63.7568,
#    'Max Temp': 67.64,
#    'Humidity': 30,
#    'Cloudiness': 24,
#    'Wind Speed': 13.89,
#    'Country': 'AR',
#    'Date': 1632684277},
#   {'City': 'Lorengau',
#    'Lat': -2.0226,
#    'Lng': 147.2712,
#    'Max Temp': 80.65,
#    'Humidity': 82,
#    'Cloudiness': 100,
#    'Wind Speed': 8.34,
#    'Country': 'PG',
#    'Date': 1632684277},
#   {'City': 'Pamekasan',
#    'Lat': -7.1568,
#    'Lng': 113.4746,
#    'Max Temp': 79.02,
#    'Humidity': 82,
#    'Cloudiness': 12,
#    'Wind Speed': 1.95,
#    'Country': 'ID',
#    'Date': 1632684277},
#   {'City': 'Cabo San Lucas',
#    'Lat': 22.8909,
#    'Lng': -109.9124,
#    'Max Temp': 94.6,
#    'Humidity': 66,
#    'Cloudiness': 7,
#    'Wind Speed': 1.01,
#    'Country': 'MX',
#    'Date': 1632683672},
#   {'City': 'Mount Isa',
#    'Lat': -20.7333,
#    'Lng': 139.5,
#    'Max Temp': 69.57,
#    'Humidity': 18,
#    'Cloudiness': 0,
#    'Wind Speed': 3.44,
#    'Country': 'AU',
#    'Date': 1632684278},
#   {'City': 'Mariental',
#    'Lat': -24.6333,
#    'Lng': 17.9667,
#    'Max Temp': 83.12,
#    'Humidity': 11,
#    'Cloudiness': 100,
#    'Wind Speed': 6.24,
#    'Country': 'NA',
#    'Date': 1632684278},
#   {'City': 'São Gabriel da Cachoeira',
#    'Lat': -0.1303,
#    'Lng': -67.0892,
#    'Max Temp': 85.8,
#    'Humidity': 74,
#    'Cloudiness': 20,
#    'Wind Speed': 9.22,
#    'Country': 'BR',
#    'Date': 1632684224},
#   {'City': 'Bichena',
#    'Lat': 10.45,
#    'Lng': 38.2,
#    'Max Temp': 51.67,
#    'Humidity': 83,
#    'Cloudiness': 13,
#    'Wind Speed': 4.92,
#    'Country': 'ET',
#    'Date': 1632684278},
#   {'City': 'Hasaki',
#    'Lat': 35.7333,
#    'Lng': 140.8333,
#    'Max Temp': 64.8,
#    'Humidity': 70,
#    'Cloudiness': 4,
#    'Wind Speed': 13.94,
#    'Country': 'JP',
#    'Date': 1632684279},
#   {'City': 'Pevek',
#    'Lat': 69.7008,
#    'Lng': 170.3133,
#    'Max Temp': 30.51,
#    'Humidity': 96,
#    'Cloudiness': 100,
#    'Wind Speed': 15.99,
#    'Country': 'RU',
#    'Date': 1632684279},
#   {'City': 'Talcahuano',
#    'Lat': -36.7167,
#    'Lng': -73.1167,
#    'Max Temp': 58.68,
#    'Humidity': 55,
#    'Cloudiness': 0,
#    'Wind Speed': 21.85,
#    'Country': 'CL',
#    'Date': 1632684279},
#   {'City': 'San Borja',
#    'Lat': -14.8167,
#    'Lng': -66.85,
#    'Max Temp': 104.4,
#    'Humidity': 20,
#    'Cloudiness': 68,
#    'Wind Speed': 8.25,
#    'Country': 'BO',
#    'Date': 1632684279},
#   {'City': 'Nizwá',
#    'Lat': 22.9333,
#    'Lng': 57.5333,
#    'Max Temp': 88.9,
#    'Humidity': 40,
#    'Cloudiness': 93,
#    'Wind Speed': 9.53,
#    'Country': 'OM',
#    'Date': 1632684280},
#   {'City': 'La Rioja',
#    'Lat': 42.25,
#    'Lng': -2.5,
#    'Max Temp': 62.49,
#    'Humidity': 66,
#    'Cloudiness': 64,
#    'Wind Speed': 4.79,
#    'Country': 'ES',
#    'Date': 1632684280},
#   {'City': 'Saint-Pierre',
#    'Lat': -21.3393,
#    'Lng': 55.4781,
#    'Max Temp': 71.28,
#    'Humidity': 79,
#    'Cloudiness': 40,
#    'Wind Speed': 6.91,
#    'Country': 'RE',
#    'Date': 1632684280},
#   {'City': 'Kamaishi',
#    'Lat': 39.2667,
#    'Lng': 141.8833,
#    'Max Temp': 63.21,
#    'Humidity': 76,
#    'Cloudiness': 70,
#    'Wind Speed': 5.84,
#    'Country': 'JP',
#    'Date': 1632684281},
#   {'City': 'Privolzhye',
#    'Lat': 52.8649,
#    'Lng': 48.6044,
#    'Max Temp': 50.99,
#    'Humidity': 91,
#    'Cloudiness': 100,
#    'Wind Speed': 3.78,
#    'Country': 'RU',
#    'Date': 1632684281},
#   {'City': 'Paamiut',
#    'Lat': 61.994,
#    'Lng': -49.6678,
#    'Max Temp': 35.92,
#    'Humidity': 50,
#    'Cloudiness': 7,
#    'Wind Speed': 5.53,
#    'Country': 'GL',
#    'Date': 1632684331},
#   {'City': 'Gushikawa',
#    'Lat': 26.3544,
#    'Lng': 127.8686,
#    'Max Temp': 79.83,
#    'Humidity': 94,
#    'Cloudiness': 1,
#    'Wind Speed': 6.91,
#    'Country': 'JP',
#    'Date': 1632684331},
#   {'City': 'Geraldton',
#    'Lat': -28.7667,
#    'Lng': 114.6,
#    'Max Temp': 62.13,
#    'Humidity': 82,
#    'Cloudiness': 90,
#    'Wind Speed': 10.36,
#    'Country': 'AU',
#    'Date': 1632684331},
#   {'City': 'Lüderitz',
#    'Lat': -26.6481,
#    'Lng': 15.1594,
#    'Max Temp': 58.05,
#    'Humidity': 92,
#    'Cloudiness': 87,
#    'Wind Speed': 13.35,
#    'Country': 'NA',
#    'Date': 1632684332},
#   {'City': 'Poum',
#    'Lat': -20.2333,
#    'Lng': 164.0167,
#    'Max Temp': 71.65,
#    'Humidity': 70,
#    'Cloudiness': 69,
#    'Wind Speed': 8.14,
#    'Country': 'NC',
#    'Date': 1632683867},
#   {'City': 'Volkhov',
#    'Lat': 59.9258,
#    'Lng': 32.3382,
#    'Max Temp': 48.78,
#    'Humidity': 95,
#    'Cloudiness': 97,
#    'Wind Speed': 4.61,
#    'Country': 'RU',
#    'Date': 1632684332},
#   {'City': 'Truth or Consequences',
#    'Lat': 33.1284,
#    'Lng': -107.2528,
#    'Max Temp': 76.91,
#    'Humidity': 56,
#    'Cloudiness': 1,
#    'Wind Speed': 6.91,
#    'Country': 'US',
#    'Date': 1632684300},
#   {'City': 'Okhotsk',
#    'Lat': 59.3833,
#    'Lng': 143.3,
#    'Max Temp': 40.98,
#    'Humidity': 65,
#    'Cloudiness': 5,
#    'Wind Speed': 9.6,
#    'Country': 'RU',
#    'Date': 1632684332},
#   {'City': 'Bhanjanagar',
#    'Lat': 19.9333,
#    'Lng': 84.5833,
#    'Max Temp': 76.95,
#    'Humidity': 96,
#    'Cloudiness': 100,
#    'Wind Speed': 8.25,
#    'Country': 'IN',
#    'Date': 1632684332},
#   {'City': 'West Bay',
#    'Lat': 19.3667,
#    'Lng': -81.4167,
#    'Max Temp': 87.87,
#    'Humidity': 66,
#    'Cloudiness': 40,
#    'Wind Speed': 7.65,
#    'Country': 'KY',
#    'Date': 1632684333},
#   {'City': 'Ancud',
#    'Lat': -41.8697,
#    'Lng': -73.8203,
#    'Max Temp': 51.33,
#    'Humidity': 62,
#    'Cloudiness': 29,
#    'Wind Speed': 9.13,
#    'Country': 'CL',
#    'Date': 1632684333},
#   {'City': 'Taltal',
#    'Lat': -25.4,
#    'Lng': -70.4833,
#    'Max Temp': 65.66,
#    'Humidity': 64,
#    'Cloudiness': 24,
#    'Wind Speed': 7.09,
#    'Country': 'CL',
#    'Date': 1632684333},
#   {'City': 'Sibolga',
#    'Lat': 1.7427,
#    'Lng': 98.7792,
#    'Max Temp': 76.03,
#    'Humidity': 93,
#    'Cloudiness': 100,
#    'Wind Speed': 5.68,
#    'Country': 'ID',
#    'Date': 1632684334},
#   {'City': 'Sturgis',
#    'Lat': 41.7992,
#    'Lng': -85.4192,
#    'Max Temp': 78.6,
#    'Humidity': 41,
#    'Cloudiness': 1,
#    'Wind Speed': 14.97,
#    'Country': 'US',
#    'Date': 1632684059},
#   {'City': 'Nhulunbuy',
#    'Lat': -12.2333,
#    'Lng': 136.7667,
#    'Max Temp': 74.01,
#    'Humidity': 94,
#    'Cloudiness': 29,
#    'Wind Speed': 0,
#    'Country': 'AU',
#    'Date': 1632684315},
#   {'City': 'Bagdarin',
#    'Lat': 54.4333,
#    'Lng': 113.6,
#    'Max Temp': 31.71,
#    'Humidity': 91,
#    'Cloudiness': 76,
#    'Wind Speed': 4.41,
#    'Country': 'RU',
#    'Date': 1632684334},
#   {'City': 'Iqaluit',
#    'Lat': 63.7506,
#    'Lng': -68.5145,
#    'Max Temp': 37.13,
#    'Humidity': 74,
#    'Cloudiness': 75,
#    'Wind Speed': 18.99,
#    'Country': 'CA',
#    'Date': 1632683864},
#   {'City': 'Alto Araguaia',
#    'Lat': -17.3147,
#    'Lng': -53.2153,
#    'Max Temp': 86.41,
#    'Humidity': 34,
#    'Cloudiness': 72,
#    'Wind Speed': 4.29,
#    'Country': 'BR',
#    'Date': 1632684335},
#   {'City': 'Novyy Rogachik',
#    'Lat': 48.6768,
#    'Lng': 44.0608,
#    'Max Temp': 50.9,
#    'Humidity': 72,
#    'Cloudiness': 9,
#    'Wind Speed': 18.01,
#    'Country': 'RU',
#    'Date': 1632684335},
#   {'City': 'Bougouni',
#    'Lat': 11.417,
#    'Lng': -7.479,
#    'Max Temp': 79.57,
#    'Humidity': 71,
#    'Cloudiness': 41,
#    'Wind Speed': 4.81,
#    'Country': 'ML',
#    'Date': 1632684335},
#   {'City': 'Makakilo City',
#    'Lat': 21.3469,
#    'Lng': -158.0858,
#    'Max Temp': 86.32,
#    'Humidity': 61,
#    'Cloudiness': 1,
#    'Wind Speed': 10.36,
#    'Country': 'US',
#    'Date': 1632684335},
#   {'City': 'Touba',
#    'Lat': 8.2833,
#    'Lng': -7.6833,
#    'Max Temp': 71.33,
#    'Humidity': 93,
#    'Cloudiness': 100,
#    'Wind Speed': 3.06,
#    'Country': 'CI',
#    'Date': 1632684336},
#   {'City': 'Paita',
#    'Lat': -5.0892,
#    'Lng': -81.1144,
#    'Max Temp': 73.96,
#    'Humidity': 73,
#    'Cloudiness': 100,
#    'Wind Speed': 16.24,
#    'Country': 'PE',
#    'Date': 1632684336},
#   {'City': 'Esim',
#    'Lat': 4.8699,
#    'Lng': -2.2405,
#    'Max Temp': 75.36,
#    'Humidity': 91,
#    'Cloudiness': 100,
#    'Wind Speed': 6.93,
#    'Country': 'GH',
#    'Date': 1632684336},
#   {'City': 'Manokwari',
#    'Lat': -0.8667,
# ...
#    'Wind Speed': 8.5,
#    'Country': 'RU',
#    'Date': 1632684633},
#   {'City': 'Feijó',
#    'Lat': -8.1642,
#    'Lng': -70.3536,
#    'Max Temp': 87.33,
#    'Humidity': 53,
#    'Cloudiness': 96,
#    'Wind Speed': 2.48,
#    'Country': 'BR',
#    'Date': 1632684633},
#   {'City': 'Kenora',
#    'Lat': 49.8167,
#    'Lng': -94.4337,
#    'Max Temp': 68.97,
#    'Humidity': 40,
#    'Cloudiness': 20,
#    'Wind Speed': 8.05,
#    'Country': 'CA',
#    'Date': 1632684634},
#   {'City': 'Diffa',
#    'Lat': 13.3154,
#    'Lng': 12.6113,
#    'Max Temp': 90.43,
#    'Humidity': 18,
#    'Cloudiness': 10,
#    'Wind Speed': 5.7,
#    'Country': 'NE',
#    'Date': 1632684634},
#   {'City': 'Husavik',
#    'Lat': 66.0449,
#    'Lng': -17.3389,
#    'Max Temp': 40.91,
#    'Humidity': 99,
#    'Cloudiness': 100,
#    'Wind Speed': 29.82,
#    'Country': 'IS',
#    'Date': 1632684338},
#   {'City': 'Ust-Kuyga',
#    'Lat': 70.0167,
#    'Lng': 135.6,
#    'Max Temp': 33.26,
#    'Humidity': 98,
#    'Cloudiness': 100,
#    'Wind Speed': 12.59,
#    'Country': 'RU',
#    'Date': 1632684634},
#   {'City': 'Hobyo',
#    'Lat': 5.3505,
#    'Lng': 48.5268,
#    'Max Temp': 78.26,
#    'Humidity': 79,
#    'Cloudiness': 35,
#    'Wind Speed': 25.34,
#    'Country': 'SO',
#    'Date': 1632684634},
#   {'City': 'Saint-Augustin',
#    'Lat': 51.226,
#    'Lng': -58.6502,
#    'Max Temp': 57.16,
#    'Humidity': 98,
#    'Cloudiness': 100,
#    'Wind Speed': 4.5,
#    'Country': 'CA',
#    'Date': 1632684635},
#   {'City': 'Rockhampton',
#    'Lat': -23.3833,
#    'Lng': 150.5,
#    'Max Temp': 66.09,
#    'Humidity': 77,
#    'Cloudiness': 40,
#    'Wind Speed': 3.44,
#    'Country': 'AU',
#    'Date': 1632684635},
#   {'City': 'Chhatarpur',
#    'Lat': 24.9,
#    'Lng': 79.6,
#    'Max Temp': 79.72,
#    'Humidity': 78,
#    'Cloudiness': 80,
#    'Wind Speed': 6.69,
#    'Country': 'IN',
#    'Date': 1632684635},
#   {'City': 'Havøysund',
#    'Lat': 70.9963,
#    'Lng': 24.6622,
#    'Max Temp': 49.08,
#    'Humidity': 86,
#    'Cloudiness': 100,
#    'Wind Speed': 7.76,
#    'Country': 'NO',
#    'Date': 1632684636},
#   {'City': 'Ayorou',
#    'Lat': 14.7308,
#    'Lng': 0.9174,
#    'Max Temp': 97.32,
#    'Humidity': 17,
#    'Cloudiness': 13,
#    'Wind Speed': 5.08,
#    'Country': 'NE',
#    'Date': 1632684636},
#   {'City': 'Seoul',
#    'Lat': 37.5683,
#    'Lng': 126.9778,
#    'Max Temp': 69.24,
#    'Humidity': 73,
#    'Cloudiness': 0,
#    'Wind Speed': 4.61,
#    'Country': 'KR',
#    'Date': 1632684636},
#   {'City': 'Lida',
#    'Lat': 53.8833,
#    'Lng': 25.2997,
#    'Max Temp': 46.26,
#    'Humidity': 83,
#    'Cloudiness': 6,
#    'Wind Speed': 5.73,
#    'Country': 'BY',
#    'Date': 1632684637},
#   {'City': 'Pervomayskoye',
#    'Lat': 43.919,
#    'Lng': 46.7102,
#    'Max Temp': 59.11,
#    'Humidity': 55,
#    'Cloudiness': 18,
#    'Wind Speed': 9.4,
#    'Country': 'RU',
#    'Date': 1632684637},
#   {'City': 'Amoy',
#    'Lat': 24.4798,
#    'Lng': 118.0819,
#    'Max Temp': 81.25,
#    'Humidity': 83,
#    'Cloudiness': 0,
#    'Wind Speed': 4.47,
#    'Country': 'CN',
#    'Date': 1632684637},
#   {'City': 'Maumere',
#    'Lat': -8.6199,
#    'Lng': 122.2111,
#    'Max Temp': 76.91,
#    'Humidity': 82,
#    'Cloudiness': 24,
#    'Wind Speed': 5.61,
#    'Country': 'ID',
#    'Date': 1632684638},
#   {'City': 'Silver City',
#    'Lat': 32.7701,
#    'Lng': -108.2803,
#    'Max Temp': 70.92,
#    'Humidity': 58,
#    'Cloudiness': 75,
#    'Wind Speed': 8.05,
#    'Country': 'US',
#    'Date': 1632684638},
#   {'City': 'Te Anau',
#    'Lat': -45.4167,
#    'Lng': 167.7167,
#    'Max Temp': 34.7,
#    'Humidity': 81,
#    'Cloudiness': 15,
#    'Wind Speed': 0.85,
#    'Country': 'NZ',
#    'Date': 1632684638},
#   {'City': 'Lebedinyy',
#    'Lat': 58.5167,
#    'Lng': 125.5167,
#    'Max Temp': 41.27,
#    'Humidity': 81,
#    'Cloudiness': 100,
#    'Wind Speed': 5.73,
#    'Country': 'RU',
#    'Date': 1632684638},
#   {'City': 'Dwārka',
#    'Lat': 22.2394,
#    'Lng': 68.9678,
#    'Max Temp': 81.52,
#    'Humidity': 85,
#    'Cloudiness': 23,
#    'Wind Speed': 11.07,
#    'Country': 'IN',
#    'Date': 1632684639},
#   {'City': 'Lebanon',
#    'Lat': 36.2081,
#    'Lng': -86.2911,
#    'Max Temp': 81.03,
#    'Humidity': 44,
#    'Cloudiness': 1,
#    'Wind Speed': 4.61,
#    'Country': 'US',
#    'Date': 1632684396},
#   {'City': 'Luwingu',
#    'Lat': -10.2621,
#    'Lng': 29.9271,
#    'Max Temp': 74.17,
#    'Humidity': 31,
#    'Cloudiness': 72,
#    'Wind Speed': 4.79,
#    'Country': 'ZM',
#    'Date': 1632684639},
#   {'City': 'Quimper',
#    'Lat': 48,
#    'Lng': -4.1,
#    'Max Temp': 65.23,
#    'Humidity': 94,
#    'Cloudiness': 90,
#    'Wind Speed': 11.5,
#    'Country': 'FR',
#    'Date': 1632684639},
#   {'City': 'Luena',
#    'Lat': -11.7833,
#    'Lng': 19.9167,
#    'Max Temp': 67.26,
#    'Humidity': 43,
#    'Cloudiness': 27,
#    'Wind Speed': 5.08,
#    'Country': 'AO',
#    'Date': 1632684640},
#   {'City': 'Palmer',
#    'Lat': 42.1584,
#    'Lng': -72.3287,
#    'Max Temp': 72.77,
#    'Humidity': 42,
#    'Cloudiness': 40,
#    'Wind Speed': 1.01,
#    'Country': 'US',
#    'Date': 1632684407},
#   {'City': 'Havelock',
#    'Lat': 34.8791,
#    'Lng': -76.9013,
#    'Max Temp': 80.02,
#    'Humidity': 52,
#    'Cloudiness': 1,
#    'Wind Speed': 1.99,
#    'Country': 'US',
#    'Date': 1632684640},
#   {'City': 'Kota Belud',
#    'Lat': 6.351,
#    'Lng': 116.4305,
#    'Max Temp': 76.86,
#    'Humidity': 90,
#    'Cloudiness': 66,
#    'Wind Speed': 3.89,
#    'Country': 'MY',
#    'Date': 1632684640},
#   {'City': 'Mocuba',
#    'Lat': -16.8392,
#    'Lng': 36.9856,
#    'Max Temp': 73.09,
#    'Humidity': 74,
#    'Cloudiness': 2,
#    'Wind Speed': 4.92,
#    'Country': 'MZ',
#    'Date': 1632684641},
#   {'City': 'Smidovich',
#    'Lat': 48.6,
#    'Lng': 133.8167,
#    'Max Temp': 50.2,
#    'Humidity': 92,
#    'Cloudiness': 85,
#    'Wind Speed': 5.91,
#    'Country': 'RU',
#    'Date': 1632684641},
#   {'City': 'Tautira',
#    'Lat': -17.7333,
#    'Lng': -149.15,
#    'Max Temp': 82.42,
#    'Humidity': 76,
#    'Cloudiness': 7,
#    'Wind Speed': 13.8,
#    'Country': 'PF',
#    'Date': 1632684641},
#   {'City': 'Moerai',
#    'Lat': -22.4333,
#    'Lng': -151.3333,
#    'Max Temp': 75.7,
#    'Humidity': 86,
#    'Cloudiness': 100,
#    'Wind Speed': 11.14,
#    'Country': 'PF',
#    'Date': 1632684641},
#   {'City': 'Faya',
#    'Lat': 18.3851,
#    'Lng': 42.4509,
#    'Max Temp': 71.71,
#    'Humidity': 26,
#    'Cloudiness': 7,
#    'Wind Speed': 9.93,
#    'Country': 'SA',
#    'Date': 1632684642},
#   {'City': 'Viedma',
#    'Lat': -40.8135,
#    'Lng': -62.9967,
#    'Max Temp': 55.81,
#    'Humidity': 32,
#    'Cloudiness': 7,
#    'Wind Speed': 11.14,
#    'Country': 'AR',
#    'Date': 1632684623},
#   {'City': 'Nicoya',
#    'Lat': 10.1483,
#    'Lng': -85.452,
#    'Max Temp': 85.55,
#    'Humidity': 77,
#    'Cloudiness': 100,
#    'Wind Speed': 1.77,
#    'Country': 'CR',
#    'Date': 1632684642},
#   {'City': 'La Suiza',
#    'Lat': 9.8524,
#    'Lng': -83.6133,
#    'Max Temp': 78.3,
#    'Humidity': 94,
#    'Cloudiness': 100,
#    'Wind Speed': 3.62,
#    'Country': 'CR',
#    'Date': 1632684642},
#   {'City': 'Lazo',
#    'Lat': 43.3817,
#    'Lng': 133.9014,
#    'Max Temp': 54.18,
#    'Humidity': 96,
#    'Cloudiness': 14,
#    'Wind Speed': 1.1,
#    'Country': 'RU',
#    'Date': 1632684643},
#   {'City': 'Bolu Province',
#    'Lat': 40.6667,
#    'Lng': 31.5833,
#    'Max Temp': 54.72,
#    'Humidity': 63,
#    'Cloudiness': 0,
#    'Wind Speed': 2.15,
#    'Country': 'TR',
#    'Date': 1632684643},
#   {'City': 'Nagato',
#    'Lat': 34.3833,
#    'Lng': 131.2,
#    'Max Temp': 73.31,
#    'Humidity': 89,
#    'Cloudiness': 13,
#    'Wind Speed': 5.37,
#    'Country': 'JP',
#    'Date': 1632684691},
#   {'City': 'Ossora',
#    'Lat': 59.2353,
#    'Lng': 163.0719,
#    'Max Temp': 42.19,
#    'Humidity': 83,
#    'Cloudiness': 91,
#    'Wind Speed': 7.31,
#    'Country': 'RU',
#    'Date': 1632684691},
#   {'City': 'Laï',
#    'Lat': 9.3952,
#    'Lng': 16.2989,
#    'Max Temp': 77.23,
#    'Humidity': 77,
#    'Cloudiness': 87,
#    'Wind Speed': 2.17,
#    'Country': 'TD',
#    'Date': 1632684691},
#   {'City': 'Bull Savanna',
#    'Lat': 17.8868,
#    'Lng': -77.5902,
#    'Max Temp': 84.27,
#    'Humidity': 64,
#    'Cloudiness': 2,
#    'Wind Speed': 5.73,
#    'Country': 'JM',
#    'Date': 1632684692},
#   {'City': 'Pinega',
#    'Lat': 64.7001,
#    'Lng': 43.3936,
#    'Max Temp': 45.63,
#    'Humidity': 97,
#    'Cloudiness': 100,
#    'Wind Speed': 3.2,
#    'Country': 'RU',
#    'Date': 1632684692},
#   {'City': 'Ciudad del Carmen',
#    'Lat': 18.6333,
#    'Lng': -91.8333,
#    'Max Temp': 86.04,
#    'Humidity': 70,
#    'Cloudiness': 40,
#    'Wind Speed': 4.61,
#    'Country': 'MX',
#    'Date': 1632684692},
#   {'City': 'Santiago de Cao',
#    'Lat': -7.9589,
#    'Lng': -79.2392,
#    'Max Temp': 62.73,
#    'Humidity': 82,
#    'Cloudiness': 90,
#    'Wind Speed': 8.05,
#    'Country': 'PE',
#    'Date': 1632684692},
#   {'City': 'Kambi',
#    'Lat': 39.2177,
#    'Lng': 20.8998,
#    'Max Temp': 75.06,
#    'Humidity': 52,
#    'Cloudiness': 0,
#    'Wind Speed': 3.44,
#    'Country': 'GR',
#    'Date': 1632684693},
#   {'City': 'Jiwani',
#    'Lat': 25.05,
#    'Lng': 61.7417,
#    'Max Temp': 82,
#    'Humidity': 80,
#    'Cloudiness': 6,
#    'Wind Speed': 5.59,
#    'Country': 'PK',
#    'Date': 1632684693},
#   {'City': 'Yeppoon',
#    'Lat': -23.1333,
#    'Lng': 150.7333,
#    'Max Temp': 65.98,
#    'Humidity': 75,
#    'Cloudiness': 98,
#    'Wind Speed': 13.09,
#    'Country': 'AU',
#    'Date': 1632684694},
#   {'City': 'Suntar',
#    'Lat': 62.1444,
#    'Lng': 117.6319,
#    'Max Temp': 35.94,
#    'Humidity': 83,
#    'Cloudiness': 100,
#    'Wind Speed': 13.02,
#    'Country': 'RU',
#    'Date': 1632684694},
#   {'City': 'Goderich',
#    'Lat': 43.7501,
#    'Lng': -81.7165,
#    'Max Temp': 63.91,
#    'Humidity': 63,
#    'Cloudiness': 100,
#    'Wind Speed': 10.36,
#    'Country': 'CA',
#    'Date': 1632684671},
#   {'City': 'Mikhaylovskoye',
#    'Lat': 51.8239,
#    'Lng': 79.7172,
#    'Max Temp': 30,
#    'Humidity': 76,
#    'Cloudiness': 2,
#    'Wind Speed': 5.55,
#    'Country': 'RU',
#    'Date': 1632684694},
#   {'City': 'Madimba',
#    'Lat': -10.4,
#    'Lng': 40.3333,
#    'Max Temp': 74.52,
#    'Humidity': 88,
#    'Cloudiness': 20,
#    'Wind Speed': 11.5,
#    'Country': 'TZ',
#    'Date': 1632684435},
#   {'City': 'Mahon',
#    'Lat': 39.8885,
#    'Lng': 4.2658,
#    'Max Temp': 75.76,
#    'Humidity': 73,
#    'Cloudiness': 20,
#    'Wind Speed': 8.05,
#    'Country': 'ES',
#    'Date': 1632684695},
#   {'City': 'Stromness',
#    'Lat': 58.965,
#    'Lng': -3.296,
#    'Max Temp': 59.25,
#    'Humidity': 87,
#    'Cloudiness': 76,
#    'Wind Speed': 11.01,
#    'Country': 'GB',
#    'Date': 1632684695},
#   {'City': '‘Āhuimanu',
#    'Lat': 21.4447,
#    'Lng': -157.8378,
#    'Max Temp': 87.51,
#    'Humidity': 70,
#    'Cloudiness': 90,
#    'Wind Speed': 10.36,
#    'Country': 'US',
#    'Date': 1632684695},
#   {'City': 'Morristown',
#    'Lat': 36.214,
#    'Lng': -83.2949,
#    'Max Temp': 76.21,
#    'Humidity': 42,
#    'Cloudiness': 1,
#    'Wind Speed': 6.91,
#    'Country': 'US',
#    'Date': 1632684542},
#   {'City': 'Necochea',
#    'Lat': -38.5473,
#    'Lng': -58.7368,
#    'Max Temp': 52.03,
#    'Humidity': 70,
#    'Cloudiness': 100,
#    'Wind Speed': 16.24,
#    'Country': 'AR',
#    'Date': 1632684549},
#   {'City': 'Prieska',
#    'Lat': -29.6641,
#    'Lng': 22.7474,
#    'Max Temp': 72.57,
#    'Humidity': 10,
#    'Cloudiness': 0,
#    'Wind Speed': 4.25,
#    'Country': 'ZA',
#    'Date': 1632684696},
#   {'City': 'Mehamn',
#    'Lat': 71.0357,
#    'Lng': 27.8492,
#    'Max Temp': 48.38,
#    'Humidity': 71,
#    'Cloudiness': 0,
#    'Wind Speed': 17.27,
#    'Country': 'NO',
#    'Date': 1632684696},
#   {'City': 'Gouré',
#    'Lat': 13.9835,
#    'Lng': 10.2704,
#    'Max Temp': 88.02,
#    'Humidity': 15,
#    'Cloudiness': 47,
#    'Wind Speed': 4.14,
#    'Country': 'NE',
#    'Date': 1632684696},
#   {'City': 'Itacaré',
#    'Lat': -14.2775,
#    'Lng': -38.9967,
#    'Max Temp': 73.29,
#    'Humidity': 76,
#    'Cloudiness': 33,
#    'Wind Speed': 7.65,
#    'Country': 'BR',
#    'Date': 1632684697},
#   {'City': 'Yuzawa',
#    'Lat': 39.1667,
#    'Lng': 140.5,
#    'Max Temp': 55.72,
#    'Humidity': 92,
#    'Cloudiness': 10,
#    'Wind Speed': 4.16,
#    'Country': 'JP',
#    'Date': 1632684697},
#   {'City': 'Mackay',
#    'Lat': -21.15,
#    'Lng': 149.2,
#    'Max Temp': 67.05,
#    'Humidity': 94,
#    'Cloudiness': 75,
#    'Wind Speed': 5.75,
#    'Country': 'AU',
#    'Date': 1632684614},
#   {'City': 'Koumac',
#    'Lat': -20.5667,
#    'Lng': 164.2833,
#    'Max Temp': 71.26,
#    'Humidity': 66,
#    'Cloudiness': 100,
#    'Wind Speed': 2.17,
#    'Country': 'NC',
#    'Date': 1632684697},
#   {'City': 'Beloha',
#    'Lat': -25.1667,
#    'Lng': 45.05,
#    'Max Temp': 70.93,
#    'Humidity': 70,
#    'Cloudiness': 38,
#    'Wind Speed': 7.43,
#    'Country': 'MG',
#    'Date': 1632684697},
#   {'City': 'Bathsheba',
#    'Lat': 13.2167,
#    'Lng': -59.5167,
#    'Max Temp': 88.41,
#    'Humidity': 66,
#    'Cloudiness': 40,
#    'Wind Speed': 8.05,
#    'Country': 'BB',
#    'Date': 1632684438},
#   {'City': 'Yarim',
#    'Lat': 14.298,
#    'Lng': 44.3779,
#    'Max Temp': 59.58,
#    'Humidity': 25,
#    'Cloudiness': 0,
#    'Wind Speed': 2.53,
#    'Country': 'YE',
#    'Date': 1632684698},
#   {'City': 'Katangli',
#    'Lat': 51.7102,
#    'Lng': 143.2326,
#    'Max Temp': 47.37,
#    'Humidity': 82,
#    'Cloudiness': 74,
#    'Wind Speed': 3.96,
#    'Country': 'RU',
#    'Date': 1632684698},
#   {'City': 'Kaputa',
#    'Lat': -8.4689,
#    'Lng': 29.6619,
#    'Max Temp': 77.68,
#    'Humidity': 44,
#    'Cloudiness': 14,
#    'Wind Speed': 2.8,
#    'Country': 'ZM',
#    'Date': 1632684698},
#   {'City': 'San Miguel de Cozumel',
#    'Lat': 20.5083,
#    'Lng': -86.9458,
#    'Max Temp': 87.78,
#    'Humidity': 89,
#    'Cloudiness': 75,
#    'Wind Speed': 11.5,
#    'Country': 'MX',
#    'Date': 1632684699},
#   {'City': 'Katsuura',
#    'Lat': 35.1333,
#    'Lng': 140.3,
#    'Max Temp': 66.31,
#    'Humidity': 75,
#    'Cloudiness': 30,
#    'Wind Speed': 13.8,
#    'Country': 'JP',
#    'Date': 1632684699},
#   {'City': 'Egvekinot',
#    'Lat': 66.3167,
#    'Lng': -179.1667,
#    'Max Temp': 21.72,
#    'Humidity': 77,
#    'Cloudiness': 15,
#    'Wind Speed': 3.2,
#    'Country': 'RU',
#    'Date': 1632684699},
#   {'City': 'Bima',
#    'Lat': -8.4667,
#    'Lng': 118.7167,
#    'Max Temp': 74.21,
#    'Humidity': 91,
#    'Cloudiness': 31,
#    'Wind Speed': 4.09,
#    'Country': 'ID',
#    'Date': 1632684699},
#   {'City': 'Kardymovo',
#    'Lat': 54.8902,
#    'Lng': 32.4311,
#    'Max Temp': 46.17,
#    'Humidity': 89,
#    'Cloudiness': 55,
#    'Wind Speed': 10.89,
#    'Country': 'RU',
#    'Date': 1632684700},
#   {'City': 'Chicama',
#    'Lat': -7.8447,
#    'Lng': -79.1469,
#    'Max Temp': 61.34,
#    'Humidity': 62,
#    'Cloudiness': 17,
#    'Wind Speed': 10.36,
#    'Country': 'PE',
#    'Date': 1632684700},
#   {'City': 'Bilibino',
#    'Lat': 68.0546,
#    'Lng': 166.4372,
#    'Max Temp': 26.92,
#    'Humidity': 97,
#    'Cloudiness': 100,
#    'Wind Speed': 13.15,
#    'Country': 'RU',
#    'Date': 1632684700},
#   {'City': 'Ndioum',
#    'Lat': 16.5129,
#    'Lng': -14.6471,
#    'Max Temp': 93.09,
#    'Humidity': 27,
#    'Cloudiness': 98,
#    'Wind Speed': 7.29,
#    'Country': 'SN',
#    'Date': 1632684701},
#   {'City': 'Limbang',
#    'Lat': 4.75,
#    'Lng': 115,
#    'Max Temp': 77.11,
#    'Humidity': 98,
#    'Cloudiness': 77,
#    'Wind Speed': 2.04,
#    'Country': 'MY',
#    'Date': 1632684701},
#   {'City': 'Asău',
#    'Lat': 46.4333,
#    'Lng': 26.4,
#    'Max Temp': 61.39,
#    'Humidity': 86,
#    'Cloudiness': 1,
#    'Wind Speed': 2.73,
#    'Country': 'RO',
#    'Date': 1632684701},
#   {'City': 'Strezhevoy',
#    'Lat': 60.7333,
#    'Lng': 77.5889,
#    'Max Temp': 33.78,
#    'Humidity': 90,
#    'Cloudiness': 7,
#    'Wind Speed': 6.98,
#    'Country': 'RU',
#    'Date': 1632684701},
#   {'City': 'Fairbanks',
#    'Lat': 64.8378,
#    'Lng': -147.7164,
#    'Max Temp': 33.1,
#    'Humidity': 87,
#    'Cloudiness': 90,
#    'Wind Speed': 0,
#    'Country': 'US',
#    'Date': 1632684610},
#   {'City': 'Jand',
#    'Lat': 33.4299,
#    'Lng': 72.0193,
#    'Max Temp': 86.14,
#    'Humidity': 49,
#    'Cloudiness': 0,
#    'Wind Speed': 5.17,
#    'Country': 'PK',
#    'Date': 1632684702},
#   {'City': 'Yakeshi',
#    'Lat': 49.2833,
#    'Lng': 120.7333,
#    'Max Temp': 41.67,
#    'Humidity': 91,
#    'Cloudiness': 3,
#    'Wind Speed': 9.98,
#    'Country': 'CN',
#    'Date': 1632684702},
#   {'City': 'Trincomalee',
#    'Lat': 8.5711,
#    'Lng': 81.2335,
#    'Max Temp': 80.8,
#    'Humidity': 78,
#    'Cloudiness': 100,
#    'Wind Speed': 22.66,
#    'Country': 'LK',
#    'Date': 1632684751},
#   {'City': 'Bac Lieu',
#    'Lat': 9.285,
#    'Lng': 105.7244,
#    'Max Temp': 79.12,
#    'Humidity': 86,
#    'Cloudiness': 31,
#    'Wind Speed': 6.93,
#    'Country': 'VN',
#    'Date': 1632684751}],
#  545)

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert to DataFrame
city_weather_df = pd.DataFrame(weather_data_list)

# Export the city data into a .csv
city_weather_df.to_csv(output_data_file)

# Display the DataFrame 
city_weather_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Zaozyornoye  45.1582   33.2787     64.94        68          59
# 1           Bluff -46.6000  168.3333     38.79        80          21
# 2        Windhoek -22.5594   17.0832     77.20        16           2
# 3         Cayenne   4.9333  -52.3333     89.64        71          88
# 4  Vestmannaeyjar  63.4427  -20.2734     43.25        81          98
#
#    Wind Speed Country        Date
# 0       10.38      UA  1632683939
# 1        7.96      NZ  1632683947
# 2        4.61      NA  1632683948
# 3        5.99      GF  1632683948
# 4        5.14      IS  1632683948

# %%
city_weather_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  545.000000  545.000000  545.000000  545.000000  545.000000  545.000000
# mean    20.876802   14.913410   64.916569   69.365138   49.627523    8.003963
# std     33.619993   93.840483   18.358833   22.636528   40.176481    5.469403
# min    -54.800000 -179.166700   20.520000    7.000000    0.000000    0.000000
# 25%     -8.466700  -70.099500   50.920000   57.000000    6.000000    4.000000
# 50%     26.100000   20.040300   68.470000   76.000000   46.000000    6.910000
# 75%     49.866800  102.500000   78.370000   87.000000   91.000000   10.980000
# max     78.218600  179.316700  106.210000  100.000000  100.000000   30.580000
#
#                Date
# count  5.450000e+02
# mean   1.632684e+09
# std    2.570250e+02
# min    1.632684e+09
# 25%    1.632684e+09
# 50%    1.632684e+09
# 75%    1.632685e+09
# max    1.632685e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#city_weather_df

city_weather_df.loc[city_weather_df['Humidity']>100]

# No cities in this set had > 100 humidity so skipping
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Cloudiness, Wind Speed, Country, Date]
# Index: []

# %%
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  550.000000  550.000000  550.000000  550.000000  550.000000  550.000000
# mean    19.973545   17.124400   58.331400   67.890909   52.141818    8.544800
# std     33.284840   91.595451   25.795297   20.864881   35.766469    6.078869
# min    -54.800000 -179.170000  -11.340000    9.000000    0.000000    0.160000
# 25%     -8.077500  -64.627500   42.800000   55.000000   20.000000    4.525000
# 50%     23.630000   19.635000   64.940000   72.000000   57.000000    7.325000
# 75%     48.672500   97.350000   78.800000   83.000000   86.750000   11.410000
# max     78.220000  179.320000  102.200000  100.000000  100.000000   46.080000
#
#                Date
# count  5.500000e+02
# mean   1.585764e+09
# std    5.539674e+01
# min    1.585764e+09
# 25%    1.585764e+09
# 50%    1.585764e+09
# 75%    1.585764e+09
# max    1.585764e+09

# %%
#  Get the indices of cities that have humidity over 100%.

# No cities in this set had > 100 humidity so skipping
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# No cities in this set had > 100 humidity so skipping
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   butaritari   3.07  172.79     83.32        74          84       10.42
# 1  yerbogachen  61.28  108.01     79.52        58          20        7.70
# 2    cape town -33.93   18.42     73.00        77          27        4.70
# 3        touba   8.28   -7.68     79.97        75          82        3.58
# 4    jamestown  42.10  -79.24     64.00        88           1        6.93
#
#   Country        Date
# 0      KI  1593605283
# 1      RU  1593605121
# 2      ZA  1593605039
# 3      CI  1593605284
# 4      US  1593605284

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Scatter plot with border around marker
plt.scatter(city_weather_df["Lat"], city_weather_df["Max Temp"], edgecolors='k')

# Label
today = date.today()
plt.title(f"City Latitude vs. Max Temperature ({today.strftime('%m/%d/%y')})")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save to image file
plt.savefig(f"{output_data_loc}/Lat_vs_MaxTemp_InWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Scatter plot with border around marker
plt.scatter(city_weather_df["Lat"], city_weather_df["Humidity"], edgecolors='k')

# Label
today = date.today()
plt.title(f"City Latitude vs. Humidity ({today.strftime('%m/%d/%y')})")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save to image file
plt.savefig(f"{output_data_loc}/Lat_vs_Humidity_InWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Scatter plot with border around marker
plt.scatter(city_weather_df["Lat"], city_weather_df["Cloudiness"], edgecolors='k')

# Label
today = date.today()
plt.title(f"City Latitude vs. Cloudiness ({today.strftime('%m/%d/%y')})")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save to image file
plt.savefig(f"{output_data_loc}/Lat_vs_Cloudiness_InWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Scatter plot with border around marker
plt.scatter(city_weather_df["Lat"], city_weather_df["Wind Speed"], edgecolors='k')

# Label
today = date.today()
plt.title(f"City Latitude vs. Wind Speed ({today.strftime('%m/%d/%y')})")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save to image file
plt.savefig(f"{output_data_loc}/Lat_vs_WindSpeed_InWorldCities.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.46937863826630627

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.6082708688906918

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.000543987878808455

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.014985174297345524

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0020898727664228514

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.0035263772085582894

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.04019723576144484

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Out:
# The r-value is: 0.017128274759839232
